# %%
import pandas as pd
import os
import tables

# %%
absolute_path = "C:\\Users\\tykun\\\OneDrive\\Documents\\SchoolDocs\VSCodeProjects\\connectedData\\board_analysis\\"
altered_dataframes = "altered_dataframes\\"
gpt_dataframes = "gpt_dataframes\\"
graphs = "graphs\\"
scripts =  "scripts\\"
board_dataframes = "board_dataframes\\"
temporary = "temporary_data\\"
college_matching = "college_matching\\"

altered_dataframe_path = f"{absolute_path}{altered_dataframes}"
gpt_dataframe_path = f"{absolute_path}{gpt_dataframes}" 
graph_path = f"{absolute_path}{graphs}"
script_path = f"{absolute_path}{scripts}"
boards_path = f"{absolute_path}{board_dataframes}"
temporary_data_path = f"{absolute_path}{temporary}"
college_matching_path = f"{absolute_path}{college_matching}"
rankings_path = f"{absolute_path}university_rankings\\"


# Valid Years
years = ["1999", "2000", "2005", "2008", "2009", "2013"]

# %%
for year in years:
    file_path = f"{rankings_path}shanghai\\ShanghaiUniversityRanking_ShanghaiRanking{year}.hdf"
    if os.path.exists(file_path):
        try:
            shanghai_df = pd.read_hdf(file_path)
            print(shanghai_df.head())
        except Exception as e:
            print(f"Error reading HDF file for year {year}: {e}")
    else:
        print(f"HDF file does not exist for year {year}: {file_path}")
# Out:
# HDF file does not exist for year 1999: C:\Users\tykun\\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\university_rankings\shanghai\ShanghaiUniversityRanking_ShanghaiRanking1999.hdf
# HDF file does not exist for year 2000: C:\Users\tykun\\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\university_rankings\shanghai\ShanghaiUniversityRanking_ShanghaiRanking2000.hdf
#   Rank                                     FullName  \
# 0    1                           Harvard University
# 1    2                      University of Cambridge
# 2    3                          Stanford University
# 3    4           University of California, Berkeley
# 4    5  Massachusetts Institute of Technology (MIT)
#
#                                                 href        Country  \
# 0  World-University-Rankings/Harvard-University.html   UnitedStates
# 1  World-University-Rankings/University-of-Cambri...  UnitedKingdom
# 2  World-University-Rankings/Stanford-University....   UnitedStates
# 3  World-University-Rankings/University-of-Califo...   UnitedStates
# 4  World-University-Rankings/Massachusetts-Instit...   UnitedStates
#
#    TotalScore  Alumni  Award   HiCi    N&S    Pub   PCP  AffiliationID
# 0       100.0   100.0  100.0  100.0  100.0  100.0  72.4    136199984.0
# 1        73.6    99.8   93.4   53.3   56.6   70.9  66.9       241749.0
# 2        73.4    41.1   72.2   88.5   70.9   72.3  65.0     97018004.0
# 3        72.8    71.8   76.0   69.4   73.9   72.2  52.7     95457486.0
# 4        70.1    74.0   80.6   66.7   65.8   64.3  53.0     63966007.0
#   Rank                                     FullName  \
# 0    1                           Harvard University
# 1    2                          Stanford University
# 2    3           University of California, Berkeley
# 3    4                      University of Cambridge
# 4    5  Massachusetts Institute of Technology (MIT)
#
#                                                 href        Country  \
# 0  World-University-Rankings/Harvard-University.html   UnitedStates
# 1  World-University-Rankings/Stanford-University....   UnitedStates
# 2  World-University-Rankings/University-of-Califo...   UnitedStates
# 3  World-University-Rankings/University-of-Cambri...  UnitedKingdom
# 4  World-University-Rankings/Massachusetts-Instit...   UnitedStates
#
#    TotalScore  Alumni  Award   HiCi    N&S    Pub   PCP  AffiliationID
# 0       100.0   100.0  100.0  100.0  100.0  100.0  74.1    136199984.0
# 1        73.7    40.0   78.7   86.6   68.9   71.6  66.9     97018004.0
# 2        71.4    69.0   77.1   68.8   70.6   70.0  53.0     95457486.0
# 3        70.4    90.3   91.5   53.6   56.0   64.1  65.0       241749.0
# 4        69.6    71.0   80.6   65.6   68.7   61.6  53.9     63966007.0
#   Rank                                     FullName  \
# 0    1                           Harvard University
# 1    2                          Stanford University
# 2    3           University of California, Berkeley
# 3    4                      University of Cambridge
# 4    5  Massachusetts Institute of Technology (MIT)
#
#                                                 href        Country  \
# 0  World-University-Rankings/Harvard-University.html   UnitedStates
# 1  World-University-Rankings/Stanford-University....   UnitedStates
# 2  World-University-Rankings/University-of-Califo...   UnitedStates
# 3  World-University-Rankings/University-of-Cambri...  UnitedKingdom
# 4  World-University-Rankings/Massachusetts-Instit...   UnitedStates
#
#    TotalScore  Alumni  Award   HiCi    N&S    Pub   PCP  AffiliationID
# 0       100.0   100.0  100.0  100.0  100.0  100.0  74.8    136199984.0
# 1        73.1    39.0   78.7   87.1   67.3   70.1  66.9     97018004.0
# 2        71.0    67.4   77.1   68.4   71.1   69.0  53.2     95457486.0
# 3        70.2    89.4   91.5   53.8   53.9   65.4  65.5       241749.0
# 4        69.5    71.0   80.6   65.7   67.9   62.0  54.4     63966007.0
#   Rank                                     FullName  \
# 0    1                           Harvard University
# 1    2                          Stanford University
# 2    3           University of California, Berkeley
# 3    4  Massachusetts Institute of Technology (MIT)
# 4    5                      University of Cambridge
#
#                                                 href        Country  \
# 0  World-University-Rankings/Harvard-University.html   UnitedStates
# 1  World-University-Rankings/Stanford-University....   UnitedStates
# 2  World-University-Rankings/University-of-Califo...   UnitedStates
# 3  World-University-Rankings/Massachusetts-Instit...   UnitedStates
# 4  World-University-Rankings/University-of-Cambri...  UnitedKingdom
#
#    TotalScore  Alumni  Award   HiCi    N&S    Pub   PCP  AffiliationID
# 0       100.0   100.0  100.0  100.0  100.0  100.0  72.5    136199984.0
# 1        72.6    40.0   80.7   88.9   68.7   69.4  50.4     97018004.0
# 2        71.3    67.8   79.0   69.7   68.5   68.1  54.7     95457486.0
# 3        71.1    68.0   81.3   68.2   69.7   60.1  65.0     63966007.0
# 4        69.6    79.1   97.3   54.6   54.0   66.2  53.3       241749.0
