# %%
import pandas as pd
from collections import defaultdict, Counter
import networkx as nx
import os
import re
import matplotlib.pyplot as plt
from rapidfuzz import fuzz
from itertools import combinations

# %%
absolute_path = "C:\\Users\\tykun\\OneDrive\\Documents\\SchoolDocs\\VSCodeProjects\\connectedData\\board_analysis\\"
altered_dataframes = "altered_dataframes\\"
gpt_dataframes = "gpt_dataframes\\"
graphs = "graphs\\"  
scripts = "scripts\\"
board_dataframes = "board_dataframes\\"
yearly_interlocks = "yearly_interlocks\\"
final_scripts = "final_scripts\\"
normalized_dataframes = "normalized_dataframes\\"


years = ["1999", "2000", "2005", "2007", "2008", "2009", "2011", "2013", "2018"]

# %%
def remove_non_samples(df: pd.DataFrame) -> pd.DataFrame:
    """Filter the DataFrame to include only rows where 'PrimarySample' is True."""
    return df[df['PrimarySample'] == True]

def normalize(x):
    """Convert the input to a string and strip whitespace."""
    return str(x).strip()

# %%
#year invariant dataframes
affiliation_path = os.path.join(absolute_path, final_scripts, 'normalized_dataframes\\affiliation_altered.csv')
state_system_path = os.path.join(absolute_path, final_scripts, 'normalized_dataframes\\state_systems_validated.csv')

affiliation_df = pd.read_csv(affiliation_path)
state_systems_df = pd.read_csv(state_system_path)

affiliation_df["AffiliationId"] = affiliation_df["AffiliationId"].astype(str)
affiliation_df = affiliation_df.drop_duplicates(subset=['AffiliationId'])

state_systems_df["AffiliationId"] = state_systems_df["AffiliationId"].astype(str)
state_systems_df = state_systems_df.drop_duplicates(subset=['AffiliationId'])

# %%
for year in years:
    board_path = os.path.join(absolute_path, board_dataframes, f"{year}_boards.csv")
    double_board_path = os.path.join(absolute_path, board_dataframes, f"{year}_double_board.csv")
    
    # Read the board data
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    # board_df = remove_non_samples(board_df)
    # double_board_df = remove_non_samples(double_board_df)

    board_df["AffiliationId"] = board_df["AffiliationId"].astype(str)
    double_board_df["AffiliationId"] = double_board_df["AffiliationId"].astype(str)
    double_board_df['StateSystem'] = ''

    board_df['AffiliationId'] = board_df['AffiliationId'].fillna('0')
    double_board_df['AffiliationId'] = double_board_df['AffiliationId'].fillna('0')

    # Merge affiliation_df's PrimarySample into board_df.
    # Use suffixes so that board_df's original column is preserved.
    merged_df = board_df.merge(
        affiliation_df[['AffiliationId', 'PrimarySample']],
        on='AffiliationId',
        how='left',
        suffixes=('_board', '')
    )
    merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])
    merged_df.drop('PrimarySample_board', axis=1, inplace=True)

    board_df = merged_df
    board_df = board_df.drop_duplicates()

    merged_df = board_df.merge(
        state_systems_df[['AffiliationId', 'StateSystem']],
        on='AffiliationId',
        how='left',
        suffixes=('_board', '')
    )
    merged_df['StateSystem'] = merged_df['StateSystem'].combine_first(merged_df['StateSystem_board'])
    merged_df.drop('StateSystem_board', axis=1, inplace=True)

    board_df = merged_df
    board_df = board_df.drop_duplicates()

    
    

    merged_df = double_board_df.merge(
        affiliation_df[['AffiliationId', 'PrimarySample']],
        on='AffiliationId',
        how='left',
        suffixes=('_board', '')
    )
    merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])
    merged_df.drop('PrimarySample_board', axis=1, inplace=True)

    double_board_df = merged_df
    double_board_df = double_board_df.drop_duplicates()

    merged_df = double_board_df.merge(
        state_systems_df[['AffiliationId', 'StateSystem']],
        on='AffiliationId',
        how='left',
        suffixes=('_board', '')
    )
    merged_df['StateSystem'] = merged_df['StateSystem'].combine_first(merged_df['StateSystem_board'])
    merged_df.drop('StateSystem_board', axis=1, inplace=True)

    double_board_df = double_board_df
    double_board_df = double_board_df.drop_duplicates()
    
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    board_df.to_csv(os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv"), index=False)
    double_board_df.to_csv(os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_double_boards_normalized.csv"), index=False)
# Out:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\3452257815.py:26: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\3452257815.py:26: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\3452257815.py:26: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\3452257815.py:26: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   merged_df['PrimarySample'] = merged_df['PrimarySample'].combine_first(merged_df['PrimarySample_board'])

# %%
affiliation_name_counter = defaultdict(Counter)  # Maps AffiliationId -> Counter of {InstitutionName: count}
years_data = {}  

for year in years:
    file_path = os.path.join(
        absolute_path, 
        final_scripts, 
        normalized_dataframes, 
        f"{year}_boards_normalized.csv"
    )
    
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    
    # Store the DataFrame in a dict so we don't need to re-read later
    years_data[year] = board_df
    
    # Count the number of times that an affiliation id and institution shows up
    for aff_id, institution_name in zip(board_df["AffiliationId"], board_df["Institution"]):
        affiliation_name_counter[aff_id][institution_name] += 1

affiliation_final_name = {}
# Get the most commonly appearing institution name for each affiliation id
for aff_id, name_counter in affiliation_name_counter.items():
    most_common_name = name_counter.most_common(1)[0][0]
    affiliation_final_name[aff_id] = most_common_name

print("Overall affiliation mapping:")
print(affiliation_final_name)

# Remove any keys that are NaN
affiliation_final_name = {k: v for k, v in affiliation_final_name.items() if pd.notna(k)}

# Update the dataframes with the standardized names we made
for year in years:
    board_df = years_data[year]
    # Make a copy of the original Institution names for printing purposes.
    original_names = board_df["Institution"].copy()
    
    board_df["Institution"] = board_df["AffiliationId"].map(affiliation_final_name)
    
    # For each unique affiliation id, print the group and name change only if a change occurred.
    for aff in board_df["AffiliationId"].unique():
        group_old_names = original_names[board_df["AffiliationId"] == aff].unique()
        new_name = affiliation_final_name.get(aff, None)
        # Only print if the change actually occurs (i.e. not all original names equal the new name)
        if set(group_old_names) != {new_name}:
            print(f"Year {year}: AffiliationId '{aff}' had original names {group_old_names} -> changed to '{new_name}'")
    
    output_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df.to_csv(output_path, index=False)

    print(f"Year {year} updated and saved to: {output_path}")
# Out:
# Overall affiliation mapping:
# {71965598.0: 'Adelphi University', 181401687.0: 'American University', 102298084.0: 'Andrews University', 55732556.0: 'Arizona State University', 82497590.0: 'Auburn University', 198089087.0: 'Ball State University', 157394403.0: 'Baylor University', 152479009.0: 'Biola University', 103531236.0: 'Boston College', 111088046.0: 'Boston University', 157417397.0: 'Bowling Green State University', 6902469.0: 'Brandeis University', 100005738.0: 'Brigham Young University', 27804330.0: 'Brown University', 122411786.0: 'California Institute Of Technology', 74973139.0: 'Carnegie Mellon University', 58956616.0: 'Case Western Reserve University', 84470341.0: 'Catholic University Of America', 1629065.0: 'Central Michigan University', 185071736.0: 'Chapman University', 174216632.0: 'City University Of New York', 52064589.0: 'Clark Atlanta University', 130785548.0: 'Clark University', 16944753.0: 'Clarkson University', 8078737.0: 'Clemson University', 102607778.0: 'Cleveland State University', 16285277.0: 'College Of William And Mary', 167576493.0: 'Colorado School Of Mines', 78577930.0: 'Columbia University', 205783295.0: 'Cornell University', 114493937.0: 'Creighton University', 107672454.0: 'Dartmouth College', 118353179.0: 'Depaul University', 72816309.0: 'Drexel University', 170897317.0: 'Duke University', 165102784.0: 'Duquesne University', 119443389.0: 'East Tennessee State University', 138216421.0: 'Eastern Michigan University', 150468666.0: 'Emory University', 106959904.0: 'Florida Institute Of Technology', 164389053.0: 'Fordham University', 66108857.0: 'Gallaudet University', 162714631.0: 'George Mason University', 193531525.0: 'George Washington University', 184565670.0: 'Georgetown University', 151328261.0: 'Hampton University', 136199984.0: 'Harvard University', 139290212.0: 'Hofstra University', 137853757.0: 'Howard University', 106969075.0: 'Idaho State University', 180949307.0: 'Illinois Institute Of Technology', 47301684.0: 'Illinois State University', 86420138.0: 'Indiana State University', 200885203.0: 'Indiana University Of Pennsylvania', 173911158.0: 'Iowa State University', 11883440.0: 'James Madison University', 145311948.0: 'Johns Hopkins University', 189590672.0: 'Kansas State University', 149910238.0: 'Kent State University', 186143895.0: 'Lehigh University', 26347476.0: 'Loma Linda University', 138873065.0: 'Long Island University', 107341208.0: 'Louisiana State University System', 35566140.0: 'Loyola Marymount University', 1925986.0: 'Loyola University Chicago', 102461120.0: 'Marquette University', 88694374.0: 'Marshall University', 63966007.0: 'Massachusetts Institute Of Technology', 150149174.0: 'Mercer University', 83328450.0: 'Miami University', 87216513.0: 'Michigan State University', 11957088.0: 'Michigan Technological University', 169615421.0: 'Middle Tennessee State University', 99041443.0: 'Mississippi State University', 166088655.0: 'Montclair State University', 118118575.0: 'New Jersey Institute Of Technology', 10052268.0: 'New Mexico State University', 102179633.0: 'New School', 57206974.0: 'New York University', 35777872.0: 'North Carolina Agricultural And Technical State University', 137902535.0: 'North Carolina State University', 4210127926.0: 'North Dakota University System', 203172682.0: 'Northern Arizona University', 102502594.0: 'Northern Illinois University', 203088144.0: 'Nova Southeastern University', 177721651.0: 'Oakland University', 52357470.0: 'Ohio State University', 4210106879.0: 'Ohio University', 115475287.0: 'Oklahoma State University', 81365321.0: 'Old Dominion University', 126863827.0: 'Pace University', 29957033.0: 'Pennsylvania State System Of Higher Education', 130769515.0: 'Pennsylvania State University', 100191712.0: 'Pepperdine University', 20089843.0: 'Princeton University', 219193219.0: 'Purdue University', 165799507.0: 'Rensselaer Polytechnic Institute', 74775410.0: 'Rice University', 155173764.0: 'Rochester Institute Of Technology', 44265643.0: 'Rowan University', 1023221 ...
# Year 1999: AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 1999: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 1999: AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 1999: AffiliationId '392282.0' had original names ['State University Of New York At Albany'] -> changed to 'University At Albany Suny'
# Year 1999: AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'University At Buffalo State University Of New York'
# Year 1999: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 1999: AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 1999 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\1999_boards_normalized.csv
# Year 2000: AffiliationId '174216632.0' had original names ['City University Of New York Cuny'] -> changed to 'City University Of New York'
# Year 2000: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2000: AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2000: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2000: AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'University At Buffalo State University Of New York'
# Year 2000: AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 2000: AffiliationId '2801919071.0' had original names ['University Of Illinois'] -> changed to 'University Of Illinois System'
# Year 2000 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2000_boards_normalized.csv
# Year 2005: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2005: AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2005: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2005: AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University Of New York At Stony Brook'
# Year 2005 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2005_boards_normalized.csv
# Year 2007: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2007: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2007: AffiliationId '1327163397.0' had original names ['State University Of New York'] -> changed to 'State University Of New York System'
# Year 2007 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2007_boards_normalized.csv
# Year 2008: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2008: AffiliationId '23732399.0' had original names ['Montana State University'] -> changed to 'Montana State University Bozeman'
# Year 2008: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2008: AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University Of New York At Stony Brook'
# Year 2008: AffiliationId '2801919071.0' had original names ['University Of Illinois'] -> changed to 'University Of Illinois System'
# Year 2008 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2008_boards_normalized.csv
# Year 2009: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2009: AffiliationId '23732399.0' had original names ['Montana State University'] -> changed to 'Montana State University Bozeman'
# Year 2009: AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2009: AffiliationId '1327163397.0' had original names ['State University Of New York'] -> changed to 'State University Of New York System'
# Year 2009: AffiliationId '859038795.0' had original names ['Virginia Tech'] -> changed to 'Virginia Polytechnic Institute And State University'
# Year 2009 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2009_boards_normalized.csv
# Year 2011: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2011: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2011: AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2011 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2011_boards_normalized.csv
# Year 2013: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2013: AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2013: AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2013 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2013_boards_normalized.csv
# Year 2018: AffiliationId 'nan' had original names [] -> changed to 'None'
# Year 2018: AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2018 updated and saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2018_boards_normalized.csv

# %%
#determine how much institution's boards overlap
def group_institutions_by_membership(institution_to_members, threshold):
    """
    Given a dict: {institution -> set_of_members}, return a list of groups
    (lists) of institutions that have >= `threshold` overlap in membership.

    overlap = (size of intersection) / (size of smaller board)
    """
    institutions = list(institution_to_members.keys())
    n = len(institutions)

    # adjacency list for institutions with >= threshold overlap
    adjacency = defaultdict(list)
    for i in range(n):
        for j in range(i + 1, n):
            inst_i, inst_j = institutions[i], institutions[j]
            members_i = institution_to_members[inst_i]
            members_j = institution_to_members[inst_j]
            size_i = len(members_i)
            size_j = len(members_j)

            if size_i == 0 or size_j == 0:
                continue
            
            intersection_size = len(members_i.intersection(members_j))
            smaller_board_size = min(size_i, size_j)
            if smaller_board_size == 0:
                continue
            
            overlap_ratio = intersection_size / smaller_board_size
            if overlap_ratio >= threshold:
                adjacency[inst_i].append(inst_j)
                adjacency[inst_j].append(inst_i)

    #Find connected components via DFS
    visited = set()
    groups = []
    for inst in institutions:
        if inst not in visited:
            stack = [inst]
            group = []
            while stack:
                current = stack.pop()
                if current not in visited:
                    visited.add(current)
                    group.append(current)
                    for neighbor in adjacency[current]:
                        if neighbor not in visited:
                            stack.append(neighbor)
            groups.append(sorted(group))

    #Keep only groups of size >= 2 (meaning actual merges)
    return [g for g in groups if len(g) > 1]

THRESHOLD = 0.7
#want all years of the data in a single var
all_data = {}
for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    df = pd.read_csv(file_path)
    df = remove_non_samples(df)
    all_data[year] = df

#map institution to board members
institution_to_members = defaultdict(set)

#map instituition to state system
institution_to_statesystem = defaultdict(set)

for df in all_data.values():
    for _, row in df.iterrows():
        inst_name = row["Institution"]
        member_id = row["Name"] 
        statesys_val = row["StateSystem"]

        institution_to_members[inst_name].add(member_id)
        if pd.notnull(statesys_val) and statesys_val.strip():
            institution_to_statesystem[inst_name].add(statesys_val.strip())

#determine which groups are categorized as identical
groups = group_institutions_by_membership(institution_to_members, THRESHOLD)

#assign the identical boards the name of their state system
institution_to_canonical_name = {}

for group in groups:
    possible_names = set()
    for inst in group:
        if institution_to_statesystem[inst]:
            possible_names.update(institution_to_statesystem[inst])
    #if one of the schools in the board group is a state system (which it will be), use that one for the name,
    #else just use the original inst name
    if len(possible_names) > 0:
        chosen_name = sorted(possible_names)[0]
    else:
        chosen_name = group[0]

    #map institutions in that group to the new name (state system name)
    for inst in group:
        institution_to_canonical_name[inst] = chosen_name

#now in each individual year, rename these boards
for year, df in all_data.items():
    # Apply the canonical naming (merge the boards)
    df["Institution"] = df["Institution"].apply(lambda x: institution_to_canonical_name.get(x, x))
    
    # --- NEW PRINT BLOCK ---
    print(f"\nIdentical board groups for Year {year}:")
    # Get the set of institutions present in this year's dataframe.
    present_institutions = set(df["Institution"].unique())
    # For each group computed from all data, check which members are present in this year.
    for group in groups:
        present = [inst for inst in group if inst in present_institutions]
        # Only print if more than one institution from the group is present (i.e. a merge will occur)
        if len(set(present)) > 1:
            canonical_name = institution_to_canonical_name[group[0]]
            print(f"Group: {group} (present: {present}) -> Merged into: {canonical_name}")
    # --- END NEW PRINT BLOCK ---

    # Instead of drop_duplicates, group by institution and select the largest board,
    # then remove all rows of the other boards.
    def keep_largest_board(group):
        # Group by board using the AffiliationId column.
        # (If an institution only appears with one board, this will just return the group as-is.)
        boards = group.groupby("AffiliationId", dropna=False)
        if len(boards) <= 1:
            return group
        # Determine which board has the most members.
        board_counts = boards.size()
        best_aff_id = board_counts.idxmax()
        # Return only the rows corresponding to the largest board.
        return group[group["AffiliationId"] == best_aff_id]
    
    df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
    
    out_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    df.to_csv(out_path, index=False)
    print(f"Year {year} merged & saved: {out_path}")
# Out:
# Identical board groups for Year 1999:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 1999 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\1999_boards_normalized.csv
#
# Identical board groups for Year 2000:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2000 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2000_boards_normalized.csv
#
# Identical board groups for Year 2005:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2005 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2005_boards_normalized.csv
#
# Identical board groups for Year 2007:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2007 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2007_boards_normalized.csv
#
# Identical board groups for Year 2008:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2008 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2008_boards_normalized.csv
#
# Identical board groups for Year 2009:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2009 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2009_boards_normalized.csv
#
# Identical board groups for Year 2011:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2011 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2011_boards_normalized.csv
#
# Identical board groups for Year 2013:
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)
# Year 2013 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2013_boards_normalized.csv
#
# Identical board groups for Year 2018:
# Year 2018 merged & saved: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2018_boards_normalized.csv
# C:\Users\tykun\AppData\Local\Temp\ipykernel_11872\766604762.py:134: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Institution", group_keys=False).apply(keep_largest_board).reset_index(drop=True)

# %%
'''
Determine what institutions report their board every year:
'''

institution_info = {}

for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    
    for _, row in board_df.iterrows():
        institution = row.get("Institution")
        affiliation_id = row.get("AffiliationId")
        
        if pd.isna(institution) or normalize(institution) == "":
            continue
        
        #Initialize entry if not already present.
        if institution not in institution_info:
            institution_info[institution] = {"years": set(), "affiliation_ids": set()}
        
        #Record the year in which the institution appears.
        institution_info[institution]["years"].add(year)
        
        #If there is an affiliation id (and it's not empty after normalization), record it.
        if pd.notna(affiliation_id) and normalize(affiliation_id) != "":
            # Ensure the affiliation id is a string.
            affiliation_id = str(affiliation_id).strip()
            institution_info[institution]["affiliation_ids"].add(affiliation_id)

#Create a set of all years (to compare with each institution's set of years)
all_years = set(years)
institutions_every_year = {inst: info for inst, info in institution_info.items() if info["years"] == all_years}
institutions_certain_years = {inst: info for inst, info in institution_info.items() if info["years"] != all_years}


print("Institutions that appear in every year:")
for inst in sorted(institutions_every_year):
    info = institutions_every_year[inst]
    # Sort affiliation ids for readability
    aff_ids = sorted(info["affiliation_ids"])
    print(f"{inst}: Affiliation IDs: {aff_ids}")

print("\nInstitutions that appear in only certain years:")
for inst, info in institutions_certain_years.items():
    aff_ids = sorted(info["affiliation_ids"])
    print(f"{inst}: appears in years {sorted(info['years'])}; Affiliation IDs: {aff_ids}")


# Now, throw away the schools that don't report their board every year from all the dataframes.
for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    
    # Keep only rows where the Institution appears in every year.
    board_df = board_df[board_df["Institution"].isin(institutions_every_year.keys())]
    
    # Save the updated dataframe back to the file.
    board_df.to_csv(file_path, index=False)
    print(f"Year {year}: kept only institutions that report every year.")
# Out:
# Institutions that appear in every year:
# Adelphi University: Affiliation IDs: ['71965598.0']
# American University: Affiliation IDs: ['181401687.0']
# Andrews University: Affiliation IDs: ['102298084.0']
# Arizona Board of Regents: Affiliation IDs: ['138006243.0', '203172682.0', '55732556.0']
# Auburn University: Affiliation IDs: ['82497590.0']
# Ball State University: Affiliation IDs: ['198089087.0']
# Baylor University: Affiliation IDs: ['157394403.0']
# Biola University: Affiliation IDs: ['152479009.0']
# Boston College: Affiliation IDs: ['103531236.0']
# Boston University: Affiliation IDs: ['111088046.0']
# Brandeis University: Affiliation IDs: ['6902469.0']
# Brown University: Affiliation IDs: ['27804330.0']
# Carnegie Mellon University: Affiliation IDs: ['74973139.0']
# Case Western Reserve University: Affiliation IDs: ['58956616.0']
# Catholic University Of America: Affiliation IDs: ['84470341.0']
# Central Michigan University: Affiliation IDs: ['1629065.0']
# Chapman University: Affiliation IDs: ['185071736.0']
# Clark Atlanta University: Affiliation IDs: ['52064589.0']
# Clark University: Affiliation IDs: ['130785548.0']
# Clarkson University: Affiliation IDs: ['16944753.0']
# Clemson University: Affiliation IDs: ['8078737.0']
# College Of William And Mary: Affiliation IDs: ['16285277.0']
# Colorado School Of Mines: Affiliation IDs: ['167576493.0']
# Columbia University: Affiliation IDs: ['78577930.0']
# Cornell University: Affiliation IDs: ['205783295.0']
# Dartmouth College: Affiliation IDs: ['107672454.0']
# Drexel University: Affiliation IDs: ['72816309.0']
# Duke University: Affiliation IDs: ['170897317.0']
# Duquesne University: Affiliation IDs: ['165102784.0']
# Eastern Michigan University: Affiliation IDs: ['138216421.0']
# Emory University: Affiliation IDs: ['150468666.0']
# Florida Institute Of Technology: Affiliation IDs: ['106959904.0']
# Fordham University: Affiliation IDs: ['164389053.0']
# George Mason University: Affiliation IDs: ['162714631.0']
# George Washington University: Affiliation IDs: ['193531525.0']
# Georgetown University: Affiliation IDs: ['184565670.0']
# Harvard University: Affiliation IDs: ['136199984.0']
# Hofstra University: Affiliation IDs: ['139290212.0']
# Howard University: Affiliation IDs: ['137853757.0']
# Illinois Institute Of Technology: Affiliation IDs: ['180949307.0']
# Illinois State University: Affiliation IDs: ['47301684.0']
# Indiana State University: Affiliation IDs: ['86420138.0']
# James Madison University: Affiliation IDs: ['11883440.0']
# Johns Hopkins University: Affiliation IDs: ['145311948.0']
# Lehigh University: Affiliation IDs: ['186143895.0']
# Loma Linda University: Affiliation IDs: ['26347476.0']
# Long Island University: Affiliation IDs: ['138873065.0']
# Louisiana State University System: Affiliation IDs: ['107341208.0']
# Loyola Marymount University: Affiliation IDs: ['35566140.0']
# Loyola University Chicago: Affiliation IDs: ['1925986.0']
# Marquette University: Affiliation IDs: ['102461120.0']
# Marshall University: Affiliation IDs: ['88694374.0']
# Massachusetts Institute Of Technology: Affiliation IDs: ['63966007.0']
# Mercer University: Affiliation IDs: ['150149174.0']
# Michigan State University: Affiliation IDs: ['87216513.0']
# Michigan Technological University: Affiliation IDs: ['11957088.0']
# Montclair State University: Affiliation IDs: ['166088655.0']
# New Jersey Institute Of Technology: Affiliation IDs: ['118118575.0']
# New School: Affiliation IDs: ['102179633.0']
# New York University: Affiliation IDs: ['57206974.0']
# North Dakota University System: Affiliation IDs: ['4210127926.0']
# Northern Illinois University: Affiliation IDs: ['102502594.0']
# Nova Southeastern University: Affiliation IDs: ['203088144.0']
# Oakland University: Affiliation IDs: ['177721651.0']
# Old Dominion University: Affiliation IDs: ['81365321.0']
# Pace University: Affiliation IDs: ['126863827.0']
# Pennsylvania State System Of Higher Education: Affiliation IDs: ['29957033.0']
# Pennsylvania State University: Affiliation IDs: ['130769515.0']
# Princeton University: Affiliation IDs: ['20089843.0']
# Purdue University: Affiliation IDs: ['219193219.0']
# Rensselaer Polytechnic Institute: Affiliation IDs: ['165799507.0']
# Rice University: Affiliation IDs: ['74775410.0']
# Rochester Institute Of Technology: Affiliation IDs: ['155173764.0']
# Rowan University: Affiliation IDs: ['44265643.0']
# Rutgers State University Of New Jersey: Affiliation IDs: ['102322142.0']
# Seton Hall University: Affiliation IDs: ['12524447.0']
# Southern Illinois University System: Affiliation IDs: ['2801502357.0']
# St Johns University: Affiliation IDs: ['142823887.0']
# Stanford University: Affiliation IDs: ['97018004.0']
# State University Of New York System: Affiliation IDs: ['1327163397.0']
# Syracuse University: Affiliation IDs: ['70983195.0']
# Temple University: Affiliation IDs: ['84392919.0']
# Texas Christian University: Affiliation IDs: ['128956969.0']
# Texas Womans University: Affiliation IDs: ['150913223.0']
# Tufts University: Affiliation IDs: ['121934306.0']
# University Of Alaska System: Affiliation IDs: ['2802090665.0']
# University Of Arkansas System: Affiliation IDs: ['2799691083.0']
# University Of California System: Affiliation IDs: ['2803209242.0']
# University Of Chicago: Affiliation IDs: ['40347166.0']
# University Of Colorado System: Affiliation IDs: ['2802236040.0']
# University Of Connecticut: Affiliation IDs: ['140172145.0']
# University Of Dayton: Affiliation IDs: ['127591826.0']
# University Of Delaware: Affiliation IDs: ['86501945.0']
# University Of Hartford: Affiliation IDs: ['162281398.0']
# University Of Hawaii System: Affiliation IDs: ['1331384533.0']
# University Of Kentucky: Affiliation IDs: ['143302722.0']
# University Of La Verne: Affiliation IDs: ['708430.0']
# University Of Louisville: Affiliation IDs: ['142740786.0']
# University Of Maine System: Affiliation IDs: ['2802397601.0']
# University Of Michigan: Affiliation IDs: ['27837315.0']
# University Of Nebraska System: Affiliation IDs: ['2802450327.0']
# University Of New Mexico: Affiliation IDs: ['169521973.0']
# University Of North Carolina System: Affiliation IDs: ['4210158053.0']
# University Of Northern Colorado: Affiliation IDs: ['71966907.0']
# University Of Notre Dame: Affiliation IDs: ['107639228.0']
# University Of Pacific: Affiliation IDs: ['119942576.0']
# University Of Pittsburgh: Affiliation IDs: ['170201317.0']
# University Of Rhode Island: Affiliation IDs: ['17626003.0']
# University Of San Diego: Affiliation IDs: ['160856358.0']
# University Of South Alabama: Affiliation IDs: ['83809506.0']
# University Of South Carolina: Affiliation IDs: ['155781252.0']
# University Of Southern California: Affiliation IDs: ['1174212.0']
# University Of St Thomas Minnesota: Affiliation IDs: ['161515732.0']
# University Of Tennessee System: Affiliation IDs: ['2799495847.0']
# University Of Texas System: Affiliation IDs: ['16452829.0']
# University Of Tulsa: Affiliation IDs: ['87208437.0']
# University Of Vermont: Affiliation IDs: ['111236770.0']
# University Of Virginia: Affiliation IDs: ['51556381.0']
# University Of Washington: Affiliation IDs: ['201448701.0']
# University Of Wisconsin System: Affiliation IDs: ['1304256225.0']
# University Of Wyoming: Affiliation IDs: ['12834331.0']
# University System Of Georgia: Affiliation IDs: ['1289702989.0']
# University System Of New Hampshire: Affiliation IDs: ['2800453862.0']
# University of Alabama System: Affiliation IDs: ['17301866.0', '2800507078.0']
# University of Minnesota System: Affiliation IDs: ['130238516.0', '2800403580.0']
# Vanderbilt University: Affiliation IDs: ['200719446.0']
# Villanova University: Affiliation IDs: ['7863295.0']
# Virginia Commonwealth University: Affiliation IDs: ['184840846.0']
# Virginia Polytechnic Institute And State University: Affiliation IDs: ['859038795.0']
# Wake Forest University: Affiliation IDs: ['47251452.0']
# Washington State University: Affiliation IDs: ['72951846.0']
# Washington University: Affiliation IDs: ['204465549.0']
# West Virginia University: Affiliation IDs: ['12097938.0']
# Western Michigan University: Affiliation IDs: ['141649380.0']
# Widener University: Affiliation IDs: ['138659443.0']
# Worcester Polytechnic Institute: Affiliation IDs: ['107077323.0']
# Yale University: Affiliation IDs: ['32971472.0']
# Yeshiva University: Affiliation IDs: ['19772626.0']
#
# Institutions that appear in only certain years:
# Boise State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['106969075.0', '120156002.0', '155093810.0']
# Bowling Green State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['157417397.0']
# Brigham Young University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['100005738.0']
# California Institute Of Technology: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011']; Affiliation IDs: ['122411786.0']
# City University Of New York: appears in years ['1999', '2000', '2005', '2007', '2008', '2011', '2013', '2018']; Affiliation IDs: ['174216632.0']
# Cleveland State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['102607778.0']
# Creighton University: appears in years ['1999', '2000', '2005', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['114493937.0']
# Depaul University: appears in years ['1999', '2008', '2009', '2011', '2013']; Affiliation IDs: ['118353179.0']
# Gallaudet University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011']; Affiliation IDs: ['66108857.0']
# Hampton University: appears in years ['1999', '2000']; Affiliation IDs: ['151328261.0']
# Indiana University Of Pennsylvania: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['200885203.0']
# Iowa Board of Regents: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['126307644.0', '173911158.0']
# Kansas Board of Regents: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['39587148.0']
# Kent State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['149910238.0']
# Miami University: appears in years ['1999', '2000', '2007', '2008', '2009']; Affiliation IDs: ['83328450.0']
# Mississippi Institutions of Higher Learning: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011', '2013']; Affiliation IDs: ['44854399.0', '99041443.0']
# New Mexico State University: appears in years ['1999', '2000', '2005', '2007', '2009', '2011', '2018']; Affiliation IDs: ['10052268.0']
# North Carolina Agricultural And Technical State University: appears in years ['1999', '2000']; Affiliation IDs: ['35777872.0']
# North Carolina State University: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['137902535.0']
# Ohio State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['52357470.0']
# Ohio University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['4210106879.0']
# Oklahoma State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['115475287.0']
# Pepperdine University: appears in years ['1999', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['100191712.0']
# South Dakota University System: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['177156846.0', '189957204.0']
# State University Of New York At Stony Brook: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['59553526.0']
# Tennessee Board of Regents: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['169615421.0', '63920570.0', '94658018.0']
# Texas Tech University: appears in years ['1999', '2000']; Affiliation IDs: ['12315562.0']
# Thomas Jefferson University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011']; Affiliation IDs: ['149251103.0']
# Union Institute & University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011']; Affiliation IDs: ['204669301.0']
# University At Albany Suny: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['392282.0']
# University At Buffalo State University Of New York: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['63190737.0']
# University Of Akron: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['110152177.0']
# University Of Cincinnati: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['63135867.0']
# University Of Denver: appears in years ['1999', '2000', '2013', '2018']; Affiliation IDs: ['131651094.0']
# University Of Houston System: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011', '2013']; Affiliation IDs: ['2801525821.0']
# University Of Illinois At Urbana Champaign: appears in years ['1999']; Affiliation IDs: ['157725225.0']
# University Of Massachusetts Worcester: appears in years ['1999']; Affiliation IDs: ['166722992.0']
# University Of Miami: appears in years ['1999', '2000', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['145608581.0']
# University Of Missouri St Louis: appears in years ['1999']; Affiliation IDs: ['208333798.0']
# University Of Montana Missoula: appears in years ['1999']; Affiliation IDs: ['6750721.0']
# University Of Nevada Reno: appears in years ['1999', '2005']; Affiliation IDs: ['134113660.0']
# University Of North Carolina At Charlotte: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['102149020.0']
# University Of North Carolina At Greensboro: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['169335092.0']
# University Of North Carolina At Wilmington: appears in years ['1999', '2000', '2005', '2007', '2008']; Affiliation IDs: ['153901656.0']
# University Of North Texas: appears in years ['1999', '2000']; Affiliation IDs: ['123534392.0']
# University Of Oklahoma: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['8692664.0']
# University Of Oregon: appears in years ['1999']; Affiliation IDs: ['181233156.0']
# University Of Rochester: appears in years ['1999', '2013', '2018']; Affiliation IDs: ['5388228.0']
# University Of Texas At Brownsville/Texas Southmost College: appears in years ['1999', '2000', '2005', '2007', '2009']; Affiliation IDs: ['2802326326.0']
# University Of Toledo: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['90871651.0']
# Utah University System: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['121980950.0', '223532165.0']
# Wayne State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009', '2011', '2018']; Affiliation IDs: ['185443292.0']
# West Chester University Of Pennsylvania: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['161171246.0']
# Wright State University: appears in years ['1999', '2000', '2005', '2007', '2008', '2009']; Affiliation IDs: ['19648265.0']
# Colorado State University System: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['4210131357.0']
# East Carolina University: appears in years ['2000', '2005', '2007', '2008']; Affiliation IDs: ['186335123.0']
# Nevada System Of Higher Education: appears in years ['2000', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['68260882.0']
# Rockefeller University: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['83399316.0']
# Saint Louis University: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['47838141.0']
# Southern Methodist University: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['178169726.0']
# State University Of New York At Binghamton: appears in years ['2000', '2007', '2008']; Affiliation IDs: ['123946342.0']
# Stevens Institute Of Technology: appears in years ['2000', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['108468826.0']
# University Of Illinois System: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['2801919071.0']
# University Of Massachusetts System: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['2802841742.0']
# University Of Missouri System: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['4777552.0']
# University Of Pennsylvania: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['79576946.0']
# University Of San Francisco: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['76766440.0']
# University Of Texas At Austin: appears in years ['2000']; Affiliation IDs: ['86519309.0']
# University System Of Maryland: appears in years ['2000', '2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['1317227900.0']
# Florida Agricultural And Mechanical University: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['8248082.0']
# Florida Atlantic University: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['63772739.0']
# Florida International University: appears in years ['2005', '2008', '2009']; Affiliation IDs: ['19700959.0']
# Florida State University: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['103163165.0']
# Mississippi Institutions Of Higher Learning: appears in years ['2005', '2007', '2008', '2011', '2013', '2018']; Affiliation IDs: ['4210141039.0']
# Montana State University Bozeman: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['23732399.0']
# Oregon Health & Science University: appears in years ['2005', '2007', '2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['165690674.0']
# University Of Central Florida: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['106165777.0']
# University Of Florida: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['33213144.0']
# University Of North Florida: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['11874761.0']
# University Of South Florida: appears in years ['2005', '2007', '2008', '2009']; Affiliation IDs: ['2613432.0']
# University Of California Los Angeles: appears in years ['2007']; Affiliation IDs: ['161318765.0']
# Baylor College Of Medicine: appears in years ['2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['181547552.0']
# Northeastern University: appears in years ['2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['12912129.0']
# Northwestern University: appears in years ['2008', '2009', '2011', '2013', '2018']; Affiliation IDs: ['111979921.0']
# University Of California Berkeley: appears in years ['2008']; Affiliation IDs: ['95457486.0']
# North Dakota State University: appears in years ['2009', '2011', '2013']; Affiliation IDs: ['57328836.0']
# Texas State University San Marcos: appears in years ['2009']; Affiliation IDs: ['13511017.0']
# Kansas Board Of Regents: appears in years ['2011', '2018']; Affiliation IDs: ['2801365651.0']
# Minnesota State Colleges And Universities System: appears in years ['2011', '2018']; Affiliation IDs: ['91221267.0']
# University System Of Ohio: appears in years ['2011', '2013', '2018']; Affiliation IDs: ['2802096936.0']
# Utah System Of Higher Education: appears in years ['2011', '2013', '2018']; Affiliation IDs: ['2801365484.0']
# University Of Houston: appears in years ['2018']; Affiliation IDs: ['44461941.0']
# University Of Missouri Columbia: appears in years ['2018']; Affiliation IDs: ['76835614.0']
# Year 1999: kept only institutions that report every year.
# Year 2000: kept only institutions that report every year.
# Year 2005: kept only institutions that report every year.
# Year 2007: kept only institutions that report every year.
# Year 2008: kept only institutions that report every year.
# Year 2009: kept only institutions that report every year.
# Year 2011: kept only institutions that report every year.
# Year 2013: kept only institutions that report every year.
# Year 2018: kept only institutions that report every year.

# %%
substrings_to_remove = [
    "Rev.", "SJ", "Sister", "Brother", "Father", "OP", "The Very",
    "Sr.", "O.P.", "Very Rev.", "Br.", "Dr.", "Md.", "S.J.", "Very Rev",
    "M.D.", "O.P", "S.J", "J.R", "Jr.", "Jr ", "III"
]

def clean_name(raw_name: str) -> str:
    """
    Clean and canonicalize a board member's name by:
      - Removing specified title substrings (case-insensitive)
      - Removing punctuation and extra whitespace
      - Converting to title case.
    """
    for title in substrings_to_remove:
        title_clean = title.strip()
        raw_name = re.sub(r'\b' + re.escape(title_clean) + r'\b', '', raw_name, flags=re.IGNORECASE)
    raw_name = re.sub(r'[^\w\s]', '', raw_name)
    cleaned_name = " ".join(raw_name.split())
    return cleaned_name.title()

# For each year, open the normalized board file as you normally do.
for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    print(f"Processing interlocks for year: {year}")
    
    # Initialize a dictionary to track which institutions each board member serves on.
    # (The keys are cleaned board member names and the values are sets of institution names.)
    board_member_dict = defaultdict(set)
    
    # Initialize a dictionary for accumulating interlock edges.
    # Keys: tuple(sorted([inst1, inst2]))
    # Values: a dictionary with edge attributes.
    edge_accum = {}
    
    # Initialize a dictionary for node (institution) attributes.
    # Each institution will record its total interlock count and its AffiliationId.
    year_nodes_dict = defaultdict(lambda: {'Interlock_Count': 0, 'AffiliationId': None})
    
    # Process each row in the board DataFrame.
    for _, row in board_df.iterrows():
        name_raw = row["Name"]
        # Skip if the board member is marked as "vacant".
        if "vacant" in str(name_raw).lower():
            continue
        
        # Clean the board member's name.
        name = clean_name(name_raw)
        institution = row["Institution"]
        affiliation_id = row["AffiliationId"]
        
        # For each institution this board member has already been recorded on,
        # record an interlock between that institution and the current one.
        for prev_institution in board_member_dict[name]:
            if prev_institution == institution:
                continue
            pair = tuple(sorted([prev_institution, institution]))
            # Increase the weight (shared board member count) by 1.
            if pair in edge_accum:
                edge_accum[pair]['Weight'] += 1
            else:
                edge_id = f"e_{year}_{len(edge_accum)+1}"
                edge_accum[pair] = {
                    'Id': edge_id,
                    'Source': pair[0],
                    'Target': pair[1],
                    'Type': 'Undirected',
                    'Weight': 1,
                    'Year': year
                }
            # Update the interlock count for both institutions.
            year_nodes_dict[prev_institution]['Interlock_Count'] += 1
            year_nodes_dict[institution]['Interlock_Count'] += 1
        
        # Add the current institution to this board member's record.
        board_member_dict[name].add(institution)
        
        # If we haven't yet recorded an AffiliationId for this institution, do so.
        if year_nodes_dict[institution]['AffiliationId'] is None and pd.notnull(affiliation_id):
            year_nodes_dict[institution]['AffiliationId'] = affiliation_id
    
    # ---------------------------
    # Create Nodes and Edges DataFrames
    # ---------------------------
    nodes_data = []
    for inst, data in year_nodes_dict.items():
        nodes_data.append({
            'Id': inst,
            'Label': inst,
            'Interlock_Count': data['Interlock_Count'],
            'AffiliationId': data['AffiliationId']
        })
    nodes_df = pd.DataFrame(nodes_data)
    
    if edge_accum:
        edges_df = pd.DataFrame(list(edge_accum.values()))
        # Reorder columns if desired.
        edges_df = edges_df[['Id', 'Source', 'Target', 'Type', 'Weight', 'Year']]
    else:
        edges_df = pd.DataFrame(columns=['Id', 'Source', 'Target', 'Type', 'Weight', 'Year'])
    
    # ---------------------------
    # Write the Nodes and Edges DataFrames to CSV
    # ---------------------------
    out_nodes_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"interlocks\\{year}_interlocks_nodes.csv")
    out_edges_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"interlocks\\{year}_interlocks_edges.csv")
    
    nodes_df.to_csv(out_nodes_path, index=False)
    edges_df.to_csv(out_edges_path, index=False)
    
    print(f"Year {year} interlock nodes saved to: {out_nodes_path}")
    print(f"Year {year} interlock edges saved to: {out_edges_path}")
# Out:
# Processing interlocks for year: 1999
# Year 1999 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\1999_interlocks_nodes.csv
# Year 1999 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\1999_interlocks_edges.csv
# Processing interlocks for year: 2000
# Year 2000 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2000_interlocks_nodes.csv
# Year 2000 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2000_interlocks_edges.csv
# Processing interlocks for year: 2005
# Year 2005 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2005_interlocks_nodes.csv
# Year 2005 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2005_interlocks_edges.csv
# Processing interlocks for year: 2007
# Year 2007 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2007_interlocks_nodes.csv
# Year 2007 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2007_interlocks_edges.csv
# Processing interlocks for year: 2008
# Year 2008 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2008_interlocks_nodes.csv
# Year 2008 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2008_interlocks_edges.csv
# Processing interlocks for year: 2009
# Year 2009 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2009_interlocks_nodes.csv
# Year 2009 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2009_interlocks_edges.csv
# Processing interlocks for year: 2011
# Year 2011 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2011_interlocks_nodes.csv
# Year 2011 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2011_interlocks_edges.csv
# Processing interlocks for year: 2013
# Year 2013 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2013_interlocks_nodes.csv
# Year 2013 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2013_interlocks_edges.csv
# Processing interlocks for year: 2018
# Year 2018 interlock nodes saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2018_interlocks_nodes.csv
# Year 2018 interlock edges saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\interlocks\2018_interlocks_edges.csv

# %%
name_counts = defaultdict(int)

for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    
    for name in board_df["Name"].dropna():
        name_str = str(name).strip()
        name_counts[name_str] += 1

all_names = list(name_counts.keys())
sorted_names = sorted(all_names, key=lambda n: name_counts[n], reverse=True)


name_mapping = {}  # original name -> canonical name
used = set()       # names already assigned to a cluster
fuzzy_threshold = 90

for name in sorted_names:
    if name in used:
        continue
    #For the current name, find all similar names from the master list that haven't been assigned yet.
    similar_names = []
    for candidate in all_names:
        if candidate in used:
            continue
        score = fuzz.token_set_ratio(name, candidate)
        if score >= fuzzy_threshold:
            similar_names.append(candidate)
    #Choose the canonical name as the candidate with the highest frequency.
    canonical = max(similar_names, key=lambda n: name_counts[n])
    for candidate in similar_names:
        name_mapping[candidate] = canonical
        used.add(candidate)


print("Name mapping (only changes shown):")
for orig, canon in name_mapping.items():
    if orig != canon:
        print(f"  {orig} -> {canon}")


for year in years:
    file_path = os.path.join(absolute_path, final_scripts, normalized_dataframes, f"{year}_boards_normalized.csv")
    board_df = pd.read_csv(file_path)
    board_df = remove_non_samples(board_df)
    
    # Update the "Name" column: if a name (converted to string and stripped) is in the mapping, use the canonical name.
    board_df["Name"] = board_df["Name"].apply(lambda x: name_mapping.get(str(x).strip(), x) if pd.notnull(x) else x)
    
    # Write the updated DataFrame back to CSV (overwriting the original file)
    board_df.to_csv(file_path, index=False)
    print(f"Updated board dataframe for year {year} with standardized names written to {file_path}")
# Out:
# Name mapping (only changes shown):
#   Rev. Edward A. Malloy, C.S.C -> Rev. Edward A. Malloy, CSC
#   Rev. Edward A. Malloy, CSC. -> Rev. Edward A. Malloy, CSC
#   David Mark Rubenstein -> David M. Rubenstein
#   Linda Sanford -> Linda S. Sanford
#   Linda S. Sanford.* -> Linda S. Sanford
#   Robert R. Riley -> Robert R. "Bob" Riley
#   Robert B. Millard. -> Robert B. Millard
#   The Hon. Edward G. Rendell -> Edward G. Rendell
#   Edward G. "Ed" Rendell -> Edward G. Rendell
#   Monica Lozano -> Monica C. Lozano
#   Elridge W. McMillanl -> Elridge W. McMillan
#   Peter C. Meinig. -> Peter C. Meinig
#   Kenneth K. Calkins -> Kenneth L. Calkins
#   Ann Quay -> Ann Quay Davis
#   David Joel Steinberg -> David J. Steinberg
#   Dr. David J. Steinberg -> David J. Steinberg
#   Nancy B. Peretsmang -> Nancy B. Peretsman
#   Joseph L. "Joe" Neubauer -> Joseph Neubauer
#   Dr. Walter Harrison -> Walter Harrison
#   Francie Frederick -> Francie A. Frederick
#   Francie A. Frederick* -> Francie A. Frederick
#   Barton Joel Winokur -> Barton J. Winokur
#   William S. Dietrich -> William S. Dietrich II
#   William S. Dietrich II. -> William S. Dietrich II
#   John J. Fauth -> John J. Fauth IV
#   John J. 'Hap' Fauth IV -> John J. Fauth IV
#   John J. "Hap" Fauth IV -> John J. Fauth IV
#   Michael Steinhardt -> Michael H. Steinhardt
#   Ray Ferrero, Jr. -> Ray Ferrero, Jr
#   The Hon. Cynthia A. Baldwin -> Cynthia A. Baldwin
#   The Honorable Cynthia A. Baldwin -> Cynthia A. Baldwin
#   James A. Stern. -> James A. Stern
#   Myra L. Wheeler -> Myrna L. Wheeler
#   James S. Broadhurst. -> James S. Broadhurst
#   Malcolm Lee Sherman -> Malcolm L. Sherman
#   Malcolm L. Sherman. -> Malcolm L. Sherman
#   Joanne Leedom-Ackerma -> Joanne Leedom-Ackerman
#   Lawrence L. Landr -> Lawrence L. Landry
#   Patricia Harron Imbesi -> Patricia Imbesi
#   Patricia H. Imbesi -> Patricia Imbesi
#   Lindsey Davis -> G. Lindsey Davis
#   Bishop G. Lindsey Davis -> G. Lindsey Davis
#   William R. "Bill" Brody -> William R. Brody
#   Malcolm A. Smith -> Malcolm B. Smith
#   John O. "Dubby" Wynne -> John O. Wynne
#   Elizabeth Moore -> Elizabeth D. Moore
#   Elizabeth D. Moore. -> Elizabeth D. Moore
#   Steven N. Reenders -> Steven N. Renders
#   Diane Lewis -> Diana Lewis
#   Juanita P. Baranco -> Juanita Powell Baranco
#   Stephen R. Reinel -> Stephen R. Reiner
#   Alan Leventhal -> Alan M. Leventhal
#   Martin Granoff -> Martin J. Granoff
#   Tra J. Gumberg -> Ira J. Gumberg
#   John T. Lynch -> John H. Lynch
#   John P. Lynch -> John H. Lynch
#   John H. Lvnch -> John H. Lynch
#   Robert Lemon -> Robert E. Lemon
#   Robert B. Shapiro -> Robert Shapiro
#   Robert N. Shapiro -> Robert Shapiro
#   Bruce S. Raynor. -> Bruce S. Raynor
#   Renee J. Amoore -> Renee Amoore
#   Alan Smith -> F. Alan Smith
#   Winston J. Churchil -> Winston J. Churchill
#   Winston J. "Win" Churchill -> Winston J. Churchill
#   Donna M. Mendes Janis M. Meyer -> Janis M. Meyer
#   Robert F. "Robbo" Hatcher -> Robert F. Hatcher
#   Robert F. "Bob" Hatcher -> Robert F. Hatcher
#   Joel I. Ferguson -> Joel Ferguson
#   Henry H. Arhold -> Henry H. Arnhold
#   William E. Havemever -> William E. Havemeyer
#   Kenneth G. "Ken" Langone -> Kenneth G. Langone
#   Nancv S. Mueller -> Nancy S. Mueller
#   David M. Hirsch. -> David M. Hirsch
#   Kent Anderson -> D. Kent Anderson
#   Daniel H. Polett. -> Daniel H. Polett
#   Anthony .J Scirica -> Anthony J. Scirica
#   Robert F. Wright -> Robert J. Wright
#   Paula Wolft -> Paula Wolff
#   Emmett L. Terrellst -> Emmett L. Terrell
#   Andrea Fischer Newman.' -> Andrea Fischer Newman
#   John W. "Jay" Jordan II -> John W. Jordan II
#   Dr. Nancy M. Haegel -> Nancy M. Haegel
#   Steven Spielberg1 -> Steven Spielberg
#   Edward S. Nelson -> Edward G. Nelson
#   John A. Rich -> John W. Rich
#   W. Louis Bissette, Jr. -> W. Louis Bissette, Jr
#   Andrew C. Taylor. -> Andrew C. Taylor
#   Ronald L. Thompson. -> Ronald L. Thompson
#   Craig D. Schnuck. -> Craig D. Schnuck
#   Stephen h. Brauer -> Stephen F. Brauer
#   Robert A. Knox. -> Robert A. Knox
#   E. John Rosenwald, Jr -> E. John Rosenwald, Jr.
#   The Hon. Christine Todd Whitman -> Christine B. Whitman
#   Rev. E. William Beauchamp, C.S.CExecutive Vice President and -> Rev. E. William Beauchamp, CSC
#   Rev. John I. Jenkins, C.S.C -> Rev. John I. Jenkins, CSC
#   Eric Krasnoft -> Eric Krasnoff
#   Steven J. Kumble. -> Steven J. Kumble
#   Howard M. Lorber. -> Howard M. Lorber
#   Cherryl T. Thomas. -> Cherryl T. Thomas
#   Dr. John Edward Sexton -> John Edward Sexton
#   Luis F. Faura -> Luis Faura
#   Richard W. Lewis -> Richard A. Lewis
#   Harry J. Flynn -> The Most Reverend Harry J. Flynn
#   Dr. James Thomas Harris IlI -> James Thomas Harris III
#   Robert R. "Bob" Martin -> Robert R. Martin
#   Dr. Robert Martin -> Robert R. Martin
#   Kennith O. Thompson -> Kennith Thompson
#   William H. "Bill" Bauer -> William Bauer
#   Patrick T. "Pat" Stokes -> Patrick T. Stokes
#   Kenneth J. "Ken" Feld -> Kenneth J. Feld
#   Ronald ARatner -> Ronald A. Ratner
#   Phillip H. Case W -> Phillip H. Case
#   Dr. Delores P. Aldridge -> Delores P. Aldridge
#   John G. Johnson, Jr -> John B. Johnson, Jr.
#   John B. Johnson, Jr -> John B. Johnson, Jr.
#   Charles P. "Charlie" Pizzi -> Charles P. Pizzi
#   M. Douglas "Doug" Ivester -> M. Douglas Ivester
#   Bobert G. Perry -> Robert G. Perry
#   Walter D. Pinkard, Jr. -> Walter D. Pinkard, Jr
#   Dr. Charles Marstiller Vest -> Charles Marstiller Vest
#   H_ Dale Hemmerdinger -> H. Dale Hemmerdinger
#   Roval F. Jonas -> Royal F. Jonas
#   H. Jesse Arnelle. -> H. Jesse Arnelle
#   Nicholas M. "Nick" Donofrio -> Nicholas M. Donofrio
#   Mrs. Lawrence J. Matteson -> Lawrence J. Matteson
#   Nancy L. FeinBlase Thomas "Tom" Golisano -> B. Thomas Golisano
#   Lawrence E. Bathgate II. -> Lawrence E. Bathgate II
#   Roy C. Snodgrass IlI -> Roy C. Snodgrass III
#   Billv Joe Miles' -> Billy Joe Miles
#   Robert A. Hoehn -> Robert Hoehn
#   Darlene V. Shiley -> Darlene Marcos Shiley
#   Jerry W. Neelv -> Jerry W. Neely
#   John F. O'Shaughnessy, Jr. -> John F. O'Shaughnessy, Jr
#   David R. "Dave" Lawson -> David R. Lawson
#   Donald M. "Don" Leebern, Jr -> Donald M. Leebern, Jr
#   John J. McMahon, Jr. -> John J. McMahon, Jr
#   John H. England, Jr. -> John H. England, Jr
#   Brownlee O. Currey, Jr. -> Brownlee O. Currey, Jr
#   Michael Lewis Ainslie -> Michael L. Ainslie
#   Eugene H. Vaughan, Jr. -> Eugene H. Vaughan, Jr
#   Ann Rubenstein Tischooo -> Ann Rubenstein Tisch
#   Ann Rubenstein Tisch. -> Ann Rubenstein Tisch
#   Dr. Richard Charles Levin -> Richard Charles Levin
#   Jeffrey Hayden Lynford -> Jeffrey H. Lynford
#   Susan R. Holliday. -> Susan R. Holliday
#   Rev. Donald J. Harrington, C.M -> Rev. Donald J. Harrington, CM
#   Rev. Donald J. Harrington -> Rev. Donald J. Harrington, CM
#   Clarence Scharbauer I -> Clarence Scharbauer III
#   Clarence Scharbauer IlI -> Clarence Scharbauer III
#   Patricia Penrose Schieffel -> Patricia Penrose Schieffer
#   Karen Katen -> Karen L. Katen
#   Tonev J. Lister -> Toney J. Lister
#   Richard M. Schulze. -> Richard M. Schulze
#   Rebecca Webb Wilson -> Rebecca W. Wilson
#   Dr. Robert Allyn Scott -> Robert Allyn Scott
#   Keith G. Fleer Thomas Gottschalk -> Thomas A. Gottschalk
#   Thomas Gottschalk -> Thomas A. Gottschalk
#   Nicholas A. Sannella -> Rev. Nicholas A. Sannella
#   Margaret Mary Fitzpatrick, SC -> Sister Margaret Mary Fitzpatrick, SC
#   Sister Margaret Mary Fitzpatrick -> Sister Margaret Mary Fitzpatrick, SC
#   David K. Wilson -> David W. Wilson
#   David Wilson -> David W. Wilson
#   Carl Ware -> Carl H. Ware
#   Robert J. Stevenish II -> Robert J. Stevenish
#   Robert J. Stevenish Il -> Robert J. Stevenish
#   Dr. Anthony G. Collins -> Anthony G. Collins
#   Dr. Anthony G. "Tony" Collins -> Anthony G. Collins
#   Mary Henderson -> Mary R. "Nina" Henderson
#   Richard A. Greenawall -> Richard A. Greenawalt
#   Richard A. Greenawal -> Richard A. Greenawalt
#   Dr. Richard H. Brodhead -> Richard H. Brodhead
#   Dr. Charles J. Dougherty -> Charles J. Dougherty
#   Dr. Anthony James Catanese -> Anthony James Catanese
#   Dr. John J. DeGioia -> John J. DeGioia
#   Mark A. Bovar -> Mark A. Boyar
#   Edward Travagliantin -> Edward Travaglianti
#   John Seazholtz -> John W. Seazholtz
#   George M. Newcome -> George M. Newcombe
#   Robert Hillier -> J. Robert Hillier
#   Laurence D. "Larry" Fink -> Laurence D. Fink
#   Barry J. Silverman, MD -> Barry J. Silverman
#   Paul Severino -> Paul J. Severino
#   John M. Hennessy -> John L. Hennessy
#   Dr. John L. Hennessy -> John L. Hennessy
#   King Harris -> King W. Harris
#   The Hon. Ann Claire Williams -> Ann Claire Williams
#   Ann Williams -> Ann Claire Williams
#   Dr. Mary E. Lyons -> Mary E. Lyons
#   Steven A. Markel -> Mark A. Stevens
#   Ross Swimmer -> Ross Owen Swimmer
#   Steven H. "Steve" Lipstein -> Steven H. Lipstein
#   Dr. Dennis D. Berkey -> Dennis D. Berkey
#   Rev. Bradley M. Schaeffer, S.J. -> Rev. Bradley M. Schaeffer, S.J
#   Rev. Bradley M. Schaefer, S.J -> Rev. Bradley M. Schaeffer, S.J
#   Rev. Bradley M. Schaefer, S.J. -> Rev. Bradley M. Schaeffer, S.J
#   Rev. Bradley M. Schaeffer, S.J, -> Rev. Bradley M. Schaeffer, S.J
#   Robert K. Durkee* -> Robert K. Durkee
#   John J. Myers -> The Most Reverend John J. Myers
#   The Most Reverend John J. Meyers -> The Most Reverend John J. Myers
#   Daniel Jackson -> Daniel R. Jackson
#   Steven N. Fischel -> Steven N. Fischer
#   Dr. Ed Richardson -> Ed Richardson
#   Robert E. "Bobby" Lowder -> Robert E. Lowder
#   Dr. Richard F. Syron -> Richard F. Syron
#   Andrea L. Berry -> Terry L. Andreas
#   John G. Rangos, Sr. -> John G. Rangos, Sr
#   Elizabeth A. Fessenden. -> Elizabeth A. Fessenden
#   James T. Wood -> James F. Wood
#   James F. "Jim" Wood -> James F. Wood
#   Bobert A. Paul -> Robert A. Paul
#   Ellen Bailey -> Ellen A. Bailey
#   Ellen A. Bailev -> Ellen A. Bailey
#   Henry L. Bowden, Jr. -> Henry L. Bowden, Jr
#   Patricia M. Nazemetz.cos -> Patricia M. Nazemetz
#   Arthur J. "Jerry" Kremer -> Arthur J. Kremer
#   Dr. Floretta Dukes McKenzie -> Floretta Dukes McKenzie
#   Dr. Charles R. McDonald -> Charles J. McDonald
#   Jay Robert Pritzker -> Robert A. Pritzker
#   Jay Robert "J. B." Pritzker -> Robert A. Pritzker
#   Fidelis N. Umeh. -> Fidelis N. Umeh
#   Fidelis N. Umehsid -> Fidelis N. Umeh
#   Bahman Atefl -> Bahman Atefi
#   Stuart S. Janney I -> Stuart S. Janney III
#   Stuart S. Janney II. -> Stuart S. Janney III
#   Robert John "Bob" Abernethy -> Robert J. Abernethy
#   Donald J. Ulrich -> Ronald J. Ulrich
#   Ronald J. Ulrich. -> Ronald J. Ulrich
#   Paul N. Leitner. -> Paul N. Leitner
#   David A. Koch -> David H. Koch
#   Jackson P. "Jack" Turner -> Jackson P. Turner
#   George Campbell, Jr. -> George Campbell, Jr
#   George Campbell, Jr., Ph.D -> George Campbell, Jr
#   George Campbell, Jr., PhD -> George Campbell, Jr
#   Dr. George Campbell, Jr., PhD -> George Campbell, Jr
#   Carl T. Shaffer. -> Carl T. Shaffer
#   Alvin H. Clemens. -> Alvin H. Clemens
#   Gary J. Lindsay. -> Gary J. Lindsay
#   Janet F. Sansone' -> Janet F. Sansone
#   Janet h. Sansone -> Janet F. Sansone
#   vanet F. Sansone -> Janet F. Sansone
#   A. Zachary Yamba. -> A. Zachary Yamba
#   James S Frank -> James S. Frank
#   James S. "Jim" Frank -> James S. Frank
#   James S. Frankgoo -> James S. Frank
#   Robert A. Fischer, Jr. -> Robert A. Fischer, Jr
#   Marie K. Abram -> Marie K. Abrams
#   James Bradley -> James Bradley Wilson
#   H. Frank Grainger -> Hiram Frank Grainger
#   Philip J. "Phil" Purcell III -> Philip J. Purcell III
#   Cathleen P. "Cathie" Black -> Cathleen P. Black
#   Michael F. Rvan -> Michael F. Ryan
#   Willis B. Wood, Jr. -> Willis B. Wood, Jr
#   Suzanne M. Nora Johnson -> Suzanne Nora Johnson
#   R. Michelle Beale -> Michelle Beale
#   Joanne Fleming Haves -> Joanne Fleming Hayes
#   Camilla Diet Bergeron -> Camilla Dietz Bergeron
#   Eugene B. Shanks, Jr. -> Eugene B. Shanks, Jr
#   Eugene B. Shanks, JrRichard H. Sinkfield -> Eugene B. Shanks, Jr
#   Wayne T. Smith -> K. Wayne Smith
#   Lawrence D. Hopkins, MD -> Lawrence D. Hopkins
#   Harvey Saligman. -> Harvey Saligman
#   Louis G. Hutt, Jr. -> Louis G. Hutt, Jr
#   Judith Witsch -> Judith Nitsch
#   Peter J. Levine -> Peter H. Levine
#   David S. Gottesmar -> David S. Gottesman
#   Hannah Fair Lee -> Hannah Lee
#   Salvador Diaz-Verson, Jr. -> Salvador Diaz-Verson, Jr
#   Frank E. Emory, Jr. -> Frank E. Emory, Jr
#   Gail J. McGover -> Gail J. McGovern
#   James A. "Jim" Bishop -> James A. Bishop
#   Craig C. Matthews -> Craig G. Matthews
#   Edward P. Junker IlI -> Edward P. Junker III
#   Thomas S. "Tom" Richards -> Thomas S. Richards
#   Thomas E. Richards -> Thomas S. Richards
#   Thomas E. "Tom" Richards -> Thomas S. Richards
#   Arold C. Greenberg -> Arnold C. Greenberg
#   Rev. David T. Tyson, C.S.C -> Rev. David T. Tyson, CSC
#   Liam E. McGree -> Liam E. McGee
#   Ann winblad -> Ann Winblad
#   Ann L. Winblad -> Ann Winblad
#   Duane Wilson -> L. Duane Wilson
#   Dr. Thalia Dorwick -> Thalia Dorwick
#   Carl T. Anderson -> Carl A. Anderson
#   Frank B. Schmeler -> Frank R. Schmeler
#   Bishop B. Michael Watson -> B. Michael Watson
#   Bishop B. Michael "Mike" Watson -> B. Michael Watson
#   Edward W. Scott, Jr. -> Edward W. Scott, Jr
#   John D. Miller Marilyn B. Monter -> Marilyn B. Monter
#   Joseph R. Perella. -> Joseph R. Perella
#   Alfred R. Kahn. -> Alfred R. Kahn
#   Edward Shorin -> Edward E. Shorin
#   Barrie B. Zesiger -> Barrie R. Zesiger
#   Preston D. Pinkett Ill -> Preston D. Pinkett III
#   Beth Rudin DeWoodv -> Beth Rudin DeWoody
#   William C. "Bill" Rudin -> William C. Rudin
#   Alan B. Levan as -> Alan B. Levan
#   Louise SSams -> Louise S. Sams
#   Michael E. Herman. -> Michael E. Herman
#   David. Burns -> David J. Burns
#   Brian H. Hall. -> Brian H. Hall
#   Bruce Tomason -> Bruce A. Tomason
#   Rev. Gerard H. Luttenberger -> Rev. Gerard H. Luttenberger, CM
#   Patricia Castel "Pat" Skarulis -> Patricia A. Castel
#   Nancy Cantor -> Nancy Ellen Cantor
#   Lewis F. Gould, Jr. -> Lewis F. Gould, Jr
#   Matthew K. "Matt" Rose -> Matthew K. Rose
#   Lawrence S. "Larry" Bacow -> Lawrence S. Bacow
#   Dr. Lawrence S. Bacow -> Lawrence S. Bacow
#   Mary K. Hughes ho -> Mary K. Hughes
#   John W. Rogers, Jr. -> John W. Rogers, Jr
#   Andrew M. "Andy" Alper -> Andrew M. Alper
#   Thomas A. Coleman -> Thomas A. Cole
#   Dr. Sanford J. Grossman -> Sanford J. Grossman
#   Brother Thomas F. Giardino, SM. -> Brother Thomas F. Giardino, SM
#   Bobbi McNeil.' -> Bobbi McNeil
#   D. Tad Lowry -> D. Tad Lowrey
#   Kent Schroeder -> Kent A. Schroeder
#   Jack Fortner -> Jack L. Fortner
#   Rev. Jose E. Ahumada, C.S.C -> Rev. Jose E. Ahumada, CSC
#   Rev. Jose E. Ahumada, CSC. -> Rev. Jose E. Ahumada, CSC
#   Dianne Philibosian -> Dianne L. Philibosian
#   Steven F. "Steve" Leer -> Steven F. Leer
#   James V. "Jim" Mazzo -> James V. Mazzo
#   Lora Y. Reed -> Lorna Y. Reed
#   Edward P. Roski, Jr. -> Edward P. Roski, Jr
#   Willam E. B. Siart -> William E. B. Siart
#   David H. Dornsife* -> David H. Dornsife
#   Dr. Antoine M. Garibaldi -> Antoine M. Garibaldi
#   Diana E. Murphv -> Diana E. Murphy
#   Barbara B. Allen -> Barbara Allen
#   Katherine G. Covle -> Katherine G. Coyle
#   W. Mansfield Jennings, Jr. -> W. Mansfield Jennings, Jr
#   James W. Wilson II -> James W. Wilson III
#   Frank A. Godchaux -> Frank A. Godchaux III
#   Martha Ingram -> Martha Rivers Ingram
#   Deborah Lambert -> Deborah D. Lambert
#   Arold B. Zetcher -> Arnold B. Zetcher
#   Eugene D. McGurk, Jr. -> Eugene D. McGurk, Jr
#   Dr. Curtis R. Carlson -> Curtis R. Carlson
#   Zygmunt "Zygi" Wilf -> Zygmunt Wilf
#   Hani M.S. Farsi -> Hani M. S. Farsi
#   Don C. Schneider -> Donald C. Schneider
#   Neils-Erik A. Andreasen -> Niels-Erik A. Andreasen
#   Sharon Ryan -> Sharon G. Ryan
#   Charles John Koch -> Charles John "Bud" Koch
#   Alan D. Schwartz -> Alan L. Schwartz
#   Mark Johnson -> Mark Chapin Johnson
#   Sebastian P. Musco -> Sebastian Paul Musco
#   Isaac J. Snype, Jr. -> Isaac J. Snype, Jr
#   Ross J. Gillman -> Ross D. Gillman
#   James B. Williams -> James R. Williams
#   James A. Williams -> James R. Williams
#   James Williams Thomas, Jr -> James R. Williams
#   Dr. David J. Skorton -> David J. Skorton
#   Paul M. Baiada -> Paul M. "Mel" Baiada
#   Michael J. Garanzini, SJ -> Michael J. Garanzini, S.J
#   Michael J. Garanzini, S.J, -> Michael J. Garanzini, S.J
#   Rev. Michael J. Garanzini, S.J. -> Michael J. Garanzini, S.J
#   Rev. Michael J. Garanzini, S.J -> Michael J. Garanzini, S.J
#   Rev. Scott R. Pilarz, SJ -> Rev. Scott R. Pilarz, S.J
#   Rev. Scott R. Pilarz, S.J. -> Rev. Scott R. Pilarz, S.J
#   Melanie Reinhold Foster -> Melanie Foster
#   William T. Allen -> William T. Mullen
#   Bruce Berger -> Bruce D. Berger
#   Mark A. Besca -> Mark M. Besca
#   John F. Davis IlI -> John F. Davis III
#   John W. Davis III -> John F. Davis III
#   William R. O'Reilly, Jr -> William R. O'Reilly, Jr.
#   Brother Francisco T. Gonzalez, SM. -> Brother Francisco T. Gonzalez, SM
#   F. James McCart III -> F. James McCarl III
#   Frank Cruz -> Frank H. Cruz
#   John Morrison -> John M. Morrison
#   Richard F. Tucker -> Richard L. Tucker
#   Finus E. St. John IV -> Finis E. St. John IV
#   Carolyn J. Abeita -> Carolyn Abeita
#   Raymond J. Lane -> Raymond J. "Ray" Lane
#   Carol Keehan, DC -> Sister Carol Keehan, DC
#   Sister Carol Keehan -> Sister Carol Keehan, DC
#   Paul J. Spina, Jr. -> Paul J. Spina, Jr
#   Willie D. Davis -> Will D. Davis
#   Gorden Rombergei -> Gorden Romberger
#   Ronald Rallis, Sr. -> Ronald Rallis, Sr
#   Rosemarie I. "Rosie" Avila -> Rosemarie Avila
#   Susan McManama Gianinno -> Susan M. Gianinno
#   Thomas P. O'Neill III. -> Thomas P. O'Neill III
#   Louis Perimutter -> Louis Perlmutter
#   Debra L Lee -> Debra L. Lee
#   Fredric B. Garonzik. -> Fredric B. Garonzik
#   James G. Taylor -> James W. Taylor
#   David A. Couiter -> David A. Coulter
#   Erroll B. Davis, Jr. -> Erroll B. Davis, Jr
#   Tod S. Johnson. -> Tod S. Johnson
#   John D. Correntia. -> John D. Correnti
#   John J. MacK -> John J. Mack
#   John J. Cook, Jr. -> John J. Cook, Jr
#   Thomas A. "Tom" Reynolds III. -> Thomas A. Reynolds III
#   Thomas A. "Tom" Reynolds III -> Thomas A. Reynolds III
#   Thomas A. "Tom" Reynolds Ill -> Thomas A. Reynolds III
#   Vernon E. Jordan, Jr. -> Vernon E. Jordan, Jr
#   Harold P Freeman -> Harold P. Freeman
#   Robert A. Corog -> Robert A. Cornog
#   Edward L. "Ed" Kaplan -> Edward L. Kaplan
#   William F. Ward, Jr. -> William F. Ward, Jr
#   William F. Ward, JrChristopher Watson -> William F. Ward, Jr
#   William F. Hecht. -> William F. Hecht
#   William F Hecht -> William F. Hecht
#   Rev. Robert A. Wild, SJ -> Rev. Robert A. Wild, S.J
#   G. Marshall Butler, Sr -> G. Marshall Butler
#   William H. Havden -> William H. Hayden
#   Manuel "Manny" Sanchez -> Manuel Sanchez
#   Robert D. Metzgar* -> Robert D. Metzgar
#   Dennis J. Browniee -> Dennis J. Brownlee
#   John D. Hardin, Jr. -> John D. Hardin, Jr
#   Kathleen M. Matteo wal -> Kathleen M. Matteo
#   Thomas A. Renvi -> Thomas A. Renyi
#   Robert A Rovner -> Robert A. Rovner
#   Gerald L. Parks -> Gerald L. Parsky
#   Richard P. Strubel.* -> Richard P. Strubel
#   Rechard A. Abdoo -> Richard A. Abdoo
#   William McIntyre -> William Mcintyre
#   Terrence J. McGinn -> Terrence J. McGlinn
#   Richard C. "Dick" Notebaert -> Richard C. Notebaert
#   William Kane Reilly -> William F. Reilly
#   William J. Shaw. -> William J. Shaw
#   William J. "Bill" Shaw -> William J. Shaw
#   Donald E. Smith -> Donald J. Smith
#   Ronald L. "Ron" Fowler -> Ronald L. Fowler
#   Roy E. "Gene" Bell -> Roy E. Bell
#   Steve Turbo -> Steve Turnbo
#   John Russell -> John Russell Thomas
#   William W. Bain, Jr. -> William W. Bain, Jr
#   J. Lawrence "Larry" Wilson -> J. Lawrence Wilson
#   James Vincent O'Donnell -> James V. O'Donnell
#   James V. "Jim" O'Donnell -> James V. O'Donnell
#   Dr. James J. "Jim" O'Donnell -> James V. O'Donnell
#   Robert J. Morrissey R. Michael Murray, Jr -> Robert J. Morrissey
#   Robert F. Morrissey -> Robert J. Morrissey
#   Rev. William P. Leahy, S.J -> Rev. William P. Leahy, SJ
#   Rev. William P. Leahy, S.J. -> Rev. William P. Leahy, SJ
#   Cecilia Presley -> Cecelia Presley
#   Chilton D. Varner. -> Chilton D. Varner
#   Chilton Davis Varner -> Chilton D. Varner
#   Pamela P. "Pam" Flaherty -> Pamela P. Flaherty
#   Katherine Wilson More -> Katherine Wilson Moret
#   Jose de Jesus Legaspi. -> Jose de Jesus Legaspi
#   Rev. Robert B. Lawton, S.J -> Rev. Robert B. Lawton, SJ
#   Rev. Robert B. Lawton, SEx Officio -> Rev. Robert B. Lawton, SJ
#   Janet C. Rutledge -> Janet Caroline Rutledge
#   Samuel T. Hubbard, Jr. -> Samuel T. Hubbard, Jr
#   Dorothy M. Stanait -> Dorothy M. Stanaitis
#   Kevin Kennedy -> Kevin E. Kennedy
#   Kevin J. Kennedy -> Kevin E. Kennedy
#   Thomas J. Groark, Jr. -> Thomas J. Groark, Jr
#   Larry Rinehart -> Larry M. Rinehart
#   Mack I. Whittle, Jr. -> Mack I. Whittle, Jr
#   Ray Irani -> Ray R. Irani
#   Dr. Ray R. Irani -> Ray R. Irani
#   Leon M. Pollack. -> Leon M. Pollack
#   Joan S. Girgus. -> Joan S. Girgus
#   Jeffrey A. "Jeff" Sine -> Jeffrey A. Sine
#   Garv D. Cohn -> Gary D. Cohn
#   Rodney A. Grove. -> Rodney A. Grove
#   Wayne B. Lowell -> Wayne Lowell
#   Dr. David J. Mitchell -> David Mitchell
#   Dr. Allan G. Kavalich -> Allan Kavalich
#   Stanley "Stan" Jantz -> Stanley Jantz
#   G. Bradley "Brad" Cole -> G. Bradley Cole
#   Thomas P. Glvnn -> Thomas P. Glynn
#   D. Ronald "Ron" Daniel -> D. Ronald Daniel
#   Barry S. Sterlicht -> Barry S. Sternlicht
#   Theodore L. Schroeder. -> Theodore L. Schroeder
#   Theodore LSchroeder -> Theodore L. Schroeder
#   James L. "Jim" Bildner -> James L. Bildner
#   Dr. Gregory L. Eastwood -> Gregory L. Eastwood
#   Very Rev. David M. O'Connell, C.MOfficio -> David M. O'Connell, CM
#   Very Rev. David M. O'Connell, CM -> David M. O'Connell, CM
#   Rev. David M. O'Connell, CM -> David M. O'Connell, CM
#   The Very Reverend David M. O'Connell, CM -> David M. O'Connell, CM
#   The Most Reverend David M. O'Connell, CM -> David M. O'Connell, CM
#   Karen R. Wilkinson1 W -> Karen R. Wilkinson
#   Loretta L. Sanchez -> Loretta Sanchez
#   William E. Shack, Jr. -> William E. Shack, Jr
#   Dr. Alvin Trotter -> Alvin Trotter
#   Dr. Alvin T. Trotter -> Alvin Trotter
#   Dennis M. Dimitri -> Dennis Dimitri
#   Gary Roboff -> Gary S. Roboff
#   Karel K. Czanderna' -> Karel K. Czanderna
#   Dr. Karel K. Czanderna -> Karel K. Czanderna
#   Dr. Austin E. Gore -> Austin Gore
#   Esta E. Stecheras -> Esta E. Stecher
#   Fave Wattleton -> Faye Wattleton
#   Kenneth A. "Ken" Goldman -> Kenneth A. Goldman
#   Thomas P. Salice* -> Thomas P. Salice
#   Sylvester McClearnr -> Sylvester McClearn
#   Dr. Donna M. Carroll -> Donna M. Carroll
#   Linda Diane Rabbit -> Linda Diane Rabbitt
#   Allan From -> I. Allan From
#   Wayman F. Smith I -> Wayman F. Smith III
#   Wayman F. Smith -> Wayman F. Smith III
#   Jesse Norman -> Jessye Norman
#   Mike Alleyow -> Mike Alley
#   Meredith Strom Gunter -> Meredith Strohm Gunter
#   Dr. Rajendra Singh -> Rajendra Singh
#   Tara I. Stacoma -> Tara I. Stacom
#   Dennis E. Singleton -> Dennis E. Singleton III
#   Dennis E. Singleton IlI -> Dennis E. Singleton III
#   Patrick Wong -> Patrick Y. Wong
#   Bonald A. Okum -> Ronald A. Okum
#   Frank J. Hogan III. -> Frank J. Hogan III
#   Ned W. Bechtold -> Ned W. Bechthold
#   Lawrence K. Fish* -> Lawrence K. Fish
#   W. Louis Sands. -> W. Louis Sands
#   Carlos Ortiz -> Carlos G. Ortiz
#   Rose Cali -> Rose C. Cali
#   Norma J. Clavton -> Norma J. Clayton
#   Norma B. Clayton -> Norma J. Clayton
#   J. Robert Kerrev -> J. Robert Kerrey
#   J. Robert "Bob" Kerrey -> J. Robert Kerrey
#   Joshua Sapan -> Joshua W. Sapan
#   Joshua W. "Josh" Sapan -> Joshua W. Sapan
#   Dr. Nancy A. Garvey -> Nancy A. Garvey
#   Anthony "Tony" Welters -> Anthony Welters
#   John L. Schaefer -> John P. Schaefer
#   Dennis K. Pawley -> Dennis Pawley
#   Edward R. Hintz, Jr. -> Edward R. Hintz, Jr
#   Keith W. Eckel. -> Keith W. Eckel
#   Jackson P. "Jack" Tai -> Jackson P. Tai
#   James W. Crownover.* -> James W. Crownover
#   Wolfgang Pfizenmaier. -> Wolfgang Pfizenmaier
#   Sandra A. Parker ****  . -> Sandra A. Parker
#   Sandra A. Parker. -> Sandra A. Parker
#   Joseph M. Lobozzo II. -> Joseph M. Lobozzo II
#   Robert D. Wayland-Smith -> Robert Wayland-Smith
#   Thomas C. Wilmot, Sr. -> Thomas C. Wilmot, Sr
#   Harvey Wachsman -> Harvey F. Wachsman
#   Michael A. Dritz. -> Michael A. Dritz
#   Mitchell .L Morgan -> Mitchell L. Morgan
#   Patrick .J O'Connor.. -> Patrick J. O'Connor
#   Ronald C. "Ron" Parker -> Ronald C. Parker
#   Frederick R. "Fred" Ruiz -> Frederick R. Ruiz
#   Sister Francis Marie Thrailkill, OSU3 -> Sister Francis Marie Thrailkill, OSU
#   Andrew F. Veresr -> Andrew F. Veres
#   John R. Haley. -> John R. Haley
#   Everett Toomey -> Everett C. Toomey
#   Twin G. Burton III -> Irwin G. Burton III
#   Irwin G. Burton IlI -> Irwin G. Burton III
#   R. R. M. Carpenter -> R. R. M. Carpenter III
#   R. R. M. Carpenter I -> R. R. M. Carpenter III
#   A. R. M. Carpenter III -> R. R. M. Carpenter III
#   Donald Frahm -> Donald R. Frahm
#   Gregor G. Peterson -> Gregory G. Petersen
#   Victoria Murphy -> Victoria M. Murphy
#   Victoria M. Murphy PI -> Victoria M. Murphy
#   William L. Johnson -> William D. Johnson
#   William Ben Johnson -> William D. Johnson
#   William P. Johnson II -> William D. Johnson
#   William R. Johnson -> William D. Johnson
#   William D. Johnston -> William D. Johnson
#   William "Bill" Johnson -> William D. Johnson
#   Charles H. Mercer, Jr -> Charles H. Mercer, Jr.
#   J. Christopher "Chris" Reyes -> J. Christopher Reyes
#   Enrique Hernandez, Jr -> Enrique "Rick" Hernandez, Jr.
#   Enrique Hernandez, Jr. -> Enrique "Rick" Hernandez, Jr.
#   Enrique "Rick" Hernandez, Jr -> Enrique "Rick" Hernandez, Jr.
#   Kathleen Lagoria Jansen -> Kathleen Lagorio Janssen
#   Kathleen Lagorio Jansen -> Kathleen Lagorio Janssen
#   George Nicholas Beckwith III -> G. Nicholas Beckwith III
#   R. Donna M. Bavtop -> R. Donna M. Baytop
#   R. Donna M. Baytop. -> R. Donna M. Baytop
#   The Very Reverend Monsignor Lawrence Purcell -> Monsignor Lawrence Purcell
#   Dr. Joseph B. Morton -> Joseph B. Morton
#   Dr. C. Edward Floyd -> C. Edward Floyd
#   Darla Moore -> Darla D. Moore
#   Laurence E. LeJeune -> Laurence LeJeune
#   James Trosoer -> James Trosper
#   Joseph C. Espy II -> Joseph C. Espy III
#   John Frobenius; -> John Frobenius
#   William W. Featheringil -> William W. Featheringill
#   Dr. Carol S. Shapiro -> Carol S. Shapiro
#   Kenneth M. Miller -> Kenneth D. Miller
#   Kenneth V. Miller -> Kenneth D. Miller
#   Harry J. Seigle. -> Harry J. Seigle
#   John D. Weil. -> John D. Weil
#   Maxine Clark -> Maxine K. Clark
#   Dr. Ira Harkavy -> Ira Harkavy
#   Paul S. Beideman. -> Paul S. Beideman
#   Dr. John L. LaMattina -> John L. LaMattina
#   Roland Betts -> Roland W. Betts
#   Barbara J. Randali -> Barbara J. Randall
#   Peter T. Paul. -> Peter T. Paul
#   Robert J. Brown -> Robert A. Brown
#   Virginia Nord Barbato -> Virginia N. Barbato
#   Paul Folino -> Paul F. Folino
#   Peter Klein -> Peter D. Klein
#   Jean E. spence -> Jean E. Spence
#   Kvriakos Tsakopoulos -> Kyriakos Tsakopoulos
#   Andrew H. TIsch -> Andrew H. Tisch
#   David Zalaznick -> David W. Zalaznick
#   Irene Blecker Rosenfeld -> Irene B. Rosenfeld
#   Abbie Dean. -> Abbie Dean
#   Clarence G. "C.G." Newsome -> Clarence G. Newsome
#   Rev. Joseph M. McShane, SJ -> Joseph M. McShane, S.J
#   Rev. Joseph M. McShane, S.J -> Joseph M. McShane, S.J
#   Rev. Joseph Michael McShane, S.J -> Joseph M. McShane, S.J
#   Richard H. Fink -> Richard H. Frank
#   Richard J. Franke -> Richard H. Frank
#   Earl G. Graves, Sr. -> Earl G. Graves, Sr
#   The Hon. L. Douglas Wilder -> L. Douglas Wilder
#   The Honorable L. Douglas Wilder -> L. Douglas Wilder
#   Kasim Reed -> M. Kasim Reed
#   Brad Eric SchelerL -> Brad Eric Scheler
#   Richard P Nespola -> Richard P. Nespola
#   Ronald E. Deal -> Ronald E. Daly
#   Rev. James G. Gartland, S.J. -> Rev. James G. Gartland, S.J
#   Dr. Kirk D. Kolenbrander -> Kirk D. Kolenbrander
#   Marjorie M.T. Yang -> Marjorie M. T. Yang
#   Patrick G. LeFore -> Patrick G. LePore
#   Charles R. Dees, Jr. -> Charles R. Dees, Jr
#   Dr. Charles R. Dees, Jr -> Charles R. Dees, Jr
#   H. Wayne Huizenga* -> H. Wayne Huizenga
#   Thomas W. Barron -> Thomas A. Barron
#   Nancy Fein -> Nancy L. Fein
#   Nick Petroni -> Nick L. Petroni
#   Jonathon Holtz -> Jonathon J. Holtz
#   Peter P. Bermont -> Peter L. Bermont
#   Timothy T. Brady -> Timothy C. Brady
#   Paul Wachter -> Paul D. Wachter
#   Gregory Westin "Greg" Wendt -> Gregory Westin Wendt
#   Richard J. Pfleger -> Richard Pfleger
#   Daryl Ward -> Rev. Daryl Ward
#   Dave Fitzgerald -> David Fitzgerald
#   Paul H. Moseley -> Paul Moseley
#   Dr. Mary Sue Coleman -> Mary Sue Coleman
#   David A. Young -> David W. Young
#   Dr. Thomas G. Burish -> Thomas G. Burish
#   Howard Koff -> Howard M. Koff
#   Marlee S. Myers -> Marlee Myers
#   James A. "Jim" Yance -> James A. Yance
#   Timothy P. Flynn* -> Timothy P. Flynn
#   Arthur H. McElroy -> Arthur H. "Chip" McElroy II
#   Robert E. Lorton -> Robert E. Lorton III
#   Willis J. Potts, Jr. -> Willis J. Potts, Jr
#   Dr. Sara Jayne Steen -> Sara Jayne Steen
#   William G. Wilson -> William M. Wilson
#   James Danella -> James D. Danella
#   Jerald Lynn "Jerry" Kent -> Jerald Lynn Kent
#   Donna Lee Dubinsky -> Donna L. Dubinsky
#   Michael Jesselson -> Michael G. Jesselson
#   Richard Cohen -> Richard D. Cohen
#   Joseph A. Sabatini. -> Joseph A. Sabatini
#   Thomas F. McKee. -> Thomas F. McKee
#   George I. Majoros, Jr. -> George I. Majoros, Jr
#   Brian Rogers -> Brian C. Rogers
#   Brian D. Rogers -> Brian C. Rogers
#   Stephen Friedman -> Stephen J. Friedman
#   John Chapple -> John H. Chapple
#   Mark W. Buyck, Jr. -> Mark W. Buyck, Jr
#   Michele Engemann -> Michele Dedeaux Engemann
#   John M. Connors, Jr. -> John M. Connors, Jr
#   John M "Jack" Connors, Jr -> John M. Connors, Jr
#   Charles I. Clough, Jr. -> Charles I. Clough, Jr
#   Benaree P. Wiley. -> Benaree P. Wiley
#   Benaree P. "Bennie" Wiley -> Benaree P. Wiley
#   Peter H. Vermilve -> Peter H. Vermilye
#   J. Kenneth Menges, Jr -> J. Kenneth Menges, Jr.
#   Marie J. Langlois. -> Marie J. Langlois
#   William P. Snyder II -> William P. Snyder III
#   Jovce Bowie Scott -> Joyce Bowie Scott
#   Vincent A. Sarni * -> Vincent A. Sarni
#   Robert L. Brown III. -> Robert M. Brown III
#   Robert L. Brown III -> Robert M. Brown III
#   Robert M. Brown II -> Robert M. Brown III
#   Robert L. Brown II -> Robert M. Brown III
#   Claire Waterhouse Gargalli -> Claire W. Gargalli
#   Edward Donlev -> Edward Donley
#   W. Lee Hoskins. -> W. Lee Hoskins
#   Torrence M. Hunt, Sr -> Torrence M. Hunt, Jr
#   Torrence M. Hunt, Sr. -> Torrence M. Hunt, Jr
#   Torrence M. Hunt, Jr. -> Torrence M. Hunt, Jr
#   Marvin S. Arrington, Sr. -> Marvin S. Arrington, Sr
#   Marvin S. Arrington -> Marvin S. Arrington, Sr
#   George F. Krall, Jr. -> George F. Krall, Jr
#   James L. Ferman, Jr. -> James L. Ferman, Jr
#   Cynthia "Cissy" Baker -> Cynthia Baker
#   Myron P. "Mike" Curzan -> Myron P. Curzan
#   Richard Dean "Dick" Parsons -> Richard D. Parsons
#   Richard Dean Parsons -> Richard D. Parsons
#   Bruce C. Liimatainen -> Bruce C. Limatainen
#   Lenox D. Baker, Jr -> Lenox D. Baker, Jr.
#   Timothy H. Bishop* -> Timothy H. Bishop
#   Robert EX. Sillerman -> Robert FX. Sillerman
#   Brian K. Land -> Brian Land
#   Joan APayden -> Joan A. Payden
#   Thomas F. Jones -> J. Thomas Jones
#   Thomas W. Jones -> J. Thomas Jones
#   Joe J. Thomas -> J. Thomas Jones
#   Robert B. Johnson -> L. Robert Johnson
#   Robert L. Johnson -> L. Robert Johnson
#   Spencer B. King II -> Spencer B. King III
#   James C. Elder, Jr. -> James C. Elder, Jr
#   James C. "Jimmy" Elder, Jr -> James C. Elder, Jr
#   Robert C. Goddard Ill -> Robert C. Goddard III
#   M. Peter McPherson -> Peter McPherson
#   Rev. John P. Murray -> John P. Murray
#   August UrbaneK -> August Urbanek
#   Henry S. Miller -> Henry G. Miller
#   Eugene W. Hickok, Jr. -> Eugene W. Hickok, Jr
#   Samuel E. Hayes, Jr. -> Samuel E. Hayes, Jr
#   William C. W. Mow -> William C.W. Mow
#   John H. Broadbent, Jr -> John H. Broadbent, Jr.
#   Thomas F. Judson, Jr. -> Thomas F. Judson, Jr
#   Thomas A. Curley -> Thomas Curley
#   Thomas "Tom" Curley -> Thomas Curley
#   Andrea Cafiero Balliette -> Andrea C. Balliette
#   Edward E. Cox -> Edward F. Cox
#   Edward F. "Ed" Cox -> Edward F. Cox
#   William Henry "Bill" Cosby, Jr -> William H. Cosby, Jr
#   F. Howard Walsh, Jr. -> F. Howard Walsh, Jr
#   F Howard Walsh, Jr -> F. Howard Walsh, Jr
#   A. R. "Buddy" Dike -> A. R. Dike
#   A. R. 'Buddy' Dike -> A. R. Dike
#   George A. Ranney, Jr. -> George A. Ranney, Jr
#   Marshall I. Wais, Jr -> Marshall I. Wais, Jr.
#   Lenworth M. Jacobs, Jr. -> Lenworth M. Jacobs, Jr
#   Lenworth M. Jacobs, Jr., M.D. -> Lenworth M. Jacobs, Jr
#   Lenworth M. Jacobs, Jr., MD -> Lenworth M. Jacobs, Jr
#   Margaret Cavanaugh -> Margaret A. Cavanaugh
#   Dr. Margaret A. Cavanaugh -> Margaret A. Cavanaugh
#   Richard H. "Dick" Finan -> Richard H. Finan
#   Peter Eio. -> Peter Eio
#   James C. Mullen -> James D. Mullen
#   Thomas E. Larkin, Jr. -> Thomas E. Larkin, Jr
#   John F. Sander -> John F. Sandner
#   John F. "Jack" Sandner -> John F. Sandner
#   Jose W. Fernandez -> Jose E. Fernandez
#   Jose Rafael Fernandez -> Jose E. Fernandez
#   Jose Enrique Fernandez -> Jose E. Fernandez
#   Jose Antonio Fernandez Carbajal -> Jose E. Fernandez
#   The Hon. Thomas J. Murphy -> Thomas J. Murphy
#   Thomas S. Murphy -> Thomas J. Murphy
#   The Honorable Thomas J. Murphy -> Thomas J. Murphy
#   James P. Nix -> The Hon. James P. Nix
#   Harry G. McNeely, Jr. -> Harry G. McNeely, Jr
#   Robert J. Lawless -> Robert W. Lawless
#   William F. Fisher, Jr. -> William F. Fisher, Jr
#   L. Hall Hardaway, Jr. -> L. Hall Hardaway, Jr
#   Cal Turner, Jr -> Cal Turner, Jr.
#   Rev. Michael G. Queen -> Michael G. Queen
#   Albert H. Hunt -> Albert R. Hunt
#   ADoyle Early, Jr -> A. Doyle Early, Jr
#   James H. Hance, Jr -> James H. Hance, Jr.
#   Ronald L. "Ron" Zarrella -> Ronald L. Zarrella
#   F. William Marshall, Jr -> F. William Marshall, Jr.
#   Dorothy and David I. Schachne Dean Sheldon R. Gelman -> David I. Schachne
#   Gary E. Randolsh -> Gary E. Randolph
#   John G. Wilkerson, Jr. -> John G. Wilkerson, Jr
#   William H. Brian, Jr. -> William H. Brian, Jr
#   R. Michael Murray, Jr. -> R. Michael Murray, Jr
#   James C. Stadler -> James C. Stalder
#   David M. RodericK -> David M. Roderick
#   Phillip L. Dowd -> Philip L. Dowd
#   Bjermar K. Hermansen -> Bjernar K. Hermansen
#   Biornar K. Hermansen -> Bjernar K. Hermansen
#   Bjornar K. Hermansen -> Bjernar K. Hermansen
#   George L. Bunting, Jr -> George L. Bunting, Jr.
#   William W. Crouse III. -> William W. Crouse III
#   Thomas J. Mostert, Jr. -> Thomas J. Mostert, Jr
#   Michael Leyden -> Michael R. Leyden
#   Richard J. Kogan -> Richard Jay Kogan
#   Richard Jay Kogan'su -> Richard Jay Kogan
#   Tevia Rose Barnes -> Teveia Rose Barnes
#   Michael P. Morely -> Michael P. Morley
#   Robert Baldini -> Robert E. Baldini
#   Robert E. "Bob" Baldini -> Robert E. Baldini
#   Dr. Gerald P. "Jerry" Buccino -> Gerald P. Buccino
#   Dr. Nathan O. Hatch -> Nathan O. Hatch
#   Frank Caprio -> Frank T. Caprio
#   John C. von Lehe, Jr. -> John C. von Lehe, Jr
#   Othniel H. Wienges, Jr -> Othniel H. Wienges, Jr.
#   James A. Webb, Jr. -> James A. Webb, Jr
#   Thomas B. Walker, Jr. -> Thomas B. Walker, Jr
#   Monroe J. Carell, Jr. -> Monroe J. Carell, Jr
#   Celeste Mason Pittman -> Celeste M. Pittman
#   CAPT Robert G. Darling, USN.! -> CAPT Robert G. Darling, USN
#   Pamela M. "Pam" Deese -> Pamela M. Deese
#   Glynn C.W. Scott -> Glynn Scott
#   Gary F. Thurber -> Gary Thurber
#   Janet Ann Napolitano -> Janet Napolitano
#   Francis A. Dovle -> Francis A. Doyle
#   Carol B. Saivetz -> Carol R. Saivetz
#   Carol R. Saivetz. -> Carol R. Saivetz
#   Dr. Carol R. Saivetz -> Carol R. Saivetz
#   Alison S. Ressler -> Alison Ressler
#   The Most Reverend Allen H. Vigneron -> Allen H. Vigneron
#   Cardinal Justin Rigal -> Cardinal Justin Rigali
#   William G. "Bill" Parrett -> William G. Parrett
#   Rev. Msgr. Michael J. Bransfield -> Michael J. Bransfield
#   Bishop Thomas G. Doran -> Thomas G. Doran
#   Most Rev. William F. Murphy -> William F. Murphy
#   Most Rev. William E. Lori -> William E. Lori
#   Archbishop William E. Lori -> William E. Lori
#   His Eminence Adam Cardinal Maida -> Cardinal Adam Maida
#   Gail E. Torreano -> Gail F. Torreano
#   Gregory B. "Greg" Morrison -> Gregory B. Morrison
#   R. William "Bill" Ide III -> R. William Ide III
#   Lawrence C. Blanford -> Lawrence J. "Larry" Blanford
#   Alexander B. "Alex" Cummings, Jr -> Alexander B. Cummings, Jr
#   Sumner B. Tilton, Jr. -> Sumner B. Tilton, Jr
#   Bayard D. Clarkson -> Bayard D. Clarkson, Jr
#   Bayard D. Clarkson, Sr -> Bayard D. Clarkson, Jr
#   Bayard D. Clarkson, Sr., M.D -> Bayard D. Clarkson, Jr
#   Bayard D. Clarkson, Sr., M.D. -> Bayard D. Clarkson, Jr
#   Dr. Bayard D. Clarkson, Sr., MD -> Bayard D. Clarkson, Jr
#   Bayard D. Clarkson, Jr., MD -> Bayard D. Clarkson, Jr
#   Dr. Bayard D. Clarkson, Jr., MD -> Bayard D. Clarkson, Jr
#   Daniel C. Heintzelman. -> Daniel C. Heintzelman
#   Daniel C. "Dan" Heintzelman -> Daniel C. Heintzelman
#   Michael Powell -> Michael K. Powell
#   Vikram S. Pandit * -> Vikram S. Pandit
#   Dr. Vikram S. Pandit -> Vikram S. Pandit
#   Albert G. Mulley, Jr. -> Albert G. Mulley, Jr
#   John J. Donahoe Il -> John J. Donahoe II
#   The Hon. Daniel Terry Blue, Jr -> The Honorable Daniel Terry Blue, Jr
#   Daniel Terry Blue, Jr -> The Honorable Daniel Terry Blue, Jr
#   The Hon. Christine M. Durham -> Christine M. Durham
#   William C. Warren III -> William C. Warren IV
#   William C. "Bill" Warren IV -> William C. Warren IV
#   Dr. William C. Warren IV, MD -> William C. Warren IV
#   Richard J. "Rick" Buoncore -> Richard J. Buoncore
#   Michael J. "Mike" Cosgrove -> Michael J. Cosgrove
#   Peter G. Cooper -> Peter C. Cooper
#   J. Bryan Hehir -> Rev. J. Bryan Hehir
#   Penny S. Pritzker -> Penny Pritzker
#   Michael D. Zisman. -> Michael D. Zisman
#   Dr. Michael D. Zisman -> Michael D. Zisman
#   George L. Engelke, Jr. -> George L. Engelke, Jr
#   Dan Wassong -> Dan K. Wassong
#   John Kanas -> John Adam Kanas
#   John Adam Kanas. -> John Adam Kanas
#   William Lynch, Jr. -> William Lynch, Jr
#   Shawn Sedaghat -> S. Shawn Sedaghat
#   William E. Strickland, -> William L. Strickland
#   Patricia Schnegg -> The Honorable Patricia M. Schnegg
#   David J. Zuecher -> David J. Zuercher
#   David J. "Dave" Zuercher -> David J. Zuercher
#   Jeffrey L. "Jeff" Glassman -> Jeffrey L. Glassman
#   Garv G. White -> Gary G. White
#   H. Al Williams -> Al Williams
#   Alex Williams -> Al Williams
#   Dorothy Gonzales -> Dorothy V. Gonzales
#   Dr. Susan A. Cole -> Susan A. Cole
#   Constance siver -> Constance Silver
#   Constance M. Silver -> Constance Silver
#   Zachariah P. Zachariah, M.D -> Zachariah P. Zachariah
#   Zachariah P. Zachariah, MD -> Zachariah P. Zachariah
#   Dr. Zachariah P. Zachariah, MD -> Zachariah P. Zachariah
#   Conrad M. Hallr -> Conrad M. Hall
#   James A. "Jim" Hixon -> James A. Hixon
#   Marie Conley -> Marie Conley Lammando
#   Shirley M. Tilghman -> Shirley M. Caldwell Tilghman
#   Thomas N. lovino -> Thomas lovino
#   Jeffrey L. "Jeff" Kodosky -> Jeffrey L. Kodosky
#   Steven S. Miller -> Steven L. Miller
#   Douglas L. "Doug" Foshee -> Douglas L. Foshee
#   Douglas Lee "Doug" Foshee -> Douglas L. Foshee
#   Essie L. Calhounmid -> Essie L. Calhoun
#   Essie L. Calhoun McDavid -> Essie L. Calhoun
#   Eric Johnson -> Eric G. Johnson
#   Eric G. Johnson. -> Eric G. Johnson
#   Ronald J. lanole -> Ronald J. lanoale
#   Robert L. "Bob" Stevenson -> Robert L. Stevenson
#   Joseph P. LaSala -> Joseph P. La Sala
#   Rev. John W. Gouldrick -> Rev. John W. Gouldrick, CM
#   Steven A. "Steve" Denning -> Steven A. Denning
#   Mariann Byerwalter! -> Mariann Byerwalter
#   Richard L. "Dick" Thompson -> Richard L. Thompson
#   Joyce Hergenhann -> Joyce Hergenhan
#   Jovce Hergenhan -> Joyce Hergenhan
#   Dr. Frank Baldino, Jr., Ph.D. -> Frank Baldino, Jr
#   A. Dana Callow, Jr. -> A. Dana Callow, Jr
#   Deborah R. "Deb" Jospin -> Deborah S. Jospin
#   E. Carl Johnson -> Carl L. Johnson
#   Carl L. Jonnson -> Carl L. Johnson
#   John W. McCarter, Jr. -> John W. McCarter, Jr
#   John N. "Nick" McCarter, Jr -> John W. McCarter, Jr
#   Richard A. Davis -> Richard P. Davis
#   Richard K. Davis -> Richard P. Davis
#   Richard P. "Dick" Davis -> Richard P. Davis
#   Stephen M. Glodek, S.M -> Brother Stephen M. Glodek, SM
#   Stephen M. Glodek, SM -> Brother Stephen M. Glodek, SM
#   John K. Wallace, Jr -> John E. Wallace, Jr
#   John E. Wallace, Jr. -> John E. Wallace, Jr
#   H. Wesley Towers, Jr. -> H. Wesley Towers, Jr
#   John I. Harris -> John T. Harris
#   James J. C. Haynes II. -> James J. C. Haynes II
#   Michael A. Abraham -> Michael Abraham
#   Marve Anne Fox -> Marye Anne Fox
#   Dr. Marye Anne Fox -> Marye Anne Fox
#   Carol Hank Hoffmann -> Carol Hank Hoffman
#   D. Kirkwood Bowman -> Kirkwood D. Bowman
#   D. Kirkwood "Kirk" Bowman -> Kirkwood D. Bowman
#   William E. Trueheart. -> William E. Trueheart
#   Catherine D. DeAngelis, M.D. -> Catherine D. DeAngelis, M.D
#   Catherine D. "Cathy" DeAngelis, MD -> Catherine D. DeAngelis, M.D
#   Jay Costa, Jr -> Jay Costa, Jr.
#   John G. Conomikos -> John G. Conomikes
#   Sy M. Holzer -> Sy Holzer
#   Lee H. Noble -> H. Lee Noble
#   Ronald D. "Ron" Sugar -> Ronald D. Sugar
#   Dr. Ronald D. "Ron" Sugar -> Ronald D. Sugar
#   Peter Lund -> Peter A. Lund
#   John W. Snow -> John R. Snow
#   John J. Snow -> John R. Snow
#   James H. "Jim" Douglas -> James H. Douglas
#   William H. Gates -> William H. Gates II
#   William H. Gates I. -> William H. Gates II
#   Howard Willson. -> Howard Willson
#   Dr. Howard T. Willson -> Howard Willson
#   Paul W. Bryant, Jr. -> Paul W. Bryant, Jr
#   Judson Randolph -> Judson G. Randolph
#   Judson G. Randolph, MD -> Judson G. Randolph
#   James K. Anderson -> James A. Anderson
#   Dr. John C. Doswell II -> John C. Doswell II
#   Hemant Kanakin -> Hemant Kanakia
#   Dr. Donna A. Boswell -> Donna A. Boswell
#   Lelia J. Farr -> Lelia B. Farr
#   Arold W. Donald -> Arnold W. Donald
#   Phillip G. Lewis -> Philip G. Lewis
#   Robert A. Belfer. -> Robert A. Belfer
#   C. Nicholas Keating, Jr. -> C. Nicholas Keating, Jr
#   Jerome L. Davis -> Jerome Davis
#   William Billard -> William G. Billard
#   Carol Stewart Hawkins -> Carol Hawkins
#   Pierre Richard Prosper -> Pierre-Richard Prosper
#   Deborah Moon -> Debra Moon
#   Kenneth B. Chance. -> Kenneth B. Chance
#   Archie G. Co. -> Archie G. Co
#   Dr. Sam R. Kottamasu -> Sam R. Kottamasu
#   Dr. Marilyn French Hubbard -> Marilyn French Hubbard
#   Dr. James L. Doti -> James L. Doti
#   George D. DiRado -> George DiRado
#   James T. Milde. -> James T. Milde
#   Dr. Lawrence J"Larry" Delaney -> Lawrence J. Delaney
#   Dr. Kenneth A. Forde -> Kenneth A. Forde
#   Antonio M. Gotto, Jr., M.D.* -> Antonio M. Gotto, Jr., M.D.
#   Dr. Philip R. Reilly -> Philip R. Reilly
#   Paula Hannawav Crown -> Paula Hannaway Crown
#   Dr. Thomas M. "Tom" Gorrie -> Thomas M. Gorrie
#   Rov E. Wilbanks -> Roy E. Wilbanks
#   John P. Calamos, Sr. -> John P. Calamos, Sr
#   Bettv Kinser -> Betty Kinser
#   Nancy Berman -> Nancy M. Berman
#   Maria L. Chrin -> Maria K. Chrin
#   Dorothy A. Courtney -> Dorothy Avila Courtney
#   Joseph A. "Joe" Power, Jr. -> Joseph A. Power, Jr.
#   Shirley R. Madiganan -> Shirley R. Madigan
#   Shirley R. Madigan. -> Shirley R. Madigan
#   Ruthellvn Musil -> Ruthellyn Musil
#   Ruthellyn Musilhar -> Ruthellyn Musil
#   Dr. Susan J. Hockfield -> Susan Hockfield
#   Carolyn Townsend McAfee -> Carolyn T. McAfee
#   Malcolm S. Burgess, Jr. -> Malcolm S. Burgess, Jr
#   Malcolm S. Burgess -> Malcolm S. Burgess, Jr
#   Kenneth E. "Ken" Ampy -> Kenneth E. Ampy
#   Robert J. "Bob" O'Neill, Jr., ICMA-CM -> Robert J. O'Neill, Jr., ICMA-CM
#   Thomas E. "Tom" Spurgeon -> Thomas E. Spurgeon
#   Mamon M. Powers, Jr. -> Mamon M. Powers, Jr
#   Susanne Glasscock -> Susanne Morris Glasscock
#   Donald N. Boyce. -> Donald N. Boyce
#   Donald Boyce -> Donald N. Boyce
#   Charles W. Brown, Jr -> Charles S. Brown, Jr.
#   Charles S. Brown, Jr -> Charles S. Brown, Jr.
#   Sandy Stewartv -> Sandy Stewart
#   Michael Bogdonoff -> Michael A. Bogdonoff
#   Patrick Randazzo -> Patrick P. Randazzo
#   Paul G. Bootkoski -> The Most Reverend Paul G. Bootkoski
#   The Most Reverend Paul G. Bootkoski. -> The Most Reverend Paul G. Bootkoski
#   The Most Reverend Joseph Anthony Galanti -> The Most Reverend Joseph Anthony Galante
#   Deryck A. Palmer -> Deryck Palmer
#   J. Roger Williams -> The Honorable J. Roger Williams
#   Roger Williams -> The Honorable J. Roger Williams
#   William B. "Bill" Richardson -> William B. Richardson
#   J. Wayne Hutchens -> Wayne Hutchens
#   Paul M. Marshall, SM -> Rev. Paul Marshall, SM
#   Rev. Paul M. Marshall, SM -> Rev. Paul Marshall, SM
#   Katherine Schipper. -> Katherine Schipper
#   P. Coleman Townsend -> P. Coleman Townsend, Jr
#   P. Coleman Townsend, Jr. -> P. Coleman Townsend, Jr
#   William H. Narvel, Jr. -> William H. "Chip" Narvel, Jr
#   Jennifer C. Smith -> Jennifer C. Smith Turner
#   Jenniter C. Smith Turner -> Jennifer C. Smith Turner
#   Don L. Chalmers -> Don Chalmers
#   Phillip R. Dixonas -> Phillip R. Dixon
#   Robert J. "Bob" Corkern -> Robert Corkern
#   Alvin E. McQuinn -> Alvin McQuinn
#   Mary G. Marso -> Mary Marso
#   Michael D. "Mike" Case -> Michael D. Case
#   James D. Miller -> Rev. James D. Miller
#   Danae D. DavIs -> Danae D. Davis
#   Dr. Helen F. Giles-Gee -> Helen F. Giles-Gee
#   John. R. Lowden -> John R. Lowden
#   Mitesh Bharat "Mit" Shah -> Mitesh Bharat Shah
#   J. Thomas Clark -> Thomas S. Clark
#   Thomas C. Clark -> Thomas S. Clark
#   Dr. Thomas S. Clark -> Thomas S. Clark
#   Cynthia H. Sarmoski -> Cynthia H. Sarnoski
#   Scott Ramsay -> Scott W. Ramsay
#   Richard F. Connolly, Jr. -> Richard F. Connolly, Jr
#   Anita Spivey -> Anita V. Spivey
#   David A. Janes, Sru -> David A. Janes, Sr
#   James T. Vaughn -> James T. "Jim" Vaughn
#   Janet Hill -> V. Janet Hill
#   V. Janet HIll -> V. Janet Hill
#   Patricia D. Yodel -> Patricia D. Yoder
#   Lvnn Stahl -> Lynn Stahl
#   Lynn H. Stahl -> Lynn Stahl
#   Claire Perry -> Claire Getty Perry
#   Dr. Claire Getty Perry -> Claire Getty Perry
#   Jeffrey H. "Jeff" Aronson -> Jeffrey H. Aronson
#   Donald King -> Donald G. King
#   Sharen Sternheim -> Sharon Sternheim
#   Sharon Sternheimw? -> Sharon Sternheim
#   John R. Bransfield, Jr -> John R. Bransfield, Jr.
#   Smita Shah -> Smita N. Shah
#   Abigail P. "Abby" Johnson -> Abigail P. Johnson
#   Barry M. Kornblau -> Barry Kornblau
#   Michael K. Hanna, Sr. -> Michael K. Hanna, Sr
#   Betsv E. Huber -> Betsy E. Huber
#   Patrick M. Murray. -> Patrick M. Murray
#   Tegwin Pulley -> Tegwin Ann Pulley
#   Wavne J. Shepperd -> Wayne J. Shepperd
#   Paul A. Sittard. -> Paul A. Sittard
#   J. Cecil Garaner -> J. Cecil Gardner
#   Kick J. Caruso -> Rick J. Caruso
#   Charles E. Wharton -> Charles Wharton
#   George E. Cates -> George Cates
#   Craig Cole -> Craig W. Cole
#   David P. Connor -> David P. O'Connor
#   Charles Winston Fowler -> Charles D. Fowler
#   Charles K. Valutas -> Charles K. "Charlie" Valutas
#   JacK O. Bovender, Jr. -> Jack O. Bovender, Jr
#   John F. Morgan, Sr. -> John F. Morgan, Sr
#   Steven Ross -> Steven S. Ross
#   John Fumosa -> John J. Fumosa
#   Bernard L. Schwartz -> Bernard Leon Schwartz
#   Curtis Priem -> Curtis R. Priem
#   Arunas Chesonis -> Arunas A. Chesonis
#   Robert Mortensen -> Robert E. Mortensen
#   William L. Collins -> William Collins
#   Howard G. Phanstiel -> Howard G. "Howie" Phanstiel
#   The Honorable Charlie L. Geren -> Charlie Geren
#   Thomas J. Pritzker -> Thomas Jay "Tom" Pritzker
#   Thomas Jay Pritzker -> Thomas Jay "Tom" Pritzker
#   James F. Flaherty III -> James F. "Jay" Flaherty III
#   James P. Flaherty -> James F. "Jay" Flaherty III
#   Robert J. Ulrich -> Robert J. "Bob" Ulrich
#   Trevor D. Rees-Jones -> Trevor Rees-Jones
#   Benjamin F. "Ben" Johnson III -> Benjamin F. Johnson III
#   Lillian Shiao- Yen Wu -> Lilian Shiao-Yen Wu
#   Lillian Shiao-Yen Wu -> Lilian Shiao-Yen Wu
#   Lilian Shiao-yen Wu -> Lilian Shiao-Yen Wu
#   Dr. Lilian Shiao-Yen Wu -> Lilian Shiao-Yen Wu
#   James Humphreys -> James F. Humphreys
#   James H. Humphreys -> James F. Humphreys
#   Roderick K. West -> Roderick K. "Rod" West
#   G. Ralph Thompsoi -> G. Ralph Thompson
#   Dr. Rebekah May Wang Cheng -> Rebekah Wang Cheng
#   Jack B. Jewett -> Jack Jewett
#   Richard L. Moske -> Richard L. Moake
#   Neal Thomas "Buddy" Jones -> Neal Thomas Jones
#   John F. Smith, Jr -> John F. Smith, Jr.
#   John J. Smith, Jr -> John F. Smith, Jr.
#   Esther A. H. Hopkins -> Esther A.H. Hopkins
#   Paul R. Dupee, Jr. -> Paul R. Dupee, Jr
#   Ms. Barrie Dinkins Simpson -> Barrie Dinkins Simpson
#   Alexander C. Speyer, Jr -> Alexander C. Speyer, Jr.
#   Herbert B. Simon -> Herbert A. Simon
#   Altred Lerner -> Alfred Lerner
#   Christopher "Chris" Cox -> Christopher Cox
#   Robert H. Tucker, Jr -> Robert H. Tucker, Jr.
#   Cornelius Henderson -> Cornelius L. Henderson
#   Dennis Ruppel -> Dennis G. Ruppel
#   Ravmond A. Mason -> Raymond A. Mason
#   Raymond A. "Chip" Mason -> Raymond A. Mason
#   Lerov A. Reese -> Leroy A. Reese
# ...
#   Gerold EL. Klauer -> Gerold PL. Klauer
#   Gerold FL. Klauer -> Gerold PL. Klauer
#   Gerold F.L. Klauer -> Gerold PL. Klauer
#   Tony E. Sayegh, Jr. -> Tony E. Sayegh, Jr
#   Ted J. Leonsis -> Ted J. LeonsIs
#   Susan L. Graham -> Susan L. Graham Harrison
#   Priscilla A. "Pam" Walter -> Priscilla A. Walter
#   Priscilla Ann "Pam" Walter -> Priscilla A. Walter
#   Jerry E. Shea, Jr. -> Jerry E. Shea, Jr
#   Ronald Anderson Walter -> Ronald R. Anderson
#   Francis M. "Hank" Gowen, Jr. -> Francis M. Gowen, Jr
#   Rev. John F. Libens, S.J -> Rev. John F. Libens, SJ
#   Rev. John F. Libens, S.J. -> Rev. John F. Libens, SJ
#   Mitt Romney -> Mitt Romnev
#   William "Gene" Powell -> William H. Powell
#   William Eugene "Gene" Powell -> William H. Powell
#   Dr. Joel S. Bloom -> Joel S. Bloom
#   ADM Harold W. Gehman, Jr., USN (Ret) -> Harold W. Gehman, Jr., US
#   ADM Harold W. Gehman, Jr., US (Ret) -> Harold W. Gehman, Jr., US
#   ADM Harold W. "Hal" Gehman, Jr., USN (Ret) -> Harold W. Gehman, Jr., US
#   ADM Harold W. 'Hal' Gehman, Jr., US (Ret) -> Harold W. Gehman, Jr., US
#   James Smith McDonnell III -> James S. McDonnell III
#   Hector L. Sambolin, Jr -> Hector L. Sambolin, Jr.
#   G. William Hunter -> G. William Hunt
#   Gail Schwartz. -> Gail Schwartz
#   Margaret Corie Darby -> Margaret Corie
#   Tommie Burns, Jr. -> Tommie Burns, Jr
#   Waymon Hickman -> Wayman Hickman
#   William B. Stokely III -> William B. Stokely
#   Georgia M. Willis Fauber -> Georgia M. Willis
#   LaKeesha K. Ransom -> LaKesha K. Ransom
#   James F. "Jim" Orr III -> James F. Orr III
#   Philip S. Thompson -> Philip Thompson, Sr
#   Roger J. Heinen, Jr -> Roger Heinen, Jr
#   Mary Venezia -> Mary Venezio
#   Michael E. BronnerA. -> Michael E. Bronner
#   John F. "Trip" Renfro II -> John F. "Trip" Renfro
#   John W. Tucker, Jr. -> John W. Tucker, Jr
#   W. E. "Bill" Tumblin I -> W. E. "Bill" Tumblin
#   R. Charles Eldridge, Jr -> B. Charles Eldridge, Jr
#   Dr. Susan H. Murphy -> Susan H. Murphy
#   Thomas E Motamed -> Thomas F. Motamed
#   Thomas F Motamed -> Thomas F. Motamed
#   Thomas F. "Tom" Motamed -> Thomas F. Motamed
#   Thomas Firouz "Tom" Motamed -> Thomas F. Motamed
#   Rev. Bienvenido F. Nebres, S.J -> Rev. Bienvenido F. Nebres, S.J.
#   Rev. Bienvenido F. Nebres, S.JV -> Rev. Bienvenido F. Nebres, S.J.
#   Fr. Bienvenido F. Nebres, S.J -> Rev. Bienvenido F. Nebres, S.J.
#   Sharon R. Kanovsky Richter -> Sharon R. Kanovsky
#   Byron E. Lewis, Jr. -> Byron E. Lewis, Jr
#   Daniel J. Carroll, Jr -> Daniel J. Carroll, Jr.
#   Ellen D. Harvey -> Ellen Harvey
#   John A. O'Brien -> John O'Brien
#   John A. "Johnny" O'Brien -> John O'Brien
#   John G. O'Brien -> John O'Brien
#   John J. Nigro -> John Nigro
#   Philip G. Satre -> Philip G. Sarte
#   Dr. Marlene M. Hapai. -> Dr. Marlene M. Hapai
#   Marlene M. Hapai -> Dr. Marlene M. Hapai
#   Chad J. Marquis -> Chad Marquis
#   John J. Ouellette -> John J. Oullette
#   Theodor P. "Ted" Baseler -> Theodor P. Baseler
#   Robert A. Wells -> Robert Wells
#   Katherine Hagedorn Littlefield -> Katherine Littlefield
#   Sulajia Motwani -> Sulajja Motwani
#   T. B. "Bruce" Harper -> T. B. Harper
#   Marshall White, Jr -> Marshall "Sonny" White, Jr
#   Joseph F. Thompson -> Joseph F. "Joe" Thompson
#   Neil C. Robinson, Jr. -> Neil C. Robinson, Jr
#   Michael K. "Mike" Drakeford -> Michael K. Drakeford
#   James R. "Jay" Courie -> James R. Courie
#   Charles Harvey McTier -> Charles Harvey "Pete" McTier
#   Renetta E. McCann -> Renetta McCann
#   Steven J. Leew -> Steven J. Lee
#   Artis L. Terrell, Jr. -> Artis L. Terrell, Jr
#   Wajdi Kanj -> Waidi Kanj
#   James D. "Jim" Kuhn -> James D. Kuhn
#   Cecelia M. Calhoun -> Cecelia Calhoun
#   W. Austin Ligon -> Austin Ligon
#   Daniel "Dan" Pero -> Daniel Pero
#   Richard Allen "Rick" Beyer -> Richard Beyer
#   Roscoe Howard II -> Roscoe Howard III
#   John P. Howe III, M.D -> John P. Howe III, M.D.
#   Dennis D. Assael -> Dennis Assael
#   John L. Cote, Jr. -> John L. Cote, Jr
#   Berry Kenneth Bolt -> Berry Kenneth "Ken" Bolt
#   William E. Williams -> William E. Williams III
#   James G. "Jimmy" Padgett, Jr -> James G. Padgett, Jr
#   Jeffrey R. "Jeff" Immelt -> Jeffrey R. Immelt
#   Jeffrey R. "Jeff' Immelt -> Jeffrey R. Immelt
#   Charles Edgar Haldeman, Jr., CFA -> Charles Edgar Haldeman, Jr
#   Charles Edgar "Ed" Haldeman, Jr., CFA -> Charles Edgar Haldeman, Jr
#   Hugh Calvin Long II. -> Hugh Calvin Long IL!
#   Hugh Calvin Long II -> Hugh Calvin Long IL!
#   Vincent F. Callahan, Jr -> Vincent F. Callahan, Jrw. f.wm.
#   Terri Cofer Beime -> Terri Cofer Beirne
#   N. Anthony Coles, M.D. -> N. Anthony Coles, M.D
#   Dr. William L. "Bill" Self -> William L. Self
#   C. Gregory "Greg" DeLoach III -> C. Gregory DeLoach II
#   Laurence E. "L.E." Simmons -> Laurence E. Simmons
#   Bart G. Guerreri -> Bart G. Guerreri.
#   Dr. Rosalie M. Mirenda -> Rosalie M. Mirenda
#   Thomas M. "Tom" Zuckerman -> Thomas M. Zuckerman
#   Steven Paul Furr, M.D -> Steven Paul Furr, M.D.
#   Charles C. Stephenson, Jr -> Charles C. Stephenson, Jr.
#   Kathryn O. "Kathy" Greenberg -> Kathryn O. Greenberg
#   Lindsey Kupterman -> Lindsey Kupferman
#   Dr. Lindsey Kupferman Levine -> Lindsey Kupferman
#   Dr. James Rund -> James Rund
#   Katherine "Kate" Burton -> Katherine Burton
#   Dorsey M. James -> Dorsey I. James
#   Lauren J. Kolodny -> Lauren Kolodny
#   Aristides S. "Aris" Candris -> Aristides S. Candris
#   Roy W. Haley -> Roy W. Haleyon
#   Michael G. "Mike" Cherkasky -> Michael G. Cherkasky
#   Dr. Ronald I. Dozoretz, MD -> Dr. Ronald I. Dozoretz, M.D
#   R. David Threshie, Jr -> R. David Threshie, Jr.
#   Dr. Carlton E. Brown -> Carlton E. Brown
#   Jeffrey M. Siegal -> Jeffrey Siegal
#   Elizabeth T. "Libby" Brown -> Elizabeth T. Brown
#   L. Clifford Schroeder, Sr -> L. Clifford Schroeder, Sr.
#   Bobert E. Scott -> Robert E. Scott
#   Scott A. Roberts -> Robert E. Scott
#   VADM Richard H. Truly, USN (Ret) -> VADM Richard H. Truly, US (Ret)
#   Dr. Robert S. Langer, Jr., ScD -> Robert S. Langer, Jr., Sc.D
#   Ronald D. "Ron" Mc Cray -> Ronald D. "Ron" Mc Cray.
#   William T. "Bill" Schleyer -> William T. Schleyer
#   Joel M. Koppelman -> Joel Koppelman
#   Dr. Donna Gentile O'Donnell, PhD -> Dr. Donna Gentile O'Donnell, Ph.D
#   Kenneth J. Boller, S.J -> Kenneth J. Boller, S.J.
#   Fr. John J. Cecero, S.J., PhDP -> Fr. John J. Cecero, S.J., Ph.D
#   GEN John M. "Jack" Keane, USA (Ret) v -> GEN John M. "Jack" Keane, USA (Ret)
#   Jay E. Katzen, MD -> Jay E. Katzen, M.D
#   David C. Karlgaard -> David Karlgaard
#   Nemir Amin Kirdar r. -> Nemir Amin Kirdar
#   Dr. Cristian Samper -> Cristian Samper
#   Dr. David W. Oxtoby -> David W. Oxtoby
#   Dr. Drew Gilpin Faust -> Drew Gilpin Faust
#   Dr. Sidney A. Ribeau -> Sidney A. Ribeau
#   Michael Anthony Pulick -> Michael Anthony "Mike" Pulick
#   Steven C. "Steve" Smith -> Steven C. Smith
#   Paula E. Boggs, Esq -> Paula E. Boggs, Esq.
#   Dr. Lenox D. Baker, Jr., MD -> Lenox D. Baker, Jr., M.D
#   Daniel E. "Dan" Smith, Jr. -> Daniel E. Smith, Jr.
#   John J. Vresics, Jr. -> John J. "Jack" Vresics, Jr.
#   John J. "Jack" Vresics, Jr -> John J. "Jack" Vresics, Jr.
#   Dr. Eduardo D. Glandt -> Eduardo D. Glandt
#   Margaret Erich Goodman -> Margaret E. Goodman
#   Robert V. "Bobby" Yarborough -> Robert "Bobby" Yarborough
#   Joseph P. Page -> Joseph P. Page9
#   Delia M. Rogesal -> Delia M. Roges
#   Dr. Robert J. Sclabassi, MD -> Robert J. Sclabassi, M.D
#   Richard H. Koppes -> Richard H. Koppes.
#   Thomas P. Beck -> Thomas P. Beck.
#   Javier R. Guerena, CPA -> Javier R. Guerena, CPA.
#   Michael J. Carbon, MD -> Michael J. Carbon, M.D
#   Rev. Paul Joseph Fitzgerald, S.J -> Rev. Paul J. Fitzgerald, S.J
#   Alejandro Padilla -> Alejandro "Alex" Padilla
#   Dr. Laura D'Andrea Tyson -> Laura D'Andrea Tyson
#   Samuel Wright Bodman III -> Samuel Wright "Sam" Bodman III
#   Sarah Stewart Johnson -> Sarah Stewart Johnsonw
#   Dr. Donald H. Sebastian -> Donald H. Sebastian
#   Dr. Richard S. Bowles III -> Richard S. Bowles III
#   Richard Flvnn -> Richard Flynn
#   Stephanie Nolan Deviney -> Stephanie Nolan Deviney.
#   Michael J. "Mike" Birck -> Michael J. Birck
#   Laura Elena Arnold -> Laura Arnold
#   Gregory Brown -> Gregory O. "Greg" Brown
#   Joyce Wilson Harley, Esq. -> Joyce Wilson Harley, Esq
#   Antoine M. Garibaldi, Ph.D. -> Antoine M. Garibaldi, Ph.D
#   Deborah A. "Debbie" Zoullas -> Deborah A. Zoullas
#   Dr. William Henry "Bill" Cosby, Jr. -> William Henry "Bill" Cosby, Jr.
#   Dr. Ann Scanion McGinity -> Ann Scanion McGinity
#   Joseph D. "Joe" Neguse -> Joseph D. Neguse
#   Dr. Jim Geddes -> Jim Geddes
#   Dr. Andrea Dennis-LaVigne, DVM -> Andrea Dennis-LaVigne, D.V.M.
#   Lynton P. Scotland -> Lynton Scotland
#   Richard B. "Rick" Beeson, Jr -> Richard B. "Rick" Beeson, Jr.
#   Richard B"Rick" Beeson, Jr -> Richard B. "Rick" Beeson, Jr.
#   Timothy F. Clare -> Timothy Clare
#   Timothy F. "Tim" Clare -> Timothy Clare
#   Charles H. Hassebrook -> Charles H. "Chuck" Hassebrook
#   Burley B. Mitchell, Jr. -> Burley B. Mitchell, Jr
#   Paul L. Fulton, Jr. -> Paul L. Fulton, Jr
#   Bev. James B. King, CSC -> Rev. James B. King, CSC
#   Naka Ushijima -> Naka "Nick" Ushijima
#   Brett Harvey -> J. Brett Harvey
#   Sir George W. Buckley -> George W. Buckley
#   Bradford S. "Brad" Mead -> Bradford S. Mead
#   Larry R. Ellis, USA (Ret) -> GEN Larry R. Ellis, USA (Ret)
#   Kurt D. Eddins -> Kurt Eddins
#   Virginia M. Barry, PhD -> Virginia M. Barry, Ph.D.
#   Levi Watkins, Jr., MD -> Levi Watkins, Jr., M.D
#   The Very Reverend Anthony M. "Micky" Genovese, OSA -> The Very Reverend Anthony M. Genovese, OSA
#   Paul A. Tufano, Esq -> Paul A. Tufano, Esg.
#   George P. Bauer, Jr. -> George P. Bauer, Jr
#   Stephen M. Wynne -> Stephen M. "Steve" Wynne
#   Larry Moore -> Larry R. Moore
#   Michael "Mike" Maples -> Michael Maples
#   Philip W. "Phil" Schiller -> Philip W. Schiller
#   Michael H. Devlin Il -> Michael H. Devlin II
#   Elizabeth W. Vanderslice -> Elizabeth W. Vanderslice.
#   S. D. "Shibu" Shibulah -> S. D. Shibulah
#   Rajen A. Kilachand -> Rajen A. Kilachand.
#   David L. "Dave" Porges -> David L. Porges
#   Dr. Julie Louise Gerberding, MD, MPH -> Julie Louise Gerberding, MD, MPH
#   Dominic L. Ozanne -> Dominic Ozanne
#   His Eminence Cardinal Donald William Wuerl -> His Eminence Cardinal Donald W. Wuerl
#   Jody A. Markopoulos -> Jody A. Markopoulos.
#   Steven D. "Steve" Odom -> Steven Odom
#   Richard T. "Rick" Caldwell Il -> Richard T. "Rick" Caldwell II
#   Benjamin "Ben" Horowitz -> Benjamin Horowitz
#   Joseph A. Greenaway, Jr -> Joseph A. Greenaway, Jr.
#   Ruben Jose King-Shaw, Jr -> Ruben Jose King-Shaw, Jr.
#   R. William "Bill" Burgess, Jr -> R. William Burgess, Jr.
#   Robert R. "Bob" Penn -> Robert R. Penn
#   John R. "Jack" McGinley, Jr -> John R. "Jack" McGinley, Jr.
#   Edward M. "Ed" Stroz -> Edward M. Stroz
#   Luis E. San Miguel -> Luis San Miguel
#   Dr. Steven M. Scott -> Steven Scott
#   Dr. Reed V. Tuckson, MD, MD, FACP, FACP -> Dr. Reed V. Tuckson, MD, FACP
#   Michael B. Battle -> Michael M. Battle
#   Charles William "Charlie" Scharf -> Charles William Scharf
#   Anne R. Kline -> Anne R. Kline.
#   Rao Subba Anumolu -> Rao Anumolu
#   Rev. Thomas A. Lawler, S.J -> Rev. Thomas A. Lawler, S.J.
#   Dr. Fariborz Maseeh -> Fariborz Maseeh
#   Phillip T. "Terry" Ragon -> Phillip T. Ragon
#   James Thomas "Tom" McAfee Ill -> James Thomas "Tom" McAfee III
#   Dr. David E. Van Zandt -> David E. Van Zandt
#   Jane E. DeFlorio -> Jane DeFlorio
#   Chandrika Krishnamurthy Tandon -> Chandrika Tandon
#   Casey Box -> Casey BoxO
#   William T. "Stuyvie" Comfort III -> William T. Comfort III
#   Dr. Bradley G. "Brad" Bond -> Bradley Bond
#   Dr. George L. Hanbury II -> Dr. George L. Hanbury II, PhD
#   Michael J. "Mike" Jackson -> Michael J. "Mike Jackson
#   Donald G. Cotner -> Donald G. Cotnerser
#   Dr. Laurence C. Morse -> Laurence C. Morse
#   Dr. John E. Kelly III -> John E. Kelly III
#   Wanda K. Denson-Low -> Wanda K. Denson Low
#   Lawrence H. "Larry" Guffey -> Lawrence H. Guffey
#   Nimesh S. Jhaveri -> Nimesh Jhaveri
#   Robert Ley -> Robert Ley.
#   Mary Ann Christopher, RN, FAAN -> Mary Ann Christopher, RN, FAAN.
#   Robert B. Budelman, Jr -> Robert B. Budelman, Jr.
#   Francis J. "Frank" Hager -> Francis J. Hager
#   Laurene Powell Jobs -> Laurene Powell
#   Jeffrey S. "Jeff" Raikes -> Jeffrey S. "Jeff" Raikes v.
#   Mark A. Neporent -> Mark A. Neporentow
#   Dr. Anthony P. Monaco -> Anthony P. Monaco
#   Diane S. Hessan -> Diane Hessan
#   W. Davis Malone IlI -> W. Davis Malone III
#   Kenneth Luckie Vandervoort -> Kenneth Luckie Vandervoorto
#   Jyotsna Jo Heckman -> Jyotsna Jo Heckman.
#   Daniel L"Dan" Doctoroff -> Daniel L. Doctoroff
#   Francis X. "Frank" Hursey -> Francis "Frank" Hursey
#   Jan Naoe Sullivan -> Jan Sullivan
#   Carol Martin "Bill" Gatton -> Carol Martin Gatton
#   Margaret H. Sedenquist -> Margaret Sedenquist
#   Wendy M. Lau -> Wendy Lau
#   ADM Gregory G. "Grog" Johnson, USN (Ret) -> ADM Gregory G. "Grog" Johnson, US (Ret)
#   LtGen Bradley C. Hosmer, USAF (Ret) -> LtGen Bradley C. Homer, USAF (Ret)
#   Kevin P. Huber -> Kevin Huber
#   Randall T. Hayashi -> Randall Hayashi
#   Roberta A. Luxbacher -> Roberta Luxbacher
#   Amy G. Beretta -> Amy Beretta
#   Thomas C "Tommy" Cofield -> Thomas C. "Tommy" Cofield
#   Thomas J. Barrack, Jr -> Thomas J. Barrack, Jr.
#   Kathleen J"Kathy" Higgins Victor -> Kathleen J. "Kathy" Higgins Victor
#   Frank B. Wilderson, Jr -> Frank Wilderson, Jr
#   Dr. Joseph Anthony "Joe" DiPietro -> Joseph Anthony "Joe" DiPietro
#   E. Thomas "Tom" Sullivan -> E. Thomas Sullivan
#   Gerald "Jerry" Whitburn -> Gerald "Jerry" Whitbumr
#   Jeffrey S. "Jeff" Marsh -> Jeffrey S. Marsh
#   Philip A. Wilheit, Sr -> Philip A. Wilheit, Sr.
#   Wallace R"Wally" Stevens -> Wallace R. "Wally" Stevens
#   Daniel M. "Dan" DiLella, Sr -> Daniel M. "Dan" DiLella, Sr.
#   John A. Luke, Jr -> John A. Luke, Jr.an
#   B. Keith "BK" Fulton -> B. Keith Fulton
#   Shelmer D. Blackburn, Jr -> Shelmer D. Blackburn, Jr.
#   Thomas Lauck "Tom" Sager -> Thomas Lauck Sager
#   Anthony R. Britton, Jr -> Anthony R. Britton, Jr.
#   Charles Waterhouse "Chip" Goodyear IV -> Charles W. "Chip" Goodyear IV
#   Mendel Mark Silber -> Mark Silber
#   Catharine M. Ryan -> Catharine Murray Ryan
#   Christopher Ludwig Eisgruber* -> Christopher Ludwig Eisgruber
# Updated board dataframe for year 1999 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\1999_boards_normalized.csv
# Updated board dataframe for year 2000 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2000_boards_normalized.csv
# Updated board dataframe for year 2005 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2005_boards_normalized.csv
# Updated board dataframe for year 2007 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2007_boards_normalized.csv
# Updated board dataframe for year 2008 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2008_boards_normalized.csv
# Updated board dataframe for year 2009 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2009_boards_normalized.csv
# Updated board dataframe for year 2011 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2011_boards_normalized.csv
# Updated board dataframe for year 2013 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2013_boards_normalized.csv
# Updated board dataframe for year 2018 with standardized names written to C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\normalized_dataframes\2018_boards_normalized.csv
