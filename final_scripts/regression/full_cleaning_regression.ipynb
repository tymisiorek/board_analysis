# %%
import pandas as pd
from collections import defaultdict, Counter
import networkx as nx
import os
import re
import matplotlib.pyplot as plt
from rapidfuzz import fuzz
from itertools import combinations

# %%
absolute_path = "C:\\Users\\tykun\\OneDrive\\Documents\\SchoolDocs\\VSCodeProjects\\connectedData\\board_analysis\\"
altered_dataframes = "altered_dataframes\\"
board_dataframes = "board_dataframes\\"
final_scripts = "final_scripts\\"
regression = "regression\\"
normalized_dataframes = "normalized_dataframes\\"
normalized_regression_boards = "normalized_regression_boards\\"


years = ["1999", "2000", "2005", "2007", "2008", "2009", "2010", "2011", "2013", "2018"]

# %%
def remove_non_samples(df: pd.DataFrame) -> pd.DataFrame:
    """Filter the DataFrame to include only rows where 'PrimarySample' is True."""
    return df[df['PrimarySample'] == True]

def normalize(x):
    """Convert the input to a string and strip whitespace."""
    return str(x).strip()

# %%
affiliation_df = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_systems.csv")

# %%
# This dictionary will map AffiliationId -> Counter({InstitutionName: count}) from both DataFrames.
affiliation_name_counter = defaultdict(Counter)
years_board_data = {}
years_double_data = {} 

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}{regression}regression_boards", f"{year}_boards_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}{regression}regression_boards", f"{year}_double_boards_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    years_board_data[year] = board_df
    years_double_data[year] = double_board_df
    
    for aff_id, institution_name in zip(board_df["AffiliationId"], board_df["Institution"]):
        affiliation_name_counter[aff_id][institution_name] += 1
        
    for aff_id, institution_name in zip(double_board_df["AffiliationId"], double_board_df["Institution"]):
        affiliation_name_counter[aff_id][institution_name] += 1

# Create final mapping: for each AffiliationId, choose the most common institution name across both DataFrames.
affiliation_final_name = {}
for aff_id, name_counter in affiliation_name_counter.items():
    most_common_name = name_counter.most_common(1)[0][0]
    affiliation_final_name[aff_id] = most_common_name



affiliation_final_name = {k: v for k, v in affiliation_final_name.items() if pd.notna(k)}

#Now update both the board and double board DataFrames using the standardized names.
for year in years:
    board_df = years_board_data[year]
    double_board_df = years_double_data[year]
    
    original_board_names = board_df["Institution"].copy()
    original_double_names = double_board_df["Institution"].copy()
    
    #map the standardized institution names based on AffiliationId
    board_df["Institution"] = board_df["AffiliationId"].map(affiliation_final_name)
    double_board_df["Institution"] = double_board_df["AffiliationId"].map(affiliation_final_name)
    
    #log changes: For each unique affiliation id, if the original names differ from the new standardized name, print the change.
    for aff in board_df["AffiliationId"].unique():
        group_old_names = original_board_names[board_df["AffiliationId"] == aff].unique()
        new_name = affiliation_final_name.get(aff, None)
        if set(group_old_names) != {new_name}:
            print(f"Year {year}: Board AffiliationId '{aff}' had original names {group_old_names} -> changed to '{new_name}'")
    
    for aff in double_board_df["AffiliationId"].unique():
        group_old_names = original_double_names[double_board_df["AffiliationId"] == aff].unique()
        new_name = affiliation_final_name.get(aff, None)
        if set(group_old_names) != {new_name}:
            print(f"Year {year}: Double Board AffiliationId '{aff}' had original names {group_old_names} -> changed to '{new_name}'")
    
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df.to_csv(board_path, index=False)
    double_board_df.to_csv(double_board_path, index=False)
# Out:
# Year 1999: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 1999: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 1999: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 1999: Board AffiliationId '35777872.0' had original names ['North Carolina Agricultural And Technical State University'] -> changed to 'North Carolina Agricultural and Technical State University'
# Year 1999: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 1999: Board AffiliationId '392282.0' had original names ['State University Of New York At Albany'] -> changed to 'State University of New York at Albany'
# Year 1999: Board AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'State University of New York at Buffalo'
# Year 1999: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 1999: Board AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 1999: Board AffiliationId '17301866.0' had original names ['University Of Alabama'] -> changed to 'Universitv of Alabama Tuscaloosa'
# Year 1999: Board AffiliationId '157725225.0' had original names ['University Of Illinois At Urbana Champaign'] -> changed to 'University of Illinois at Urbana-Champaign'
# Year 1999: Board AffiliationId '166722992.0' had original names ['University Of Massachusetts Worcester'] -> changed to 'University of Massachusetts at Worcester'
# Year 1999: Board AffiliationId '368840534.0' had original names ['University Of Mississippi'] -> changed to 'University of Mississippi Ole Miss'
# Year 1999: Board AffiliationId '208333798.0' had original names ['University Of Missouri St Louis'] -> changed to 'University of Missouri St Louis'
# Year 1999: Board AffiliationId '134113660.0' had original names ['University Of Nevada Reno'] -> changed to 'University of Nevada, Reno'
# Year 1999: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 1999: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 1999: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 1999: Board AffiliationId '123534392.0' had original names ['University Of North Texas'] -> changed to 'University of North Texas'
# Year 1999: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 1999: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 1999: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2000: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2000: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2000: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2000: Board AffiliationId '35777872.0' had original names ['North Carolina Agricultural And Technical State University'] -> changed to 'North Carolina Agricultural and Technical State University'
# Year 2000: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2000: Board AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'State University of New York at Buffalo'
# Year 2000: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2000: Board AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 2000: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2000: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2000: Board AffiliationId '368840534.0' had original names ['University Of Mississippi'] -> changed to 'University of Mississippi Ole Miss'
# Year 2000: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2000: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2000: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2000: Board AffiliationId '123534392.0' had original names ['University Of North Texas'] -> changed to 'University of North Texas'
# Year 2000: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 2000: Board AffiliationId '86519309.0' had original names ['University Of Texas At Austin'] -> changed to 'University of Texas at Austin'
# Year 2000: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2000: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2000: Double Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2005: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2005: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2005: Board AffiliationId '23732399.0' had original names ['Montana State University Bozeman'] -> changed to 'Montana State University'
# Year 2005: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2005: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2005: Board AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2005: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2005: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2005: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2005: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2005: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2005: Board AffiliationId '134113660.0' had original names ['University Of Nevada Reno'] -> changed to 'University of Nevada, Reno'
# Year 2005: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2005: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2005: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2005: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2005: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2005: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2005: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2005: Double Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2007: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2007: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2007: Board AffiliationId '23732399.0' had original names ['Montana State University Bozeman'] -> changed to 'Montana State University'
# Year 2007: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2007: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2007: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2007: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2007: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2007: Board AffiliationId '161318765.0' had original names ['University Of California Los Angeles'] -> changed to 'University of California Los Angeles'
# Year 2007: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2007: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2007: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2007: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2007: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2007: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2007: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2007: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2007: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2007: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2008: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2008: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2008: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2008: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2008: Board AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2008: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2008: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2008: Board AffiliationId '95457486.0' had original names ['University Of California Berkeley'] -> changed to 'University of California Berkeley'
# Year 2008: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2008: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2008: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2008: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2008: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2008: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2008: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2008: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2008: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2009: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2009: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2009: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2009: Board AffiliationId '13511017.0' had original names ['Texas State University San Marcos'] -> changed to 'Southwest Texas State University'
# Year 2009: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2009: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2009: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2009: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2009: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2009: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 2009: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2009: Board AffiliationId '859038795.0' had original names ['Virginia Tech'] -> changed to 'Virginia Polytechnic Institute And State University'
# Year 2009: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2009: Double Board AffiliationId '859038795.0' had original names ['Virginia Tech'] -> changed to 'Virginia Polytechnic Institute And State University'
# Year 2010: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2010: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2010: Board AffiliationId '155093810.0' had original names ['University of Idaho'] -> changed to 'University Of Idaho'
# Year 2010: Board AffiliationId '146416000.0' had original names ['University of Kansas'] -> changed to 'University Of Kansas'
# Year 2010: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2011: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2011: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2011: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2011: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2011: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2011: Board AffiliationId '155093810.0' had original names ['University of Idaho'] -> changed to 'University Of Idaho'
# Year 2011: Board AffiliationId '146416000.0' had original names ['University of Kansas'] -> changed to 'University Of Kansas'
# Year 2011: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2011: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'
# Year 2013: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2013: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2013: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2013: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2013: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2013: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2013: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'
# Year 2018: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2018: Board AffiliationId '44461941.0' had original names ['University Of Houston'] -> changed to 'University of Houston'
# Year 2018: Board AffiliationId '76835614.0' had original names ['University Of Missouri Columbia' 'University of Missouri, Columbia'] -> changed to 'University of Missouri, Columbia'
# Year 2018: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2018: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2018: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2018: Board AffiliationId '155093810.0' had original names ['University of Idaho'] -> changed to 'University Of Idaho'
# Year 2018: Board AffiliationId '146416000.0' had original names ['University of Kansas'] -> changed to 'University Of Kansas'
# Year 2018: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2018: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'

# %%
'''
Determine what institutions report their board every year:
'''
affiliation_info = {}

for year in years:
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    for _, row in board_df.iterrows():
        affiliation_id = row.get("AffiliationId")
        if pd.isna(affiliation_id) or normalize(str(affiliation_id)) == "":
            continue
        affiliation_id = str(affiliation_id).strip()
        if affiliation_id not in affiliation_info:
            affiliation_info[affiliation_id] = {"years": set()}
        affiliation_info[affiliation_id]["years"].add(year)
    
    for _, row in double_board_df.iterrows():
        affiliation_id = row.get("AffiliationId")
        if pd.isna(affiliation_id) or normalize(str(affiliation_id)) == "":
            continue
        affiliation_id = str(affiliation_id).strip()
        if affiliation_id not in affiliation_info:
            affiliation_info[affiliation_id] = {"years": set()}
        affiliation_info[affiliation_id]["years"].add(year)

all_years = set(years)
affiliations_every_year = {aff: info for aff, info in affiliation_info.items() if info["years"] == all_years}
affiliations_certain_years = {aff: info for aff, info in affiliation_info.items() if info["years"] != all_years}

# print("Affiliation IDs that appear in every year:")
# for aff in sorted(affiliations_every_year):
#     info = affiliations_every_year[aff]
#     print(f"{aff}: Years: {sorted(info['years'])}")

# print("\nAffiliation IDs that appear in only certain years:")
# for aff, info in affiliations_certain_years.items():
#     print(f"{aff}: Years: {sorted(info['years'])}")

print(len(affiliations_every_year), len(affiliations_certain_years))
# Out:
# 227 66

# %%
for year in years:
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    board_df["AffiliationId"] = board_df["AffiliationId"].astype(str).str.strip()
    double_board_df["AffiliationId"] = double_board_df["AffiliationId"].astype(str).str.strip()
    
    # Ensure the keys in affiliations_every_year are strings
    aff_keys = set(str(key).strip() for key in affiliations_every_year.keys())
    
    board_df = board_df[ board_df["AffiliationId"].isin(aff_keys) ]
    double_board_df = double_board_df[ double_board_df["AffiliationId"].isin(aff_keys) ]
    
    board_df.to_csv(board_path, index=False)
    double_board_df.to_csv(double_board_path, index=False)
    
    print(f"Year {year}: kept only affiliation IDs that report every year.")
    print(f"  Boards saved to: {board_path}")
    print(f"  Double Boards saved to: {double_board_path}")
# Out:
# Year 1999: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\1999_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\1999_double_boards_normalized_regression.csv
# Year 2000: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2000_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2000_double_boards_normalized_regression.csv
# Year 2005: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2005_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2005_double_boards_normalized_regression.csv
# Year 2007: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2007_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2007_double_boards_normalized_regression.csv
# Year 2008: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2008_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2008_double_boards_normalized_regression.csv
# Year 2009: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2009_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2009_double_boards_normalized_regression.csv
# Year 2010: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2010_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2010_double_boards_normalized_regression.csv
# Year 2011: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2011_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2011_double_boards_normalized_regression.csv
# Year 2013: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2013_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2013_double_boards_normalized_regression.csv
# Year 2018: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2018_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2018_double_boards_normalized_regression.csv

# %%
#time invariant dfs
affiliation_df = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_systems.csv")
original_affiliation_df  = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_original.csv")

#create a dictionary mapping state system -> institutions within the system
affiliation_dict = affiliation_df.groupby("StateSystem")["AffiliationId"].apply(list).to_dict()

affiliation_inverted = {
    aff_id: state_system
    for state_system, aff_ids in affiliation_dict.items()
    for aff_id in aff_ids
}

matched_df = original_affiliation_df[original_affiliation_df["FullName"].isin(affiliation_dict.keys())].copy()

matched_df["StateSystem"] = matched_df["FullName"]

mapping_df = matched_df[["StateSystem", "AffiliationId"]]

mapping_df = mapping_df.drop_duplicates()

system_id_map = {}
nan_id_map = {}

for _, row in mapping_df.iterrows():
    state_system = row["StateSystem"]
    board_aff_id = row["AffiliationId"]
    if pd.isna(board_aff_id):
        nan_id_map[state_system] = affiliation_dict.get(state_system, [])
    else:
        system_id_map[board_aff_id] = affiliation_dict.get(state_system, [])

# Display the resulting dictionary
print(system_id_map)
print(nan_id_map)
# Out:
# {127339247.0: [184813773, 67328108, 67328108, 142934699, 142934699, 142934699, 59897056, 59897056, 43369023, 43369023, 26538001, 71838634], 174216632.0: [125687163, 125687163, 125687163], 4210131357.0: [92446798, 92446798, 92446798, 92446798], 4210165361.0: [120156002, 106969075, 155093810], 2801365651.0: [189590672, 146416000, 39587148], 4210141039.0: [61937129, 99041443, 368840534, 44854399], 4210127926.0: [57328836, 24571045, 24571045], 29957033.0: [200885203, 161171246, 161171246], 1327163397.0: [392282, 392282, 392282, 392282, 123946342, 123946342, 123946342, 123946342, 63190737, 63190737, 63190737, 63190737, 59553526, 59553526, 59553526, 59553526, 59553526], 2801649442.0: [8248082, 63772739, 19700959, 106165777, 33213144, 11874761, 2613432], 173268674.0: [75063564, 91045830, 91045830, 91045830, 206651237, 206651237, 96749437, 96749437, 164185940, 164185940, 181414168, 181414168], 2801273398.0: [191429286, 13511017, 13511017, 13511017, 13511017], 4210088475.0: [12315562, 926076166], 68260882.0: [133999245, 133999245, 134113660, 134113660], 2800507078.0: [32389192, 32389192, 82495205, 82495205, 17301866, 17301866, 17301866, 17301866], 2802090665.0: [141472210], 2799691083.0: [78715868, 78715868, 78715868, 102401767, 79620101], 2803209242.0: [95457486, 95457486, 84218800, 84218800, 204250578, 204250578, 161318765, 161318765, 156087764, 156087764, 103635307, 103635307, 36258959, 36258959, 180670191, 154570441, 185103710], 2802236040.0: [188538660, 188538660, 888729015, 888729015, 921990950, 921990950, 921990950, 921990950], 1331384533.0: [117965899, 117965899], 2801525821.0: [44461941], 2801919071.0: [39422238, 39422238, 157725225, 157725225], 2799628689.0: [919208787, 79516672, 79516672, 79516672, 79516672], 2802397601.0: [7947594, 7947594, 7947594], 2802841742.0: [24603500, 24603500, 33434090, 33434090, 100633361, 100633361, 133738476, 133738476, 166722992, 166722992, 166722992], 4777552.0: [76835614, 76835614, 75421653, 75421653, 20382870, 20382870, 208333798, 208333798], 2802450327.0: [114395901, 114395901, 114395901, 122266389, 122266389, 59130452], 4210158053.0: [186335123, 35777872, 137902535, 114027177, 102149020, 169335092, 153901656, 153901656], 2802090120.0: [123534392], 2799495847.0: [75027704, 160606119, 160606119], 16452829.0: [189196454, 86519309, 2802326326, 2802326326, 162577319, 164936912, 164936912, 45438204, 221716585, 4210094379, 4210094379, 919571938, 165951966, 165951966, 55302922], 1304256225.0: [135310074, 135310074, 43579087, 43579087], 1289702989.0: [130701444, 39815113, 181565077, 172980758, 165733156], 1317227900.0: [126744593, 79272384, 66946132, 22407884, 22407884], 2800453862.0: [161057412, 161057412], 2802096936.0: [157417397, 102607778, 149910238, 83328450, 52357470, 52357470, 4210106879, 110152177, 63135867, 90871651, 19648265]}
# {'Arizona Board of Regents': [55732556, 203172682, 138006243], 'Indiana University System': [4210119109, 55769427], 'Oklahoma State System of Higher Education': [115475287, 8692664], 'Tennessee Board of Regents': [119443389, 169615421, 75256744, 63920570, 94658018]}

# %%
'''
The interlocks that we count here are not going to be the interlocks used for the network. this is to identify interlocking institutions so we can clean the members names
'''

substrings_to_remove = [
    "Rev.", "SJ", "Sister", "Brother", "Father", "OP", "The Very",
    "Sr.", "O.P.", "Very Rev.", "Br.", "Dr.", "Md.", "S.J.", "Very Rev",
    "M.D.", "O.P", "S.J", "J.R", "Jr.", "Jr ", "III"
]

def clean_name(raw_name: str) -> str:
    for title in substrings_to_remove:
        raw_name = re.sub(r'\b' + re.escape(title.strip()) + r'\b', '', raw_name, flags=re.IGNORECASE)
    raw_name = re.sub(r'[^\w\s]', '', raw_name)
    return " ".join(raw_name.split()).title()

# Convert system_id_map values to a list of sets.
# For each value, first cast to int then to str.
system_lists = []
for vals in system_id_map.values():
    sys_set = set(str(int(x)).strip() for x in vals if pd.notna(x))
    if sys_set and sys_set not in system_lists:
        system_lists.append(sys_set)

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    combined_df = pd.concat([board_df, double_board_df], ignore_index=True)
    board_sizes = combined_df.groupby("Institution").size().to_dict()
    
    board_member_dict = defaultdict(set)
    edge_accum = {}
    # Each institution's affiliation id will be stored as a string of the int value.
    year_nodes_dict = defaultdict(lambda: {'Interlock_Count': 0, 'AffiliationId': None})
    
    for _, row in combined_df.iterrows():
        name_raw = row["Name"]
        if "vacant" in str(name_raw).lower():
            continue
        name = clean_name(name_raw)
        institution = row["Institution"]
        if pd.notnull(row["AffiliationId"]):
            try:
                affiliation_id = str(int(float(row["AffiliationId"]))).strip()
            except Exception:
                affiliation_id = str(row["AffiliationId"]).strip()
        else:
            affiliation_id = None

        for prev_institution in board_member_dict[name]:
            if prev_institution == institution:
                continue
            # Get affiliation IDs for both institutions, casting to int then to str.
            id1 = None
            if year_nodes_dict.get(prev_institution, {}).get('AffiliationId') is not None:
                try:
                    id1 = str(int(float(year_nodes_dict.get(prev_institution)['AffiliationId']))).strip()
                except Exception:
                    id1 = str(year_nodes_dict.get(prev_institution)['AffiliationId']).strip()
            id2 = affiliation_id
            same_system = False
            if id1 and id2:
                for sys_set in system_lists:
                    if id1 in sys_set and id2 in sys_set:
                        same_system = True
                        break
            if same_system:
                continue
            pair = tuple(sorted([prev_institution, institution]))
            if pair not in edge_accum:
                edge_id = f"e_{year}_{len(edge_accum)+1}"
                edge_accum[pair] = {
                    'Id': edge_id,
                    'Source': pair[0],
                    'Target': pair[1],
                    'Type': 'Undirected',
                    'Shared': 0,
                    'Year': year
                }
            edge_accum[pair]['Shared'] += 1
            year_nodes_dict[prev_institution]['Interlock_Count'] += 1
            year_nodes_dict[institution]['Interlock_Count'] += 1
        board_member_dict[name].add(institution)
        if year_nodes_dict[institution]['AffiliationId'] is None and affiliation_id:
            year_nodes_dict[institution]['AffiliationId'] = affiliation_id

    for pair, data in edge_accum.items():
        inst1, inst2 = pair
        size1 = board_sizes.get(inst1, 0)
        size2 = board_sizes.get(inst2, 0)
        denom = size1 + size2 if (size1 + size2) > 0 else 1
        data['Weight'] = data['Shared'] / denom

    nodes_data = []
    for inst, data in year_nodes_dict.items():
        nodes_data.append({
            'Id': inst,
            'Label': inst,
            'Interlock_Count': data['Interlock_Count'],
            'AffiliationId': data['AffiliationId'],
            'Board_Size': board_sizes.get(inst, 0)
        })
    nodes_df = pd.DataFrame(nodes_data)
    
    if edge_accum:
        edges_df = pd.DataFrame(list(edge_accum.values()))
        edges_df = edges_df[['Id', 'Source', 'Target', 'Type', 'Weight', 'Year']]
    else:
        edges_df = pd.DataFrame(columns=['Id', 'Source', 'Target', 'Type', 'Weight', 'Year'])
    
    # out_nodes_path = os.path.join(absolute_path, f"{final_scripts}regression\\interlocks\\{year}_interlocks_nodes.csv")
    # out_edges_path = os.path.join(absolute_path, f"{final_scripts}regression\\interlocks\\{year}_interlocks_edges.csv")
    # nodes_df.to_csv(out_nodes_path, index=False)
    # edges_df.to_csv(out_edges_path, index=False)
    
    # print(f"Year {year} interlock nodes saved to: {out_nodes_path}")
    # print(f"Year {year} interlock edges saved to: {out_edges_path}")

# %%
name_counts = defaultdict(int)

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_boards_normalized_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_double_boards_normalized_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)

    for name in board_df["Name"].dropna():
        name_counts[str(name).strip()] += 1
    for name in double_board_df["Name"].dropna():
        name_counts[str(name).strip()] += 1

all_names = list(name_counts.keys())
sorted_names = sorted(all_names, key=lambda n: name_counts[n], reverse=True)

name_mapping = {}
used = set()
fuzzy_threshold = 90

for name in sorted_names:
    if name in used:
        continue
    similar_names = []
    for candidate in all_names:
        if candidate in used:
            continue
        if fuzz.token_set_ratio(name, candidate) >= fuzzy_threshold:
            similar_names.append(candidate)
    canonical = max(similar_names, key=lambda n: name_counts[n])
    for candidate in similar_names:
        name_mapping[candidate] = canonical
        used.add(candidate)

print("Name mapping (only changes):")
for orig, canon in name_mapping.items():
    if orig != canon:
        print(f"{orig} -> {canon}")

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_boards_normalized_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_double_boards_normalized_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    board_df["Name"] = board_df["Name"].apply(lambda x: name_mapping.get(str(x).strip(), x) if pd.notnull(x) else x)
    double_board_df["Name"] = double_board_df["Name"].apply(lambda x: name_mapping.get(str(x).strip(), x) if pd.notnull(x) else x)
    
    board_df.to_csv(board_path, index=False)
    double_board_df.to_csv(double_board_path, index=False)
    print(f"Year {year} updated with standardized names.")
# Out:
# Name mapping (only changes):
# Dr. Charles Reed -> Charles B. Reed
# Francie Frederick -> Francie A. Frederick
# Francie A. Frederick* -> Francie A. Frederick
# Monica Lozano -> Monica C. Lozano
# Frederick R. "Fred" Ruiz -> Frederick R. Ruiz
# Paul Wachter -> Paul D. Wachter
# Gerald L. Parks -> Gerald L. Parsky
# Linda Sanford -> Linda S. Sanford
# Linda S. Sanford.* -> Linda S. Sanford
# John Perez -> John A. Perez
# Edmund Gerald Brown, Jr. -> Edmund Gerald "Jerry" Brown, Jr
# Erle A. Nye -> Erle Nye
# Debra S. rarar -> Debra S. Farar
# Dr. Debra S. Farar -> Debra S. Farar
# George Gowgani -> George G. Gowgani
# Paul L. Foster. -> Paul L. Foster
# Cruz Bustamante -> Cruz M. Bustamante
# James Richard Huffines -> James R. Huffines
# Harvey Wachsman -> Harvey F. Wachsman
# Kvriakos Tsakopoulos -> Kyriakos Tsakopoulos
# Carol R. Chandler -> Carol Chandler
# Gene Stallings -> Gene C. Stallings
# Lube Fraga -> Lupe Fraga
# Robert E. Stillwell -> Robert L. Stillwell
# Colleen McHugh -> M. Colleen McHugh
# I Stanley Rogers -> J. Stanley Rogers
# Kent Schroeder -> Kent A. Schroeder
# The Hon. Delaine Eastin. -> The Hon. Delaine Eastin
# Donald M. "Don" Leebern, Jr -> Donald M. Leebern, Jr
# H. Scott Caven, Jr. -> H. Scott Caven, Jr
# Ken civens -> Ken Givens
# Elridge W. McMillanl -> Elridge W. McMillan
# Phillip R. Dixonas -> Phillip R. Dixon
# William Hauck, Jr. -> William Hauck, Jr
# R. William Hauck, Jr -> William Hauck, Jr
# Ann Goodnight -> Ann Baggett Goodnight
# Richard D'Aquin -> Richard E. D'Aquin
# Robert R. Riley -> Robert R. "Bob" Riley
# Richard F. Tucker -> Richard L. Tucker
# Willis J. Potts, Jr. -> Willis J. Potts, Jr
# The Hon. Antonio Villaraigosa -> Antonio R. Villaraigosa
# David S. Lee. -> David S. Lee
# David L. Lee -> David S. Lee
# Peter J. Taylor -> Peter Taylor
# Michael Russell -> Michael E. Russell
# Edward F. Cox -> Edward F. "Ed" Cox
# J. Wayne Hutchens -> Wayne Hutchens
# Irvin A. Roseman -> Irvin Al Roseman
# Robert F. "Robbo" Hatcher -> Robert F. Hatcher
# Robert F. "Bob" Hatcher -> Robert F. Hatcher
# Charles H. Mercer, Jr -> Charles H. Mercer, Jr.
# John F. Davis III -> John W. Davis III
# Michael L. Browne -> Michael T. Brown
# Michael H. Brown -> Michael T. Brown
# Michael Brown -> Michael T. Brown
# Robert Levy -> Robert W. Levy
# William H. Powell -> William "Gene" Powell
# William Eugene "Gene" Powell -> William "Gene" Powell
# Howard W. Roddy -> Howard Roddy
# Leslie Parks Pope. -> Leslie Parks Pope
# James W. Wilson II -> James W. Wilson III
# Finus E. St. John IV -> Finis E. St. John IV
# Robert Estrada -> Robert A. Estrada
# John W. Barnhill, Jr -> John W. Barnhill, Jr.
# W. Mansfield Jennings, Jr. -> W. Mansfield Jennings, Jr
# John J. McMahon, Jr. -> John J. McMahon, Jr
# John H. England, Jr. -> John H. England, Jr
# E. Carl Johnson -> Carl L. Johnson
# Carl L. Jonnson -> Carl L. Johnson
# Mary Ellen Roy. -> Mary Ellen Roy
# Dr. William J. Campbell -> William D. Campbell
# Robert G. Foster -> Robert Foster
# Robert F. Allen -> Robert H. Allen
# Robert Allen -> Robert H. Allen
# Thomas J. Lucero, Jr. -> Thomas J. Lucero, Jr
# Thomas J. "Tom" Lucero, Jr -> Thomas J. Lucero, Jr
# Raymond Holdsworth, Jr. -> Raymond Holdsworth, Jr
# Raymond W. "Ray" Holdsworth, Jr. -> Raymond Holdsworth, Jr
# Joseph C. Espy II -> Joseph C. Espy III
# Paul Schauer. -> Paul Schauer
# Randolph M. Ferlic, M.D -> Randolph M. Ferlic, M.D.
# Robert Phares -> Robert "Bob" Phares
# W. Louis Bissette, Jr. -> W. Louis Bissette, Jr
# Roland M. Toups. -> Roland M. Toups
# James P. Wilson -> James P. "Jim" Wilson
# James A. "Jim" Bishop -> James A. Bishop
# Paul W. Bryant, Jr. -> Paul W. Bryant, Jr
# Charles A. Haves -> Charles A. Hayes
# Danae D. DavIs -> Danae D. Davis
# Ingrid Labat -> Ingrid T. Labat
# Ben Hvneman -> Ben Hyneman
# Jud Gooch -> Judy Gooch
# Clifford H. Henry. -> Clifford H. Henry
# Ed Jernigan. -> Ed Jernigan
# Juanita P. Baranco -> Juanita Powell Baranco
# David Joel Steinberg -> David J. Steinberg
# Dr. David J. Steinberg -> David J. Steinberg
# David Mark Rubenstein -> David M. Rubenstein
# William L. Johnson -> William D. Johnson
# William Ben Johnson -> William D. Johnson
# William P. Johnson II -> William D. Johnson
# William R. Johnson -> William D. Johnson
# William D. Johnston -> William D. Johnson
# William "Bill" Johnson -> William D. Johnson
# Victoria Murphy -> Victoria M. Murphy
# Victoria M. Murphy PI -> Victoria M. Murphy
# Thomas M. Roberts -> Robert P. Thomas
# Robert P Thomas -> Robert P. Thomas
# Robert P. "Bobby" Thomas -> Robert P. Thomas
# Burley B. Mitchell, Jr. -> Burley B. Mitchell, Jr
# Ava Parker -> Ava L. Parker
# Norman Tripp -> Norman D. Tripp
# James Bradley -> James Bradley Wilson
# H. Frank Grainger -> Hiram Frank Grainger
# John Russell -> John Russell Thomas
# S. Stephen Nakashima -> S. Stephen Nakashima.
# Howard H. Leach -> Howard H. Leach.
# Rev. Edward A. Malloy, C.S.C -> Rev. Edward A. Malloy, CSC
# Rev. Edward A. Malloy, CSC. -> Rev. Edward A. Malloy, CSC
# Donald N. Boyce -> Donald Boyce
# Pedro Noguera -> Pedro Noquera
# William Edward "Bill" Haslam* -> William Edward "Bill" Haslam
# Janet Napolitano -> Janet Ann Napolitano
# John T. Lynch -> John H. Lynch
# John P. Lynch -> John H. Lynch
# John H. Lvnch -> John H. Lynch
# Angus Cooper II -> Angus R. Cooper II
# Angus R. Cooper Il -> Angus R. Cooper II
# Marshall B. Pitts, Jr. -> Marshall B. Pitts, Jr
# Michael J. Falbo -> Michael J. "Mike" Falbo
# Paul L. Fulton, Jr. -> Paul L. Fulton, Jr
# Marietta Urquhart -> Marietta M. Urquhart
# Dr. Jim Geddes -> Jim Geddes
# Bill G. Daughtridge, Jr -> Bill G. Daughtridge, Jr.
# Stephen Ludwig -> Stephen "Steve" Ludwig
# Kathleen Leavey McCarthy -> Kathleen L. McCarthy
# Robert B. Millard. -> Robert B. Millard
# Scott O. Brame -> Scott Brame
# Barbara DeVico -> Barbara F. DeVico
# Barbara F. DeVico* -> Barbara F. DeVico
# James J. "Jim" Karam -> James J. Karam
# Clifford V. Smith -> William Clifford Smith
# William Smith -> William Clifford Smith
# Hugh A. Carter, Jr -> Hugh A. Carter, Jr.
# Benjamin J. "Ben" Tarbutton III -> Benjamin Tarbutton
# Benjamin J. "Ben" Tarbutton Ill -> Benjamin Tarbutton
# Richard A. Beard III -> Richard A. "Dick" Beard III
# Richard A. "Dick" Beard Ill -> Richard A. "Dick" Beard III
# John J. Myers -> The Most Reverend John J. Myers
# The Most Reverend John J. Meyers -> The Most Reverend John J. Myers
# Harold Stokes -> Harold M. Stokes
# Harold M. Stokes. -> Harold M. Stokes
# Dr. Kerri E. Osterhaus-Houle -> Kerri Osterhaus-Houle
# George E. Cates -> George Cates
# Charles E. Wharton -> Charles Wharton
# Kenneth R. Bernard, Jr -> Kenneth R. Bernard, Jr.
# Artis Terrell, Jr. -> Artis L. Terrell, Jr
# Artis L. Terrell, Jr. -> Artis L. Terrell, Jr
# Henry M. Thomas IlI -> Henry M. Thomas III
# Gregory M. Duckett -> Gregory M. "Greg" Duckett
# Gregory M"Greg" Duckett -> Gregory M. "Greg" Duckett
# W. Clinton Rasberry, Jr -> William Clinton "Bubba" Rasberry, Jr
# W. Clinton "Bubba" Rasberry, Jr -> William Clinton "Bubba" Rasberry, Jr
# William Clinton "Bubba" Rasberry, Jr. -> William Clinton "Bubba" Rasberry, Jr
# Peter C. Meinig. -> Peter C. Meinig
# Nancy Neal -> Nancy R. Neal
# James S. Broadhurst. -> James S. Broadhurst
# Kenneth K. Calkins -> Kenneth L. Calkins
# Dr. Joseph B. Morton -> Joseph B. Morton
# Ann Quay -> Ann Quay Davis
# James r. Rothenberg -> James F. Rothenberg
# Dennis DeConcini -> Dennis W. DeConcini
# The Hon. Cynthia A. Baldwin -> Cynthia A. Baldwin
# The Honorable Cynthia A. Baldwin -> Cynthia A. Baldwin
# The Hon. Tom Loeffler -> Tom Loeffler
# A. R. Sanchez, Jr -> A. R. Sanchez, Jr.
# Eric Krasnoft -> Eric Krasnoff
# Edward Travagliantin -> Edward Travaglianti
# Steven J. Kumble. -> Steven J. Kumble
# Howard M. Lorber. -> Howard M. Lorber
# Barton Joel Winokur -> Barton J. Winokur
# Stanley T. Wang. -> Stanley T. Wang
# Phillip G. Lewis -> Philip D. Lewis
# Philip G. Lewis -> Philip D. Lewis
# Ralph E. Schey P -> Ralph E. Schey
# Nancy B. Peretsmang -> Nancy B. Peretsman
# Michael Steinhardt -> Michael H. Steinhardt
# Kurt T. Borovsky -> Kurt T. Borowsky
# Anne L. Armstrong -> Anne Armstrong
# William H. Watkins, Jr. -> William H. Watkins, Jr
# William H. Watkins, Jr . -> William H. Watkins, Jr
# James A. Stern. -> James A. Stern
# Dr. Walter Harrison -> Walter Harrison
# Myra L. Wheeler -> Myrna L. Wheeler
# James C. Mullen -> James D. Mullen
# Gerard A. Randall, Jr. -> Gerard A. Randall, Jr
# Frederick W. Pierce IV -> Frederick W. Pierce IV.
# Adam Herbert -> Adam W. Herbert
# Herbert C. Adams -> Adam W. Herbert
# Polivanna A. Stephens -> Pollyanna A. Stephens
# R. H. "Steve" Stevens, Jr. -> R. H. Stevens, Jr.
# Dorothy S. Gallagher -> Dorothy Sewell Gallagher
# Charles Q. Miller -> Charles Miller
# Charles D. Miller -> Charles Miller
# Murray L. Galinson -> Murrav L. Galinson
# Wendy L. Gramm -> Wendy Gramm
# charles Pruitt -> Charles Pruitt
# Charles "Chuck" Pruitt -> Charles Pruitt
# Dr. Charles R. "Chuck" Pruitt -> Charles Pruitt
# William H. Smith -> William G. Smith
# William J. Smith -> William G. Smith
# H. Wayne Huizenga* -> H. Wayne Huizenga
# Lawrence Boyle -> Lawrence F. Boyle
# Jim McClurg, Ph.D. -> Jim McClurg, Ph.D
# Jim McClurg. Ph.D. -> Jim McClurg, Ph.D
# Dr. Sara Jayne Steen -> Sara Jayne Steen
# Don Stansberry, J -> Don Stansberry, Jr
# Don Stansberry, Jr. -> Don Stansberry, Jr
# Charles O'Leary -> Charles J. O'Leary
# Charles S. Wilson, MD -> Charles S. Wilson, M.D
# Charles S. Wilson, M.D. -> Charles S. Wilson, M.D
# Charles Anderson, Jr. -> Charles Anderson, Jr
# Charles C. Anderson, Jr -> Charles Anderson, Jr
# Anne Holt Blackburr -> Anne Holt Blackburn
# Elizabeth A. Burmaster -> Elizabeth Burmaster
# Charles "Charlie" Amato -> Charles Amato
# Timothy F. Clare -> Timothy Clare
# Timothy F. "Tim" Clare -> Timothy Clare
# Charles H. Hassebrook -> Charles H. "Chuck" Hassebrook
# James Lawrence "Larry" Norton -> James Norton
# Rebecca D. Eisen -> Rebecca Eisen
# Robert L. Allbritton -> Robert L. Albritton
# William S. Dietrich -> William S. Dietrich II
# William S. Dietrich II. -> William S. Dietrich II
# Lindsey Davis -> G. Lindsey Davis
# Bishop G. Lindsey Davis -> G. Lindsey Davis
# John J. Fauth -> John J. Fauth IV
# John J. 'Hap' Fauth IV -> John J. Fauth IV
# John J. "Hap" Fauth IV -> John J. Fauth IV
# Robert John Abernethy -> Robert J. Abernethy
# Robert John "Bob" Abernethy -> Robert J. Abernethy
# Ray Ferrero, Jr. -> Ray Ferrero, Jr
# James M. Powers, Sr. -> James M. Powers, Sr
# Joseph L. "Joe" Neubauer -> Joseph Neubauer
# Bill W. Burgess, Jr. -> Bill W. Burgess, Jr
# David S. Gottesmar -> David S. Gottesman
# Mark A. Bovar -> Mark A. Boyar
# Jim W. Phillips, Jr. -> Jim W. Phillips, Jr
# Zachariah P. Zachariah, M.D -> Zachariah P. Zachariah
# Zachariah P. Zachariah, MD -> Zachariah P. Zachariah
# Dr. Zachariah P. Zachariah, MD -> Zachariah P. Zachariah
# Bruce Tomason -> Bruce A. Tomason
# Dr. Jack Lund Schofield -> Jack Lund Schofield
# Dr. Ruth J. Simmons -> Ruth J. Simmons
# Robert Lemon -> Robert E. Lemon
# Philip Norman "Phil" Bredesen, Jr. -> Philip Norman "Phil" Bredesen
# Philip Norman "Phil" Bredesen, Jr -> Philip Norman "Phil" Bredesen
# Malcolm Lee Sherman -> Malcolm L. Sherman
# Malcolm L. Sherman. -> Malcolm L. Sherman
# Ronald ARatner -> Ronald A. Ratner
# Joanne Leedom-Ackerma -> Joanne Leedom-Ackerman
# Lawrence L. Landr -> Lawrence L. Landry
# Patricia Harron Imbesi -> Patricia Imbesi
# Patricia H. Imbesi -> Patricia Imbesi
# Michael H. Woods -> Michael Woods
# Malcolm A. Smith -> Malcolm B. Smith
# Elizabeth Moore -> Elizabeth D. Moore
# Elizabeth D. Moore. -> Elizabeth D. Moore
# Steven N. Reenders -> Steven N. Renders
# Diane Lewis -> Diana Lewis
# Louis B. Lynn. -> Louis B. Lynn
# Charles M. Smith -> Charles E. Smith
# Liam E. McGree -> Liam E. McGee
# Liam E. McGee V.O -> Liam E. McGee
# Virgil Robinson, Jr. -> Virgil Robinson, Jr
# Alan Leventhal -> Alan M. Leventhal
# Martin Granoff -> Martin J. Granoff
# Tra J. Gumberg -> Ira J. Gumberg
# J. Timothy Shelnut -> Timothy J. Shelnut
# James D. "Jimmy" Harrel -> James D. Harrel
# Luis F. Faura -> Luis Faura
# James J. C. Haynes II. -> James J. C. Haynes II
# Robert R. "Bob" Martin -> Robert R. Martin
# Dr. Robert Martin -> Robert R. Martin
# Dr. Helen F. Giles-Gee -> Helen F. Giles-Gee
# Patrick M. Murray. -> Patrick M. Murray
# Michael Wixom -> Michael B. Wixom
# Ruben J. King-Shaw, Jr -> Ruben Jose King-Shaw, Jr
# Ruben Jose King-Shaw, Jr. -> Ruben Jose King-Shaw, Jr
# Larry R. Ellis, USA (Ret) -> GEN Larry R. Ellis, USA (Ret)
# William NeSmith, Jr -> William H. "Dink" NeSmith, Jr
# William H. "Dink" NeSmith, Jr. -> William H. "Dink" NeSmith, Jr
# Edward G. Rendell -> Edward G. "Ed" Rendell
# James Tuschman -> James M. "Jim" Tuschman
# James M. Tuschman -> James M. "Jim" Tuschman
# Walter A. Reiling, Jr -> Walter A. Reiling, Jr.
# Danni Varlan -> Danni B. Varlan
# Thomas C. Griscom -> Thomas C. "Tom" Griscom
# C. Thomas Hopkins, Jr. -> C. Thomas Hopkins, Jr
# Jack B. Jewett -> Jack Jewett
# Dr. Ed Richardson -> Ed Richardson
# Robert B. Shapiro -> Robert Shapiro
# Robert N. Shapiro -> Robert Shapiro
# Bruce S. Raynor. -> Bruce S. Raynor
# Renee J. Amoore -> Renee Amoore
# Alan Smith -> F. Alan Smith
# Donna M. Mendes Janis M. Meyer -> Janis M. Meyer
# William R. "Bill" Brody -> William R. Brody
# Joan APayden -> Joan A. Payden
# Joel I. Ferguson -> Joel Ferguson
# William E. Havemever -> William E. Havemeyer
# Henry H. Arhold -> Henry H. Arnhold
# H. Jesse Arnelle. -> H. Jesse Arnelle
# John O. "Dubby" Wynne -> John O. Wynne
# David M. Hirsch. -> David M. Hirsch
# Nancv S. Mueller -> Nancy S. Mueller
# A. Zachary Yamba. -> A. Zachary Yamba
# Anthony .J Scirica -> Anthony J. Scirica
# Daniel H. Polett. -> Daniel H. Polett
# Paula Wolft -> Paula Wolff
# Emmett L. Terrellst -> Emmett L. Terrell
# Andrea Fischer Newman.' -> Andrea Fischer Newman
# John W. "Jay" Jordan II -> John W. Jordan II
# Dr. Nancy M. Haegel -> Nancy M. Haegel
# Ronnie C. Chancon -> Ronnie C. Chan
# Steven Spielberg1 -> Steven Spielberg
# Edward S. Nelson -> Edward G. Nelson
# John A. Rich -> John W. Rich
# Ronald L. Thompson. -> Ronald L. Thompson
# Craig D. Schnuck. -> Craig D. Schnuck
# Andrew C. Taylor. -> Andrew C. Taylor
# Stephen h. Brauer -> Stephen F. Brauer
# Dorothy and David I. Schachne Dean Sheldon R. Gelman -> David I. Schachne
# Joseph D. "Joe" Swann -> Joseph D. Swann
# D. Ronald "Ron" Daniel -> D. Ronald Daniel
# Tonev J. Lister -> Toney J. Lister
# Robert A. Knox. -> Robert A. Knox
# Stephen R. Reinel -> Stephen R. Reiner
# Edgar R. Bowers. -> Edgar R. Bowers
# Michael R. Steed. -> Michael R. Steed
# Jeffrey Hayden Lynford -> Jeffrey H. Lynford
# The Hon. Christine Todd Whitman -> Christine B. Whitman
# Rev. John I. Jenkins, C.S.C -> Rev. John I. Jenkins, CSC
# Rev. E. William Beauchamp, C.S.CExecutive Vice President and -> Rev. E. William Beauchamp, CSC
# Thalia Dondero -> Thalia M. Dondero
# Cherryl T. Thomas. -> Cherryl T. Thomas
# Dr. John Edward Sexton -> John Edward Sexton
# Kenneth D. Schmidt -> Kenneth M. Schmidt
# John M. Hennessy -> John L. Hennessy
# Dr. John L. Hennessy -> John L. Hennessy
# Richard W. Lewis -> Richard A. Lewis
# Edward P. Roski, Jr. -> Edward P. Roski, Jr
# Harry J. Flynn -> The Most Reverend Harry J. Flynn
# Lyndel J. "Joe" Wishcamper -> Lyndel J. Wishcamper
# Dr. James Thomas Harris IlI -> James Thomas Harris III
# Rev. Bradley M. Schaeffer, S.J. -> Rev. Bradley M. Schaeffer, S.J
# Rev. Bradley M. Schaefer, S.J -> Rev. Bradley M. Schaeffer, S.J
# Rev. Bradley M. Schaefer, S.J. -> Rev. Bradley M. Schaeffer, S.J
# Rev. Bradley M. Schaeffer, S.J, -> Rev. Bradley M. Schaeffer, S.J
# Wendy F Murphy -> Wendy F. Murphy
# Janet D. Pearlm -> Janet D. Pearl
# Jean Flahive -> Jean M. Flahive
# Michael Truncale -> Michael J. Truncale
# Wayne Newell -> Wayne A. Newell
# Michael K. Hanna, Sr. -> Michael K. Hanna, Sr
# D. Crawford Gallimore -> Crawford Gallimore
# Steven N. Fischel -> Steven N. Fischer
# William H. "Bill" Bauer -> William Bauer
# Kennith O. Thompson -> Kennith Thompson
# Kenneth J. "Ken" Feld -> Kenneth J. Feld
# Phillip H. Case W -> Phillip H. Case
# Dr. Delores P. Aldridge -> Delores P. Aldridge
# Charles P. "Charlie" Pizzi -> Charles P. Pizzi
# Robert Buckley -> Robert R. Buckley
# Bobert G. Perry -> Robert G. Perry
# Winston J. Churchil -> Winston J. Churchill
# Winston J. "Win" Churchill -> Winston J. Churchill
# Dr. Charles Marstiller Vest -> Charles Marstiller Vest
# H_ Dale Hemmerdinger -> H. Dale Hemmerdinger
# Kenneth G. "Ken" Langone -> Kenneth G. Langone
# Roval F. Jonas -> Royal F. Jonas
# Alvin H. Clemens. -> Alvin H. Clemens
# Nicholas M. "Nick" Donofrio -> Nicholas M. Donofrio
# Mrs. Lawrence J. Matteson -> Lawrence J. Matteson
# Nancy L. FeinBlase Thomas "Tom" Golisano -> B. Thomas Golisano
# Lawrence E. Bathgate II. -> Lawrence E. Bathgate II
# Roy C. Snodgrass IlI -> Roy C. Snodgrass III
# Robert F. Wright -> Robert J. Wright
# Robert J Wright -> Robert J. Wright
# Michael L. Klowden Ivorov -> Michael L. Klowden
# Billv Joe Miles' -> Billy Joe Miles
# Robert M. Conwav -> Robert M. Conway
# Darlene V. Shiley -> Darlene Marcos Shiley
# Jerry W. Neelv -> Jerry W. Neely
# David R. "Dave" Lawson -> David R. Lawson
# Michael Lewis Ainslie -> Michael L. Ainslie
# Richard H. Sinktield -> Richard H. Sinkfield
# Jocelvn Burton -> Jocelyn Burton
# Ann Rubenstein Tischooo -> Ann Rubenstein Tisch
# Ann Rubenstein Tisch. -> Ann Rubenstein Tisch
# Dr. Richard Charles Levin -> Richard Charles Levin
# Robert M. Ward -> Robert A. Ward
# William Lynch, Jr. -> William Lynch, Jr
# Michael B. Smith -> Michael J. Smith
# Lisa P. Verble -> Lisa Verble
# Rev. Robert B. Lawton, S.J -> Rev. Robert B. Lawton, SJ
# Rev. Robert B. Lawton, SEx Officio -> Rev. Robert B. Lawton, SJ
# Rev. Robert B. Lawton, S.J. -> Rev. Robert B. Lawton, SJ
# E. John Rosenwald, Jr -> E. John Rosenwald, Jr.
# Edward P. Junker IlI -> Edward P. Junker III
# Susan R. Holliday. -> Susan R. Holliday
# Rev. Donald J. Harrington, C.M -> Rev. Donald J. Harrington, CM
# Rev. Donald J. Harrington -> Rev. Donald J. Harrington, CM
# Patricia Penrose Schieffel -> Patricia Penrose Schieffer
# Clarence Scharbauer I -> Clarence Scharbauer III
# Clarence Scharbauer IlI -> Clarence Scharbauer III
# Karen Katen -> Karen L. Katen
# Richard M. Schulze. -> Richard M. Schulze
# Rebecca Webb Wilson -> Rebecca W. Wilson
# Anthony J. Knapp, Jr. -> Anthony J. Knapp, Jr
# Dr. Robert Allyn Scott -> Robert Allyn Scott
# Keith G. Fleer Thomas Gottschalk -> Thomas A. Gottschalk
# Thomas Gottschalk -> Thomas A. Gottschalk
# Nicholas A. Sannella -> Rev. Nicholas A. Sannella
# Margaret Mary Fitzpatrick, SC -> Sister Margaret Mary Fitzpatrick, SC
# Sister Margaret Mary Fitzpatrick -> Sister Margaret Mary Fitzpatrick, SC
# Sister Margaret Mary Fitzpatrick, Sc -> Sister Margaret Mary Fitzpatrick, SC
# David K. Wilson -> David W. Wilson
# David Wilson -> David W. Wilson
# Carl Ware -> Carl H. Ware
# Robert J. Stevenish II -> Robert J. Stevenish
# Robert J. Stevenish Il -> Robert J. Stevenish
# Dr. Anthony G. Collins -> Anthony G. Collins
# Dr. Anthony G. "Tony" Collins -> Anthony G. Collins
# Richard A. Greenawall -> Richard A. Greenawalt
# Richard A. Greenawal -> Richard A. Greenawalt
# Mary Henderson -> Mary R. "Nina" Henderson
# Dr. Richard H. Brodhead -> Richard H. Brodhead
# Dr. Charles J. Dougherty -> Charles J. Dougherty
# Noble Codv -> Noble Cody
# Bishop B. Michael Watson -> B. Michael Watson
# Bishop B. Michael "Mike" Watson -> B. Michael Watson
# Dr. Anthony James Catanese -> Anthony James Catanese
# Dr. John J. DeGioia -> John J. DeGioia
# Robert Hillier -> J. Robert Hillier
# John Seazholtz -> John W. Seazholtz
# George M. Newcome -> George M. Newcombe
# Barry J. Silverman, MD -> Barry J. Silverman
# Paul Severino -> Paul J. Severino
# King Harris -> King W. Harris
# D. Tad Lowry -> D. Tad Lowrey
# The Hon. Ann Claire Williams -> Ann Claire Williams
# Ann Williams -> Ann Claire Williams
# Dr. Mary E. Lyons -> Mary E. Lyons
# Steven A. Markel -> Mark A. Stevens
# Dr. Antoine M. Garibaldi -> Antoine M. Garibaldi
# Ross Swimmer -> Ross Owen Swimmer
# Gail Schwartz. -> Gail Schwartz
# Penelope C. Hunt -> Penelepe C. Hunt
# Karl White -> Karl E. White
# Steven H. "Steve" Lipstein -> Steven H. Lipstein
# Dr. Dennis D. Berkey -> Dennis D. Berkey
# Judy Hample -> Judy G. Hample
# Dr. Judy G. Hample -> Judy G. Hample
# Don C. Schneider -> Donald C. Schneider
# James B. Williams -> James R. Williams
# James A. Williams -> James R. Williams
# James Williams Thomas, Jr -> James R. Williams
# Julle Carson -> Julie Carson
# Julie K. Carson -> Julie Carson
# Robert K. Durkee* -> Robert K. Durkee
# Bob Owens. -> Bob Owens
# Robin Robinson. -> Robin Robinson
# Fred Duval -> Fred DuVal
# Daniel Jackson -> Daniel R. Jackson
# Carolyn J. Abeita -> Carolyn Abeita
# Dr. Mark W. Huddleston -> Mark W. Huddleston
# The Most Reverend Aurthur J. Serratelli -> The Most Reverend Arthur J. Serratelli
# The Most Reverend Arthur J. Serratell -> The Most Reverend Arthur J. Serratelli
# James V. Mazzo -> James V. "Jim" Mazzo
# Michael E. Dahilig -> Michael A. Dahilig
# Elizabeth Hoadley -> Elizabeth K. Hoadley
# Raymond J. Lane -> Raymond J. "Ray" Lane
# Carol Keehan, DC -> Sister Carol Keehan, DC
# Sister Carol Keehan -> Sister Carol Keehan, DC
# Joseph D. "Joe" Neguse -> Joseph D. Neguse
# Michael M. Knetter -> Dr. Michael M. "Mike" Knetter
# Dr. Richard F. Syron -> Richard F. Syron
# Patrick T. "Pat" Stokes -> Patrick T. Stokes
# Steven L. "Steve" Rattner -> Steven L. Rattner
# Elizabeth A. Fessenden. -> Elizabeth A. Fessenden
# John G. Johnson, Jr -> John B. Johnson, Jr.
# John B. Johnson, Jr -> John B. Johnson, Jr.
# James T. Wood -> James F. Wood
# James F. "Jim" Wood -> James F. Wood
# Bobert A. Paul -> Robert A. Paul
# Ellen Bailey -> Ellen A. Bailey
# Ellen A. Bailev -> Ellen A. Bailey
# M. Douglas "Doug" Ivester -> M. Douglas Ivester
# Patricia M. Nazemetz.cos -> Patricia M. Nazemetz
# Dr. Charles R. McDonald -> Charles J. McDonald
# Dr. Floretta Dukes McKenzie -> Floretta Dukes McKenzie
# Jay Robert Pritzker -> Robert A. Pritzker
# Jay Robert "J. B." Pritzker -> Robert A. Pritzker
# Bahman Atefl -> Bahman Atefi
# Stuart S. Janney I -> Stuart S. Janney III
# Stuart S. Janney II. -> Stuart S. Janney III
# Walter D. Pinkard, Jr. -> Walter D. Pinkard, Jr
# Michael G. Fox -> Michael A. Fox
# Paul N. Leitner. -> Paul N. Leitner
# Donald J. Ulrich -> Ronald J. Ulrich
# Ronald J. Ulrich. -> Ronald J. Ulrich
# David A. Koch -> David H. Koch
# Jackson P. "Jack" Turner -> Jackson P. Turner
# William J. "Bill" Snipes -> William J. Snipes
# Gary J. Lindsay. -> Gary J. Lindsay
# Janet F. Sansone' -> Janet F. Sansone
# Janet h. Sansone -> Janet F. Sansone
# vanet F. Sansone -> Janet F. Sansone
# James S Frank -> James S. Frank
# James S. "Jim" Frank -> James S. Frank
# James S. Frankgoo -> James S. Frank
# Tahlman Krumm, Jr. -> Tahlman Krumm, Jr
# Robert M. Mahoney. -> Robert M. Mahoney
# Grace K. Fey* -> Grace K. Fey
# Thomas E. Larkin, Jr. -> Thomas E. Larkin, Jr
# Michael F. Rvan -> Michael F. Ryan
# Robert A. Hoehn -> Robert Hoehn
# Willis B. Wood, Jr. -> Willis B. Wood, Jr
# John F. O'Shaughnessy, Jr. -> John F. O'Shaughnessy, Jr
# R. Michelle Beale -> Michelle Beale
# Brownlee O. Currey, Jr. -> Brownlee O. Currey, Jr
# Joanne Fleming Haves -> Joanne Fleming Hayes
# Eugene H. Vaughan, Jr. -> Eugene H. Vaughan, Jr
# Camilla Diet Bergeron -> Camilla Dietz Bergeron
# Lawrence D. Hopkins, MD -> Lawrence D. Hopkins
# Wayne T. Smith -> K. Wayne Smith
# Harvey Saligman. -> Harvey Saligman
# Louis G. Hutt, Jr. -> Louis G. Hutt, Jr
# Peter J. Levine -> Peter H. Levine
# Judith Witsch -> Judith Nitsch
# Mack I. Whittle, Jr. -> Mack I. Whittle, Jr
# Dr. C. Edward Floyd -> C. Edward Floyd
# Hannah Fair Lee -> Hannah Lee
# Salvador Diaz-Verson, Jr. -> Salvador Diaz-Verson, Jr
# Frank E. Emory, Jr. -> Frank E. Emory, Jr
# Katherine Wilson More -> Katherine Wilson Moret
# Craig C. Matthews -> Craig G. Matthews
# Thomas S. "Tom" Richards -> Thomas S. Richards
# Thomas E. Richards -> Thomas S. Richards
# Thomas E. "Tom" Richards -> Thomas S. Richards
# Arold C. Greenberg -> Arnold C. Greenberg
# Rev. David T. Tyson, C.S.C -> Rev. David T. Tyson, CSC
# Ann winblad -> Ann Winblad
# Ann L. Winblad -> Ann Winblad
# Duane Wilson -> L. Duane Wilson
# Paul W. Mikos. -> Paul W. Mikos
# Albert R. Gamper, Jr. -> Albert R. Gamper, Jr
# Ryan C. Fowler Albert R. Gamper, Jr. -> Albert R. Gamper, Jr
# Dr. Thalia Dorwick -> Thalia Dorwick
# Carl T. Anderson -> Carl A. Anderson
# Frank B. Schmeler -> Frank R. Schmeler
# Dr. Austin E. Gore -> Austin Gore
# Edward W. Scott, Jr. -> Edward W. Scott, Jr
# John D. Miller Marilyn B. Monter -> John D. Miller
# Joseph F. "Joe" Damico -> Joseph F. Damico
# Joseph R. Perella. -> Joseph R. Perella
# Edward Shorin -> Edward E. Shorin
# Alfred R. Kahn. -> Alfred R. Kahn
# Preston D. Pinkett Ill -> Preston D. Pinkett III
# Beth Rudin DeWoodv -> Beth Rudin DeWoody
# Laurence D. "Larry" Fink -> Laurence D. Fink
# William C. "Bill" Rudin -> William C. Rudin
# Alan B. Levan as -> Alan B. Levan
# Keith W. Eckel. -> Keith W. Eckel
# Edward R. Hintz, Jr. -> Edward R. Hintz, Jr
# Louise SSams -> Louise S. Sams
# Michael E. Herman. -> Michael E. Herman
# Thomas C. Wilmot, Sr. -> Thomas C. Wilmot, Sr
# David. Burns -> David J. Burns
# Joseph P. LaSala -> Joseph P. La Sala
# Patricia Castel "Pat" Skarulis -> Patricia A. Castel
# Rev. Gerard H. Luttenberger -> Rev. Gerard H. Luttenberger, CM
# Lewis F. Gould, Jr. -> Lewis F. Gould, Jr
# Matthew K. "Matt" Rose -> Matthew K. Rose
# Lawrence S. "Larry" Bacow -> Lawrence S. Bacow
# Dr. Lawrence S. Bacow -> Lawrence S. Bacow
# Andrew M. "Andy" Alper -> Andrew M. Alper
# Thomas A. Coleman -> Thomas A. Cole
# Dr. Sanford J. Grossman -> Sanford J. Grossman
# Brother Thomas F. Giardino, SM. -> Brother Thomas F. Giardino, SM
# Bobbi McNeil.' -> Bobbi McNeil
# Steve Sisolak. -> Steve Sisolak
# Jack Fortner -> Jack L. Fortner
# Rev. Jose E. Ahumada, C.S.C -> Rev. Jose E. Ahumada, CSC
# Rev. Jose E. Ahumada, CSC. -> Rev. Jose E. Ahumada, CSC
# Steven F Leer -> Steven F. Leer
# Steven F. "Steve" Leer -> Steven F. Leer
# Dianne Philibosian -> Dianne L. Philibosian
# Willam E. B. Siart -> William E. B. Siart
# David H. Dornsife* -> David H. Dornsife
# Diana E. Murphv -> Diana E. Murphy
# Katherine G. Covle -> Katherine G. Coyle
# Barbara B. Allen -> Barbara Allen
# Mary J. Hughes -> Mary K. Hughes
# Mary K. Hughes ho -> Mary K. Hughes
# Frank A. Godchaux -> Frank A. Godchaux III
# Martha Ingram -> Martha Rivers Ingram
# Eugene D. McGurk, Jr. -> Eugene D. McGurk, Jr
# Dr. Curtis R. Carlson -> Curtis R. Carlson
# Zygmunt "Zygi" Wilf -> Zygmunt Wilf
# Kathleen Aikenhead -> Kathleen Hannon Aikenhead
# Robert H. Baker -> Robert C. Baker
# Robert C. "Bob" Baker -> Robert C. Baker
# Dennis M. Bone. -> Dennis M. Bone
# Philip K. Beachem. -> Philip K. Beachem
# W. Duncan MacMillan -> Duncan L. MacMillan
# Duncal L. MacMillan -> Duncan L. MacMillan
# Hani M.S. Farsi -> Hani M. S. Farsi
# Neils-Erik A. Andreasen -> Niels-Erik A. Andreasen
# Sharon Ryan -> Sharon G. Ryan
# Charles John Koch -> Charles John "Bud" Koch
# Alan D. Schwartz -> Alan L. Schwartz
# Mark Johnson -> Mark Chapin Johnson
# Sebastian P. Musco -> Sebastian Paul Musco
# Isaac J. Snype, Jr. -> Isaac J. Snype, Jr
# Ross J. Gillman -> Ross D. Gillman
# Dr. David J. Skorton -> David J. Skorton
# Paul M. Baiada -> Paul M. "Mel" Baiada
# Michael J. Garanzini, SJ -> Michael J. Garanzini, S.J
# Michael J. Garanzini, S.J, -> Michael J. Garanzini, S.J
# Michael J. Garanzini, S.J. -> Michael J. Garanzini, S.J
# Rev. Michael J. Garanzini, S.J. -> Michael J. Garanzini, S.J
# Rev. Michael J. Garanzini, S.J -> Michael J. Garanzini, S.J
# Rev. Scott R. Pilarz, SJ -> Rev. Scott R. Pilarz, S.J
# Rev. Scott R. Pilarz, S.J. -> Rev. Scott R. Pilarz, S.J
# Melanie Reinhold Foster -> Melanie Foster
# William T. Allen -> William T. Mullen
# Bruce Berger -> Bruce D. Berger
# Mark A. Besca -> Mark M. Besca
# John F. Russo, Sr. -> John F. Russo, Sr
# Brother Francisco T. Gonzalez, SM. -> Brother Francisco T. Gonzalez, SM
# F. James McCart III -> F. James McCarl III
# Frank Cruz -> Frank H. Cruz
# John Morrison -> John M. Morrison
# Aubrey B. Patterson Setters -> Aubrey B. Patterson
# Michael Jesselson -> Michael G. Jesselson
# John Chapple -> John H. Chapple
# Christine Lindsay Pickering -> Christine Lindsay Pickering, CPA
# Paul J. Spina, Jr. -> Paul J. Spina, Jr
# Robert E. "Bobby" Lowder -> Robert E. Lowder
# Susan McManama Gianinno -> Susan M. Gianinno
# Andrea L. Berry -> Terry L. Andreas
# J. Robert Brown -> Robert J. Brown
# Robert A. Brown -> Robert J. Brown
# Louis Perimutter -> Louis Perlmutter
# Debra L Lee -> Debra L. Lee
# Fredric B. Garonzik. -> Fredric B. Garonzik
# Dand E. McKinney -> David E. McKinney
# John G. Rangos, Sr. -> John G. Rangos, Sr
# John D. Correntia. -> John D. Correnti
# John J. MacK -> John J. Mack
# Henry L. Bowden, Jr. -> Henry L. Bowden, Jr
# James F. Heekin, Jr -> James F. Heekin, Jr.
# Paul L. Ceias -> Paul L. Cejas
# Arthur J. "Jerry" Kremer -> Arthur J. Kremer
# Fidelis N. Umeh. -> Fidelis N. Umeh
# Fidelis N. Umehsid -> Fidelis N. Umeh
# Robert A. Corog -> Robert A. Cornog
# David L. Johnston -> David L. Johnson
# David M. Johnson -> David L. Johnson
# Kim E. Lvttle -> Kim E. Lyttle
# Jeanette G. Grasseli Brown -> Jeanette G. Grasselli Brown
# Jeanette Grasseli Brown -> Jeanette G. Grasselli Brown
# Jeanette Grasselli Brown -> Jeanette G. Grasselli Brown
# William F. Hecht. -> William F. Hecht
# William F Hecht -> William F. Hecht
# G. Marshall Butler, Sr -> G. Marshall Butler
# William H. Havden -> William H. Hayden
# Manuel "Manny" Sanchez -> Manuel Sanchez
# Carl T. Shaffer. -> Carl T. Shaffer
# Carl T. Shafter -> Carl T. Shaffer
# Robert D. Metzgar* -> Robert D. Metzgar
# Samuel E. Hayes, Jr. -> Samuel E. Hayes, Jr
# George Campbell, Jr. -> George Campbell, Jr
# George Campbell, Jr., Ph.D. -> George Campbell, Jr
# George Campbell, Jr., Ph.D -> George Campbell, Jr
# George Campbell, Jr., PhD -> George Campbell, Jr
# Dr. George Campbell, Jr., PhD -> George Campbell, Jr
# Dennis J. Browniee -> Dennis J. Brownlee
# John D. Hardin, Jr. -> John D. Hardin, Jr
# Thomas A. Renvi -> Thomas A. Renyi
# Thomas J. Sharkey -> Thomas Sharkey
# Robert A Rovner -> Robert A. Rovner
# Richard P. Strubel.* -> Richard P. Strubel
# Robert A. Fischer, Jr. -> Robert A. Fischer, Jr
# William McIntyre -> William Mcintyre
# Marie K. Abram -> Marie K. Abrams
# Cathleen P. "Cathie" Black -> Cathleen P. Black
# Philip J. "Phil" Purcell III -> Philip J. Purcell III
# Terrence J. McGinn -> Terrence J. McGlinn
# Suzanne M. Nora Johnson -> Suzanne Nora Johnson
# Steve Turbo -> Steve Turnbo
# Rosemary Skrupa -> Rosemark Skrupa
# James A. Haslam II -> James A. Haslam
# Charles M. Peccolo, Jr -> Charles M. Peccolo
# Johnnie D. Amonette -> Johnnie Amonette
# Eugene B. Shanks, Jr. -> Eugene B. Shanks, Jr
# Eugene B. Shanks, JrRichard H. Sinkfield -> Eugene B. Shanks, Jr
# John J. "J. J." Britton -> John J. Britton
# Dan Wassong -> Dan K. Wassong
# Morton P Hyman -> Morton P. Hyman
# Robert J. Morrissey R. Michael Murray, Jr -> Robert J. Morrissey
# Robert F. Morrissey -> Robert J. Morrissey
# Gail J. McGover -> Gail J. McGovern
# Jose de Jesus Legaspi. -> Jose de Jesus Legaspi
# Samuel T. Hubbard, Jr. -> Samuel T. Hubbard, Jr
# Kevin Kennedy -> Kevin E. Kennedy
# Kevin J. Kennedy -> Kevin E. Kennedy
# Leslie E. Goodman -> Leslie Eugene Goodman
# Robert Baldini -> Robert E. Baldini
# Robert E. "Bob" Baldini -> Robert E. Baldini
# Gerald P. "Jerry" Buccino -> Gerald P. Buccino
# Dr. Gerald P. "Jerry" Buccino -> Gerald P. Buccino
# Thomas J. Groark, Jr. -> Thomas J. Groark, Jr
# Ray Irani -> Ray R. Irani
# Dr. Ray R. Irani -> Ray R. Irani
# Thomas B. McTeer, Jr -> Thomas B. McTeer, Jr.
# George L. Engelke, Jr. -> George L. Engelke, Jr
# The Hon. Steve Adams. -> The Hon. Steve Adams
# Joan S. Girgus. -> Joan S. Girgus
# Leon M. Pollack. -> Leon M. Pollack
# Garv D. Cohn -> Gary D. Cohn
# Rodney A. Grove. -> Rodney A. Grove
# Dr. David J. Mitchell -> David Mitchell
# G. Bradley "Brad" Cole -> G. Bradley Cole
# Wayne B. Lowell -> Wayne Lowell
# Stanley "Stan" Jantz -> Stanley Jantz
# Dr. Allan G. Kavalich -> Allan Kavalich
# Thomas P. Glvnn -> Thomas P. Glynn
# Barry S. Sterlicht -> Barry S. Sternlicht
# Theodore L. Schroeder. -> Theodore L. Schroeder
# Theodore LSchroeder -> Theodore L. Schroeder
# Dr. Gregory L. Eastwood -> Gregory L. Eastwood
# James L. "Jim" Bildner -> James L. Bildner
# Karen R. Wilkinson1 W -> Karen R. Wilkinson
# Loretta L. Sanchez -> Loretta Sanchez
# William E. Shack, Jr. -> William E. Shack, Jr
# Dr. Alvin Trotter -> Alvin Trotter
# Dr. Alvin T. Trotter -> Alvin Trotter
# Gary Roboff -> Gary S. Roboff
# Dennis M. Dimitri -> Dennis Dimitri
# Karel K. Czanderna' -> Karel K. Czanderna
# Dr. Karel K. Czanderna -> Karel K. Czanderna
# Esta E. Stecheras -> Esta E. Stecher
# Fave Wattleton -> Faye Wattleton
# Kenneth A. "Ken" Goldman -> Kenneth A. Goldman
# Dr. Donna M. Carroll -> Donna M. Carroll
# Sylvester McClearnr -> Sylvester McClearn
# Linda Diane Rabbit -> Linda Diane Rabbitt
# Allan From -> I. Allan From
# Mike Alleyow -> Mike Alley
# Meredith Strom Gunter -> Meredith Strohm Gunter
# Mariorie M. Fisher -> Marjorie M. Fisher
# Dr. Rajendra Singh -> Rajendra Singh
# Patrick Wong -> Patrick Y. Wong
# John Kanas -> John Adam Kanas
# John Adam Kanas. -> John Adam Kanas
# Bonald A. Okum -> Ronald A. Okum
# Frank J. Hogan III. -> Frank J. Hogan III
# Ned W. Bechtold -> Ned W. Bechthold
# Lawrence K. Fish* -> Lawrence K. Fish
# Barrie B. Zesiger -> Barrie R. Zesiger
# W. Louis Sands. -> W. Louis Sands
# Carlos Ortiz -> Carlos G. Ortiz
# Rose Cali -> Rose C. Cali
# Norma J. Clavton -> Norma J. Clayton
# Norma B. Clayton -> Norma J. Clayton
# Dr. Nancy A. Garvey -> Nancy A. Garvey
# Joshua Sapan -> Joshua W. Sapan
# Joshua W. "Josh" Sapan -> Joshua W. Sapan
# Dennis K. Pawley -> Dennis Pawley
# John L. Schaefer -> John P. Schaefer
# Jackson P. "Jack" Tai -> Jackson P. Tai
# James W. Crownover.* -> James W. Crownover
# Brian H. Hall. -> Brian H. Hall
# Bran H. Hall -> Brian H. Hall
# Joseph M. Lobozzo II. -> Joseph M. Lobozzo II
# Robert D. Wayland-Smith -> Robert Wayland-Smith
# Wolfgang Pfizenmaier. -> Wolfgang Pfizenmaier
# Sandra A. Parker ****  . -> Sandra A. Parker
# Sandra A. Parker. -> Sandra A. Parker
# Iris Martinez-campbell -> Iris Martinez-Campbell
# Michael A. Dritz. -> Michael A. Dritz
# Nancy Cantor -> Nancy Ellen Cantor
# Patrick .J O'Connor.. -> Patrick J. O'Connor
# Mitchell .L Morgan -> Mitchell L. Morgan
# Ronald C. "Ron" Parker -> Ronald C. Parker
# John W. Rogers, Jr. -> John W. Rogers, Jr
# John R. Haley. -> John R. Haley
# Sister Francis Marie Thrailkill, OSU3 -> Sister Francis Marie Thrailkill, OSU
# Andrew F. Veresr -> Andrew F. Veres
# R. R. M. Carpenter -> R. R. M. Carpenter III
# R. R. M. Carpenter I -> R. R. M. Carpenter III
# A. R. M. Carpenter III -> R. R. M. Carpenter III
# Twin G. Burton III -> Irwin G. Burton III
# Irwin G. Burton IlI -> Irwin G. Burton III
# Everett Toomey -> Everett C. Toomey
# Donald Frahm -> Donald R. Frahm
# Gregor G. Peterson -> Gregory G. Petersen
# J. Christopher "Chris" Reyes -> J. Christopher Reyes
# Kathleen Lagoria Jansen -> Kathleen Lagorio Janssen
# Kathleen Lagorio Jansen -> Kathleen Lagorio Janssen
# George Nicholas Beckwith III -> G. Nicholas Beckwith III
# The Very Reverend Monsignor Lawrence Purcell -> Monsignor Lawrence Purcell
# R. Donna M. Bavtop -> R. Donna M. Baytop
# R. Donna M. Baytop. -> R. Donna M. Baytop
# Darla Moore -> Darla D. Moore
# Lora Y. Reed -> Lorna Y. Reed
# Laurence E. LeJeune -> Laurence LeJeune
# William H. Gates -> William H. Gates II
# William H. Gates I. -> William H. Gates II
# Robert McCarthy -> Robert B. McCarthy
# Robert J. "Bob" McCarthy -> Robert B. McCarthy
# Peter F. Lamb -> Peter F. H. Lamb
# Walter R. Peterson -> The Honorable Walter R. Peterson
# William W. Featheringil -> William W. Featheringill
# Dr. Carol S. Shapiro -> Carol S. Shapiro
# Deborah Lambert -> Deborah D. Lambert
# Kenneth M. Miller -> Kenneth D. Miller
# Kenneth V. Miller -> Kenneth D. Miller
# Maxine Clark -> Maxine K. Clark
# Arold B. Zetcher -> Arnold B. Zetcher
# Harry J. Seigle. -> Harry J. Seigle
# Dr. Ira Harkavy -> Ira Harkavy
# Paul S. Beideman. -> Paul S. Beideman
# Dr. John L. LaMattina -> John L. LaMattina
# Roland Betts -> Roland W. Betts
# Barbara J. Randali -> Barbara J. Randall
# Peter T. Paul. -> Peter T. Paul
# Virginia Nord Barbato -> Virginia N. Barbato
# Paul Folino -> Paul F. Folino
# Jean E. spence -> Jean E. Spence
# Andrew H. TIsch -> Andrew H. Tisch
# David Zalaznick -> David W. Zalaznick
# Irene Blecker Rosenfeld -> Irene B. Rosenfeld
# Abbie Dean. -> Abbie Dean
# Clarence G. "C.G." Newsome -> Clarence G. Newsome
# Richard H. Fink -> Richard H. Frank
# Richard J. Franke -> Richard H. Frank
# Kasim Reed -> M. Kasim Reed
# The Hon. L. Douglas Wilder -> L. Douglas Wilder
# The Honorable L. Douglas Wilder -> L. Douglas Wilder
# Brad Eric SchelerL -> Brad Eric Scheler
# Richard P Nespola -> Richard P. Nespola
# Ronald E. Deal -> Ronald E. Daly
# Rev. James G. Gartland, S.J. -> Rev. James G. Gartland, S.J
# Dr. Kirk D. Kolenbrander -> Kirk D. Kolenbrander
# Marjorie M.T. Yang -> Marjorie M. T. Yang
# Patrick G. LeFore -> Patrick G. LePore
# Charles R. Dees, Jr. -> Charles R. Dees, Jr
# Dr. Charles R. Dees, Jr -> Charles R. Dees, Jr
# Thomas W. Barron -> Thomas A. Barron
# Nancy Fein -> Nancy L. Fein
# Nick Petroni -> Nick L. Petroni
# M. William Howard, -> Rev. M. William Howard, Jr
# M. William Howard, Jr -> Rev. M. William Howard, Jr
# Rev. M. William Howard, Jr. -> Rev. M. William Howard, Jr
# Jonathon Holtz -> Jonathon J. Holtz
# Peter P. Bermont -> Peter L. Bermont
# William R. O'Reilly, Jr -> William R. O'Reilly, Jr.
# Dave Fitzgerald -> David Fitzgerald
# Daryl Ward -> Rev. Daryl Ward
# Richard J. Pfleger -> Richard Pfleger
# Paul H. Moseley -> Paul Moseley
# Dr. Mary Sue Coleman -> Mary Sue Coleman
# Dr. Thomas G. Burish -> Thomas G. Burish
# Howard Koff -> Howard M. Koff
# Marlee S. Myers -> Marlee Myers
# James A. "Jim" Yance -> James A. Yance
# Timothy P. Flynn* -> Timothy P. Flynn
# Robert E. Lorton -> Robert E. Lorton III
# Arthur H. McElroy -> Arthur H. "Chip" McElroy II
# Timothy T. Brady -> Timothy C. Brady
# Devon Bruce -> Devon C. Bruce
# Robert Sperling -> Robert Y. Sperling
# Niranjan Shah -> Niranjan S. Shah
# Lawrence Eppley -> Lawrence C. Eppley
# James Dowe, Jr. -> P. James Dowe, Jr.
# P. James Dowe, Jr -> P. James Dowe, Jr.
# John M. Carnahan -> John M. Carnahan III
# Dr. Jason Geddes -> Jason Geddes
# William G. Wilson -> William M. Wilson
# James Danella -> James D. Danella
# Donna Lee Dubinsky -> Donna L. Dubinsky
# Elbridge H. Stuart I -> Elbridge H. Stuart III
# Richard Cohen -> Richard D. Cohen
# Jonathan M. Nelson -> Jonathan Milton Nelson
# George I. Majoros, Jr. -> George I. Majoros, Jr
# Thomas F. McKee. -> Thomas F. McKee
# Joseph A. Sabatini. -> Joseph A. Sabatini
# Brian Rogers -> Brian C. Rogers
# Brian D. Rogers -> Brian C. Rogers
# Stephen Friedman -> Stephen J. Friedman
# Jeffrey Harris -> Jeffrey K. Harris
# L. F. "Rick" Francis -> L. Frederick "Rick" Francis
# Mark W. Buck, Jr -> Mark W. Buyck, Jr
# Mark W. Buyck, Jr. -> Mark W. Buyck, Jr
# Michele Engemann -> Michele Dedeaux Engemann
# Al Williams -> Alex Williams
# Robert L. Peeler. -> Robert L. Peeler
# James F. Flaherty III -> James F. "Jay" Flaherty III
# James P. Flaherty -> James F. "Jay" Flaherty III
# Ronald L. Fowler -> Ronald L. "Ron" Fowler
# William F J. "Bill" Ardinger -> William F. J. "Bill" Ardinger
# Charles B. "Charlie" Edwards -> Charles "Charlie" Edwards
# Anthony M. laniero -> Anthony M. Laniero
# Glen D. Johnson, Jr. -> Glen D. Johnson, Jr
# Dr. Glen D. Johnson, Jr -> Glen D. Johnson, Jr
# Deryck Palmer -> Deryck A. Palmer
# Richard L. Thompson -> Richard L. "Dick" Thompson
# James D. Montgomery -> James D. Montgomery, Sr
# James D. Montgomery, Sr . -> James D. Montgomery, Sr
# Robert T. Blakely III -> Robert J. Blakely
# Pamela "Pam" Stewart -> Pamela Stewart
# Samuel W. Collins -> Samuel W. "Sam" Collins
# Maria Furman -> Maria D. Furman
# Willie D. Davis -> Will D. Davis
# Ronald Rallis, Sr. -> Ronald Rallis, Sr
# Rosemarie I. "Rosie" Avila -> Rosemarie Avila
# Gorden Rombergei -> Gorden Romberger
# Rev. William P. Leahy, SJ -> Rev. William P. Leahy, S.J
# Rev. William P. Leahy, S.J. -> Rev. William P. Leahy, S.J
# Thomas P. O'Neill III. -> Thomas P. O'Neill III
# J. Kenneth Menges, Jr -> J. Kenneth Menges, Jr.
# Tod S. Johnson. -> Tod S. Johnson
# James G. Taylor -> James W. Taylor
# Erroll B. Davis, Jr. -> Erroll B. Davis, Jr
# David A. Couiter -> David A. Coulter
# Richard W. "Dick" Pogue -> Richard W. Pogue
# James L. Ferman, Jr. -> James L. Ferman, Jr
# John J. Cook, Jr. -> John J. Cook, Jr
# Thomas A. "Tom" Reynolds III. -> Thomas A. Reynolds III
# Thomas A. "Tom" Reynolds III -> Thomas A. Reynolds III
# Thomas A. "Tom" Reynolds Ill -> Thomas A. Reynolds III
# Thomas F. Allgood, Sr -> Thomas F. Allgood, Sr.
# S. William Clark, Jr. -> s. William Clark, Jr.
# Harold P Freeman -> Harold P. Freeman
# Vernon E. Jordan, Jr. -> Vernon E. Jordan, Jr
# Edward L. "Ed" Kaplan -> Edward L. Kaplan
# William F. Ward, Jr. -> William F. Ward, Jr
# William F. Ward, JrChristopher Watson -> William F. Ward, Jr
# Frank E. Walsh, Jr. -> Frank E. Walsh, Jr
# Rev. Robert A. Wild, SJ -> Rev. Robert A. Wild, S.J
# Rev. Robert A. Wild, S.J. -> Rev. Robert A. Wild, S.J
# Robert C. Goddard Ill -> Robert C. Goddard III
# Spencer B. King II -> Spencer B. King III
# Douglas E. Burns -> Douglas Burns
# Robert H. Rawson, Jr -> Robert H. Rawson, Jr.
# Kathleen M. Matteo wal -> Kathleen M. Matteo
# F. Howard Walsh, Jr. -> F. Howard Walsh, Jr
# F Howard Walsh, Jr -> F. Howard Walsh, Jr
# Richard L. Holmes -> Richard Holmes
# Marshall I. Wais, Jr -> Marshall I. Wais, Jr.
# Rechard A. Abdoo -> Richard A. Abdoo
# Margaret Cavanaugh -> Margaret A. Cavanaugh
# Dr. Margaret A. Cavanaugh -> Margaret A. Cavanaugh
# Gayle W. Strange -> Gayle Strange
# Richard C. "Dick" Notebaert -> Richard C. Notebaert
# William J. Shaw. -> William J. Shaw
# William J. "Bill" Shaw -> William J. Shaw
# William Kane Reilly -> William F. Reilly
# Donald E. Smith -> Donald J. Smith
# Roy E. "Gene" Bell -> Roy E. Bell
# Harry G. McNeely, Jr. -> Harry G. McNeely, Jr
# William F. Fisher, Jr. -> William F. Fisher, Jr
# J. Lawrence "Larry" Wilson -> J. Lawrence Wilson
# William W. Bain, Jr. -> William W. Bain, Jr
# James Vincent O'Donnell -> James V. O'Donnell
# James V. "Jim" O'Donnell -> James V. O'Donnell
# Timothy C. "Tim" Forbes -> Timothy C. Forbes
# Leslie G. "Les" McCraw -> Leslie G. McCraw
# Robert FX. Sillerman -> Robert EX. Sillerman
# Robert F.X. Sillerman -> Robert EX. Sillerman
# Robert F. X. Sillerman -> Robert EX. Sillerman
# Othniel H. Wienges, Jr -> Othniel H. Wienges, Jr.
# Robert A. Belfer. -> Robert A. Belfer
# R. Michael Murray, Jr. -> R. Michael Murray, Jr
# Cecilia Presley -> Cecelia Presley
# Joan E. Spero* -> Joan E. Spero
# Chilton D. Varner. -> Chilton D. Varner
# Chilton Davis Varner -> Chilton D. Varner
# Bjermar K. Hermansen -> Bjernar K. Hermansen
# Biornar K. Hermansen -> Bjernar K. Hermansen
# Bjornar K. Hermansen -> Bjernar K. Hermansen
# Gerald R. Blaszczak, S.J -> Rev. Gerald R. Blaszczak, SJ
# Pamela P. "Pam" Flaherty -> Pamela P. Flaherty
# George L. Bunting, Jr -> George L. Bunting, Jr.
# William W. Crouse III. -> William W. Crouse III
# Michael Leyden -> Michael R. Leyden
# Thomas C. Black -> Thomas B. Black
# Richard J. Kogan -> Richard Jay Kogan
# Richard Jay Kogan'su -> Richard Jay Kogan
# Janet C. Rutledge -> Janet Caroline Rutledge
# Michael P. Morely -> Michael P. Morley
# Dorothy M. Stanait -> Dorothy M. Stanaitis
# Larry Rinehart -> Larry M. Rinehart
# Frank Caprio -> Frank T. Caprio
# John C. von Lehe, Jr. -> John C. von Lehe, Jr
# Jill Derby -> Jill Talbot Derby
# L. Hall Hardaway, Jr -> L. Hall Hardaway, Jr.
# Andrew B. Benedict, Jr. -> Andrew B. Benedict, Jr
# Cal Turner, Jr. -> Cal Turner, Jr
# John F. Morgan -> John Morgan
# John G. Morgan -> John Morgan
# John Dorgan -> John Morgan
# CAPT Robert G. Darling, USN.! -> CAPT Robert G. Darling, USN
# Jeffrey A. "Jeff" Sine -> Jeffrey A. Sine
# Glynn C.W. Scott -> Glynn Scott
# Gerrv D. Karst -> Gerry D. Karst
# Francis A. Dovle -> Francis A. Doyle
# Carol B. Saivetz -> Carol R. Saivetz
# Carol R. Saivetz. -> Carol R. Saivetz
# Dr. Carol R. Saivetz -> Carol R. Saivetz
# Cardinal Justin Rigal -> Cardinal Justin Rigali
# Very Rev. David M. O'Connell, C.MOfficio -> David M. O'Connell, CM
# Very Rev. David M. O'Connell, CM -> David M. O'Connell, CM
# Rev. David M. O'Connell, CM -> David M. O'Connell, CM
# The Very Reverend David M. O'Connell, CM -> David M. O'Connell, CM
# The Most Reverend David M. O'Connell, CM -> David M. O'Connell, CM
# Gail E. Torreano -> Gail F. Torreano
# Alexander B. "Alex" Cummings, Jr -> Alexander B. Cummings, Jr
# Sumner B. Tilton, Jr. -> Sumner B. Tilton, Jr
# Daniel C. Heintzelman. -> Daniel C. Heintzelman
# Daniel C. "Dan" Heintzelman -> Daniel C. Heintzelman
# Bayard D. Clarkson -> Bayard D. Clarkson, Jr
# Bayard D. Clarkson, Sr -> Bayard D. Clarkson, Jr
# Bayard D. Clarkson, Sr., M.D -> Bayard D. Clarkson, Jr
# Bayard D. Clarkson, Sr., M.D. -> Bayard D. Clarkson, Jr
# Bayard D. Clarkson, Jr., MD -> Bayard D. Clarkson, Jr
# Dr. Bayard D. Clarkson, Sr., MD -> Bayard D. Clarkson, Jr
# Dr. Bayard D. Clarkson, Jr., MD -> Bayard D. Clarkson, Jr
# Vikram S. Pandit * -> Vikram S. Pandit
# Dr. Vikram S. Pandit -> Vikram S. Pandit
# John J. Donahoe Il -> John J. Donahoe II
# Jose E. Fernandez -> Jose W. Fernandez
# Jose Rafael Fernandez -> Jose W. Fernandez
# Jose Enrique Fernandez -> Jose W. Fernandez
# Jose Antonio Fernandez Carbajal -> Jose W. Fernandez
# William C. Warren III -> William C. Warren IV
# William C. "Bill" Warren IV -> William C. Warren IV
# Dr. William C. Warren IV, MD -> William C. Warren IV
# Richard J. "Rick" Buoncore -> Richard J. Buoncore
# Michael J. "Mike" Cosgrove -> Michael J. Cosgrove
# Thomas P. Salice* -> Thomas P. Salice
# Peter G. Cooper -> Peter C. Cooper
# William F. "Bill" Lee -> William F. Lee
# Jesse Norman -> Jessye Norman
# Wayman F. Smith I -> Wayman F. Smith III
# Wayman F. Smith -> Wayman F. Smith III
# Wavman F. Smith III -> Wayman F. Smith III
# S. Andrew Banks -> Andrew J. Banks
# Dennis E. Singleton -> Dennis E. Singleton III
# Dennis E. Singleton II -> Dennis E. Singleton III
# Dennis E. Singleton IlI -> Dennis E. Singleton III
# Tara Stacom -> Tara I. Stacom
# Tara I. Stacoma -> Tara I. Stacom
# Michael D. Zisman. -> Michael D. Zisman
# Dr. Michael D. Zisman -> Michael D. Zisman
# Caro Allen -> Carol Allen
# Walter R. Rhodes -> Walter Rhodes
# Jeffrey L. "Jeff" Glassman -> Jeffrey L. Glassman
# James E. Janz -> James F. Janz
# Garv G. White -> Gary G. White
# Dr. Susan A. Cole -> Susan A. Cole
# James J. Coleman, Jr. -> James J. Coleman, Jr
# J. Robert Kerrev -> J. Robert Kerrey
# J. Robert "Bob" Kerrey -> J. Robert Kerrey
# Constance siver -> Constance Silver
# Constance M. Silver -> Constance Silver
# Anthony "Tony" Welters -> Anthony Welters
# James A. "Jim" Hixon -> James A. Hixon
# Conrad M. Hallr -> Conrad M. Hall
# John H. Broadbent, Jr. -> John H. Broadbent, Jr
# Jeffrey L. "Jeff" Kodosky -> Jeffrey L. Kodosky
# Eric Johnson -> Eric G. Johnson
# Eric G. Johnson. -> Eric G. Johnson
# Essie L. Calhounmid -> Essie L. Calhoun
# Essie L. Calhoun McDavid -> Essie L. Calhoun
# Rev. John W. Gouldrick -> Rev. John W. Gouldrick, CM
# Mariann Byerwalter! -> Mariann Byerwalter
# Joyce Hergenhann -> Joyce Hergenhan
# Jovce Hergenhan -> Joyce Hergenhan
# Deborah R. "Deb" Jospin -> Deborah S. Jospin
# Stephen M. Glodek, S.M -> Brother Stephen M. Glodek, SM
# Stephen M. Glodek, SM -> Brother Stephen M. Glodek, SM
# John K. Wallace, Jr -> John E. Wallace, Jr
# John E. Wallace, Jr. -> John E. Wallace, Jr
# H. Wesley Towers, Jr. -> H. Wesley Towers, Jr
# John I. Harris -> John T. Harris
# Jean-Pierre van Roy -> Jean-Pierre van Rooy
# Marve Anne Fox -> Marye Anne Fox
# Dr. Marye Anne Fox -> Marye Anne Fox
# Enrique Hernandez, Jr -> Enrique "Rick" Hernandez, Jr.
# Enrique Hernandez, Jr. -> Enrique "Rick" Hernandez, Jr.
# Enrique "Rick" Hernandez, Jr -> Enrique "Rick" Hernandez, Jr.
# Catherine D. DeAngelis, M.D. -> Catherine D. DeAngelis, M.D
# Catherine D. "Cathy" DeAngelis, MD -> Catherine D. DeAngelis, M.D
# Jay Costa, Jr -> Jay Costa, Jr.
# William E. Trueheart. -> William E. Trueheart
# Lee H. Noble -> H. Lee Noble
# James P. Nix -> The Honorable James P. Nix
# John W. Snow -> John R. Snow
# John J. Snow -> John R. Snow
# James Irosper -> James Trosper
# James Trosoer -> James Trosper
# Howard Willson. -> Howard Willson
# Dr. Howard T. Willson -> Howard Willson
# Judson Randolph -> Judson G. Randolph
# Judson G. Randolph, MD -> Judson G. Randolph
# James K. Anderson -> James A. Anderson
# Dr. John C. Doswell II -> John C. Doswell II
# Lelia J. Farr -> Lelia B. Farr
# Arold W. Donald -> Arnold W. Donald
# John D. Weil. -> John D. Weil
# Thomas R. Von der Abe, Sr -> Thomas R. Von Der Ahe, Sr
# Thomas R. Von Der Ahe, Sr. -> Thomas R. Von Der Ahe, Sr
# Jerome L. Davis -> Jerome Davis
# Carol Stewart Hawkins -> Carol Hawkins
# William Billard -> William G. Billard
# Pierre Richard Prosper -> Pierre-Richard Prosper
# Archie G. Co. -> Archie G. Co
# Kenneth B. Chance. -> Kenneth B. Chance
# Dr. Marilyn French Hubbard -> Marilyn French Hubbard
# Dr. Sam R. Kottamasu -> Sam R. Kottamasu
# Dr. James L. Doti -> James L. Doti
# George D. DiRado -> George DiRado
# Peter Klein -> Peter D. Klein
# Dr. Lawrence J"Larry" Delaney -> Lawrence J. Delaney
# Mary Joy Pizzella -> Mary Joy "M J" Pizzella
# Dr. Kenneth A. Forde -> Kenneth A. Forde
# Dr. Philip R. Reilly -> Philip R. Reilly
# Paula Hannawav Crown -> Paula Hannaway Crown
# Dr. Thomas M. "Tom" Gorrie -> Thomas M. Gorrie
# ...
# Barry K. Robinson. -> Barry K. Robinson
# John C. Oliver III. -> John C. Oliver III
# Linda L. Cartright -> Linda L. Cartwright
# Obie Snider. -> Obie Snider
# Casimir Skrzypezak -> Casimir Skrzypczak
# Casimir S. Skrzypczak -> Casimir Skrzypczak
# Richard O. Scribner -> Richard D. Scribner
# D. William Moreau, Jrs -> D. William Moreau, Jr
# Robert P. Bozzone a -> Robert P. Bozzone
# Robert Oscar Swanson -> Robert Swanson
# Frederick R. Lummis, J -> Frederick R. Lummis, Jr
# Raymond Brochstein -> Raymond Brockstein
# Constantine S. Nicandros -> Constatine S. Nicandros
# Robert W. Kober. -> Robert W. Kober
# Jorge A.G. Rivas. -> Jorge A.G. Rivas
# Melvin R. Primas, Jr -> Melvin R. Primas, Jr.
# John Ruvolo -> John D. Ruvolo
# Msgr. David A. Rubino -> Rev. Msgr. David A. Rubino
# Most Rev. Vincent DePaul Breen -> Most Rev. Vincent D. Breen
# Eleanor H. McMahon -> Eleanor McMahon os
# Eleanor McMahon -> Eleanor McMahon os
# Leonard Smith Coleman, Jr. -> Leonard Smith Coleman, Jr
# John S. Brewster -> John Brewster
# George T. Wilkins, Jr. -> George T. Wilkins, Jr
# Sr. Augustine D. Towey -> Eugene J. SullivanBr. Augustine D. Towey
# Douglas M. Browning -> Douglas M. Brown
# The Hon. John E. Holt-Harris -> The Hon. John E. Holt-Harris, Jr
# James H. Shacklett -> James H. Shacklett III
# S. Patrick Woodson III -> S. Patrick Woodson
# Nancy E. Jones -> Nancy C. Jones
# Robert Legold -> Robert Legvold
# Stanley G. Mathews, SM -> Stanley G. Mathews, S.M
# Ronald Mason, Jr -> Ronald Mason, Jr.
# John J. Moder, SM -> John J. Moder, S.M
# S. Lee Frankel, Jr. -> S. Lee Frankel, Jr
# Terri Trotter ABANANADA -> Terri Trotter
# Elissa Platter -> Elissa Plattner
# T. W. Samuels, Jr -> T. W. Samuels, Jr.
# Gary E. Johnson -> Gary Johnson
# James B. Garland -> The Hon. James B. Garland
# Sue W. Cole -> Sue Cole
# JoAnne S. Drane -> JoAnne Drane
# JoAnne Smart Drane -> JoAnne Drane
# Alfred P. Carlton, Jr. -> Alfred P. Carlton, Jr
# Ray H. Siegfried II -> Ray H. Siegrfried II
# Rev. Ernest Bartell, CSC -> Rev. Ernest Bartell, C.S.C.
# Alfred C. DeCrane, Jr -> Alfred C. DeCrane, Ji
# G. T. Blankenship -> G. T. Blakenship
# Thomas R. Coderre -> Tom R. Coderre
# Gordon D. Fox -> Gordon Fox
# Most Rev. Robert H. Brom -> Robert Brom
# Robert H. Brom -> Robert Brom
# Sr. Gertrude Patch, RSCJ -> Sr. Gertrude Patch, R.S.C.J
# Sr. Barbara Dawson, RSCJ -> Sr. Barbara Dawson, R.S.C.J.
# William C. Allen -> William Allen
# Richard J. Stegemeie -> Richard J. Stegemeier
# Forrest N. Shumwai -> Forrest N. Shumway
# Leonard R. Fuller -> Leonard L. Fuller
# Linda D. Maudlin -> Linda Maudlin
# Alfred E. Mann -> Alfred Mann
# The Hon. Isabel Gomez. -> The Hon. Isabel Gomez
# Arnold P. Mikulay -> Arold P. Mikulay
# Ernest S. Micek -> Ernest Micek.
# Michael W. Cashman, Sr -> Michael W. Cashman, Sr.
# Ronald R. Langenderfer -> Ronald Langenderfer
# Paula A. Marshall-Chapman -> Paula Marshall-Chapman
# Edward Grace -> Edward Graze
# Charles M. Caravati, Jr. -> Charles M. Caravati, Jr
# William H. Goodwin, Jr. -> William H. Goodwin, Jr
# Shellv Ritthaler -> Shelly Ritthaler
# Judv Catchpole -> Judy Catchpole
# Zachary Willette -> Zachary M. Willette
# Rev. Kevin F. Dwyer, OSA -> Rev. Kevin F. Dwyer, O.S.A
# George F. Burnell, OSA -> Rev. George F. Burnell, O.S.A.
# Rev. Edson J. Wood, OSA -> Rev. Edson J. Wood, O.S.A
# Rev. Joseph F. Wimmer, OSA -> Rev. Joseph F. Wimmer, O.S.A
# H. George White, Ji -> H. George White, Jr
# Clarence L. Townes -> Clarence L. Townes, Jr
# W. Baxter Perkinson, Jr., D.D.S -> W. Baxter Perkinson, Jr
# Dr. W. Baxter Perkinson, Jr., DDS -> W. Baxter Perkinson, Jr
# Cecil R. Mason, Jr -> Cecil R. Maxson, Jr
# Victor I. Flow, Jr. -> Victor I. Flow, Jr
# John C. Whitaker, Jr -> John C. Whitaker, Jr.
# Leslie M. Baker, Jr. -> Leslie M. Baker, Jr
# Paul L. Miller, Jr. -> Paul L. Miller, Jr
# Mary Ann Krey -> Mary Ann Krey.
# David C. Farrell -> David C. Farrell.
# William E. Cornelius -> William E. Cornelius.
# B. A. Bridgewater, Jr. -> B. A. Bridgewater, Jr
# Constance B. Girard-diCario -> Constance B. Girard-diCarlo
# Donald Tavlor -> Donald Taylor
# Alfred A. Molinari, Jr -> Alfred A. Molinari, Jr.
# Rt. Rev. Victoria Matthews -> Victoria Matthews
# John Ennis Pepper, Jr. -> John Ennis Pepper, Jr
# Ronald Shear. -> Ronald Shear
# David Lipka -> David H. Lipka
# Alex R. Arshinkoff -> Alex Arshinkoff
# Beniamin Gettler -> Benjamin Gettler
# Saul Kramer. -> Saul Kramer
# A. W. "Pete" Smith -> A. W. Smith
# Robin Chemers Neustein -> Robin Neustein
# Angelo R. Mozilo -> Angelo Mozilo
# Dr. Edison K, Miyawaki, MD -> Edison K. Miyawaki, MD
# Michael J. Bidart -> Michael Bidart
# Rev. John P. Schlegel, SJ. -> Rev. John P. Schlegel, SJ
# Rev. Anthony J. Kuzniewski, SJ -> Anthony J. Kuzniewski, SJ
# Dr. Kenan E. Sahin -> Kenan E. Sahin
# Robert M. Duncan -> The Hon. Robert M. Duncan
# Carin M. Barth -> Carin Barth
# John F. McHale, Jr -> John F. McHale, Jr.
# Robert J. Kamerschen -> Robert Kamerschen
# Donald E. O'Connell -> Donald O'Connell
# Daniel J. Brennan -> Daniel Brennan
# L. Francis Rooney III -> L. Francis Rooney
# Malcolm F. Severance -> Malcolm Severance
# Judson G. Randolph, M.D -> Judson Randolph, MD
# John F. Johnson -> John Johnson
# Michael T. Miller -> Michael Miller
# Holcombe T. Green, Jr. -> Holcombe T. Green, Jr
# Joan Treacy, RSHM -> Joan Tracy, RSHM
# Michael C. Forman -> Michael R. Forman
# Michael G. "Mike" Frieze -> Michael G. Frieze
# Joyce Gail Krasnow -> Joyce Krasnow
# Kenneth R. Fitzsimmons, Jr -> Kenneth R. Fitzsimmons, Jr.
# Alfred M. Rankin, Jr. -> Alfred M. Rankin, Jr
# Edward v.K. Cunningham, Jr. -> Edward v.K. Cunningham, Jr
# Leerie T. Jenkins, Jr. -> Leerie Jenkins, Jr.
# Gerold EL. Klauer -> Gerold PL. Klauer
# Gerold FL. Klauer -> Gerold PL. Klauer
# Gerold F.L. Klauer -> Gerold PL. Klauer
# Tony E. Sayegh, Jr. -> Tony E. Sayegh, Jr
# Ted J. Leonsis -> Ted J. LeonsIs
# Rev. John F. Libens, S.J -> Rev. John F. Libens, SJ
# Rev. John F. Libens, S.J. -> Rev. John F. Libens, SJ
# Mitt Romney -> Mitt Romnev
# Dr. Joel S. Bloom -> Joel S. Bloom
# ADM Harold W. Gehman, Jr., USN (Ret) -> Harold W. Gehman, Jr., US
# ADM Harold W. Gehman, Jr., US (Ret) -> Harold W. Gehman, Jr., US
# ADM Harold W. "Hal" Gehman, Jr., USN (Ret) -> Harold W. Gehman, Jr., US
# ADM Harold W. 'Hal' Gehman, Jr., US (Ret) -> Harold W. Gehman, Jr., US
# James Smith McDonnell III -> James S. McDonnell III
# Hector L. Sambolin, Jr -> Hector L. Sambolin, Jr.
# G. William Hunter -> G. William Hunt
# Margaret Corie Darby -> Margaret Corie
# Tommie Burns, Jr. -> Tommie Burns, Jr
# Steven T. Halverson -> Steve T. Halverson
# Georgia M. Willis Fauber -> Georgia M. Willis
# James F. "Jim" Orr III -> James F. Orr III
# Roger J. Heinen, Jr -> Roger Heinen, Jr
# Michael E. BronnerA. -> Michael E. Bronner
# Debra Scheetz Ryan -> Debra Ryan
# Dr. Susan H. Murphy -> Susan H. Murphy
# Sharon R. Kanovsky Richter -> Sharon R. Kanovsky
# Byron E. Lewis, Jr. -> Byron E. Lewis, Jr
# Daniel J. Carroll, Jr -> Daniel J. Carroll, Jr.
# John J. Nigro -> John Nigro
# Deneal A. Michaels -> Deneal Michaels
# Carolyn R. Ferree -> Carolyn Ferree
# W. Wilson, Sr. -> W. Wilson, Sr
# Welcome W. Wilson, Sr -> W. Wilson, Sr
# Calvin W. Stephens -> Calvin Stephens
# Robert A. Wells -> Robert Wells
# Marshall White, Jr -> Marshall "Sonny" White, Jr
# Joseph F. Thompson -> Joseph F. "Joe" Thompson
# T. B. "Bruce" Harper -> T. B. Harper
# Patrick A. "Pat" Duncan -> Patrick A. Duncan
# Solomon L. "Chuck" Badger -> Solomon L. Badger
# Steven J. Leew -> Steven J. Lee
# G. Gilbert "Gil" Cloyd -> G. Gilbert Cloyd
# Sandra .Anderson -> Sandra Anderson
# Sandra J. Anderson -> Sandra Anderson
# Wajdi Kanj -> Waidi Kanj
# Cecelia M. Calhoun -> Cecelia Calhoun
# David G. Huey, CPA -> David G. Huey, CPA.
# Marian D. Moskowitz -> Marian D. Moskowit
# Daniel "Dan" Pero -> Daniel Pero
# Richard "Rick" Beyer -> Richard Beyer
# Richard Allen "Rick" Beyer -> Richard Beyer
# James G. "Jimmy" Padgett, Jr. -> James G. Padgett, Jr
# James G. "Jimmy" Padgett, Jr -> James G. Padgett, Jr
# David Alexander Paterson -> David A. Paterson
# Maria Mascioli Charlton -> Maria Mascioli chariton
# Hugh Calvin Long III -> Hugh Calvin Long IL!
# Hugh Calvin Long II. -> Hugh Calvin Long IL!
# Hugh Calvin Long II -> Hugh Calvin Long IL!
# Stephen Colecchi -> Stephen Collechi
# C. Gregory DeLoach III -> C. Gregory DeLoach II
# C. Gregory "Greg" DeLoach III -> C. Gregory DeLoach II
# Linda S. Kass -> Linda S. Kass'
# David I. McGrath III, D.V.M. -> David I. McGrath III, D.V.M
# Steven Scott -> Steven M. Scott
# Dr. Steven M. Scott -> Steven M. Scott
# Steven Paul Furr, M.D -> Steven Paul Furr, M.D.
# S. Amiad Hussain -> S. Amjad Hussain
# Dr. Francis M. Lazarus -> Dr. Francis M. Lazarus.
# Virginia Stallings -> Virginia "Lyn" Stallings
# Stephen H. Case, Esq. -> Stephen H. Case, Esq
# Lawrence E. Auriana -> Lawrence Auriana
# Kenneth J. Boller, S.J. -> Kenneth Boller, S.J
# Kenneth J. Boller, S.J -> Kenneth Boller, S.J
# Joshua S. Boger, Ph.D. -> Joshua S. Boger, Ph.D
# Warner Lawson, Jr. -> Warner Lawson, Jr
# Bvron E. Lewis -> Byron E. Lewis
# William rung -> William Fung
# William K. Fung -> William Fung
# Thomas N. lovino. -> Thomas N. Lovino
# Rachel M. Sanford -> Rachel Sanford
# Adrian R. King, Jr. -> Adrian R. King, Jr
# Ann Scanion McGinity -> Ann Scanlon McGinity
# Dr. Ann Scanlon McGinity -> Ann Scanlon McGinity
# Kathleen T. "Kathy" O'Loughlin, D.M.D -> Kathleen T. "Kathy" O'Loughlin, D.M.D.
# Andrea Dennis-LaVigne, D.V.M. -> Andrea Dennis-LaVigne, D.V.M
# Nandita Venkateswaran "Nandy" Berry -> Nandita "Nandy" Berry
# Calvin D. Jamison, Sr -> Calvin D. Jamison, Sr.
# Katherine "Kate" Burton -> Katherine Burton
# Dorsey M. James -> Dorsey I. James
# Lauren J. Kolodny -> Lauren Kolodny
# Aristides S. "Aris" Candris -> Aristides S. Candris
# Michael G. "Mike" Cherkasky -> Michael G. Cherkasky
# Dr. Ronald I. Dozoretz, MD -> Dr. Ronald I. Dozoretz, M.D
# Jeffrey M. Siegal -> Jeffrey Siegal
# Elizabeth T. "Libby" Brown -> Elizabeth T. Brown
# L. Clifford Schroeder, Sr -> L. Clifford Schroeder, Sr.
# VADM Richard H. Truly, USN (Ret) -> VADM Richard H. Truly, US (Ret)
# Dr. Robert S. Langer, Jr., ScD -> Robert S. Langer, Jr., Sc.D
# William T. "Bill" Schleyer -> William T. Schleyer
# Joel M. Koppelman -> Joel Koppelman
# Dr. Donna Gentile O'Donnell, PhD -> Dr. Donna Gentile O'Donnell, Ph.D
# GEN John M. "Jack" Keane, USA (Ret) v -> GEN John M. "Jack" Keane, USA (Ret)
# Fr. John J. Cecero, S.J., PhDP -> Fr. John J. Cecero, S.J., Ph.D
# David C. Karlgaard -> David Karlgaard
# Jay E. Katzen, MD -> Jay E. Katzen, M.D
# Dr. Sidney A. Ribeau -> Sidney A. Ribeau
# Michael Anthony Pulick -> Michael Anthony "Mike" Pulick
# Steven C. "Steve" Smith -> Steven C. Smith
# Dr. Lenox D. Baker, Jr., MD -> Lenox D. Baker, Jr., M.D
# Paula E. Boggs, Esq -> Paula E. Boggs, Esq.
# John J. Vresics, Jr. -> John J. "Jack" Vresics, Jr.
# John J. "Jack" Vresics, Jr -> John J. "Jack" Vresics, Jr.
# Dr. Eduardo D. Glandt -> Eduardo D. Glandt
# Margaret Erich Goodman -> Margaret E. Goodman
# Daniel E. "Dan" Smith, Jr. -> Daniel E. Smith, Jr.
# Michael J. Carbon, MD -> Michael J. Carbon, M.D
# Samuel Wright Bodman III -> Samuel Wright "Sam" Bodman III
# Sarah Stewart Johnson -> Sarah Stewart Johnsonw
# Stephanie Nolan Deviney -> Stephanie Nolan Deviney.
# Laura Elena Arnold -> Laura Arnold
# Gregory Brown -> Gregory O. "Greg" Brown
# Gregory "Greg" Brown -> Gregory O. "Greg" Brown
# Gregory Q. "Greg" Brown -> Gregory O. "Greg" Brown
# Antoine M. Garibaldi, Ph.D. -> Antoine M. Garibaldi, Ph.D
# Deborah A. "Debbie" Zoullas -> Deborah A. Zoullas
# Dr. William Henry "Bill" Cosby, Jr. -> William Henry "Bill" Cosby, Jr.
# Bev. James B. King, CSC -> Rev. James B. King, CSC
# Levi Watkins, Jr., MD -> Levi Watkins, Jr., M.D
# The Very Reverend Anthony M. "Micky" Genovese, OSA -> The Very Reverend Anthony M. Genovese, OSA
# George P. Bauer, Jr. -> George P. Bauer, Jr
# Larry Moore -> Larry R. Moore
# Michael "Mike" Maples -> Michael Maples
# Michael H. Devlin Il -> Michael H. Devlin II
# Philip W. "Phil" Schiller -> Philip W. Schiller
# Elizabeth W. Vanderslice -> Elizabeth W. Vanderslice.
# Rajen A. Kilachand -> Rajen A. Kilachand.
# S. D. "Shibu" Shibulah -> S. D. Shibulah
# David L. "Dave" Porges -> David L. Porges
# Dominic L. Ozanne -> Dominic Ozanne
# Dr. Julie Louise Gerberding, MD, MPH -> Julie Louise Gerberding, MD, MPH
# His Eminence Cardinal Donald William Wuerl -> His Eminence Cardinal Donald W. Wuerl
# Jody A. Markopoulos -> Jody A. Markopoulos.
# Steven D. "Steve" Odom -> Steven Odom
# Richard T. "Rick" Caldwell Il -> Richard T. "Rick" Caldwell II
# Joseph A. Greenaway, Jr -> Joseph A. Greenaway, Jr.
# Benjamin "Ben" Horowitz -> Benjamin Horowitz
# R. William "Bill" Burgess, Jr -> R. William Burgess, Jr.
# Robert R. "Bob" Penn -> Robert R. Penn
# John R. "Jack" McGinley, Jr -> John R. "Jack" McGinley, Jr.
# Edward M. "Ed" Stroz -> Edward M. Stroz
# Luis E. San Miguel -> Luis San Miguel
# Dr. Reed V. Tuckson, MD, MD, FACP, FACP -> Dr. Reed V. Tuckson, MD, FACP
# Michael B. Battle -> Michael M. Battle
# Charles William "Charlie" Scharf -> Charles William Scharf
# Anne R. Kline -> Anne R. Kline.
# Rao Subba Anumolu -> Rao Anumolu
# Rev. Thomas A. Lawler, S.J -> Rev. Thomas A. Lawler, S.J.
# Peter L. Slavin, MD -> Dr. Peter L. Slavin, MD
# Dr. Fariborz Maseeh -> Fariborz Maseeh
# Phillip T. "Terry" Ragon -> Phillip T. Ragon
# James Thomas "Tom" McAfee Ill -> James Thomas "Tom" McAfee III
# Jane E. DeFlorio -> Jane DeFlorio
# Dr. David E. Van Zandt -> David E. Van Zandt
# Casey Box -> Casey BoxO
# William T. "Stuyvie" Comfort III -> William T. Comfort III
# Chandrika Krishnamurthy Tandon -> Chandrika Tandon
# Dr. Bradley G. "Brad" Bond -> Bradley Bond
# Michael J. "Mike" Jackson -> Michael J. "Mike Jackson
# Dr. George L. Hanbury II -> Dr. George L. Hanbury II, PhD
# Donald G. Cotner -> Donald G. Cotnerser
# Dr. Laurence C. Morse -> Laurence C. Morse
# Wanda K. Denson-Low -> Wanda K. Denson Low
# Dr. John E. Kelly III -> John E. Kelly III
# Lawrence H. "Larry" Guffey -> Lawrence H. Guffey
# Nimesh S. Jhaveri -> Nimesh Jhaveri
# Robert L. "Bob" Barchi -> Robert L. Barchi
# Robert B. Budelman, Jr -> Robert B. Budelman, Jr.
# Robert Ley -> Robert Ley.
# Jeffrey S. "Jeff" Raikes -> Jeffrey S. "Jeff" Raikes v.
# Laurene Powell Jobs -> Laurene Powell
# Mark A. Neporent -> Mark A. Neporentow
# Dr. Anthony P. Monaco -> Anthony P. Monaco
# Diane S. Hessan -> Diane Hessan
# Daniel L"Dan" Doctoroff -> Daniel L. Doctoroff
# Francis X. "Frank" Hursey -> Francis "Frank" Hursey
# Margaret H. Sedenquist -> Margaret Sedenquist
# Wendy M. Lau -> Wendy Lau
# LtGen Bradley C. Hosmer, USAF (Ret) -> LtGen Bradley C. Homer, USAF (Ret)
# Randall T. Hayashi -> Randall Hayashi
# Kevin P. Huber -> Kevin Huber
# Roberta A. Luxbacher -> Roberta Luxbacher
# Amy G. Beretta -> Amy Beretta
# Thomas C "Tommy" Cofield -> Thomas C. "Tommy" Cofield
# Thomas J. Barrack, Jr -> Thomas J. Barrack, Jr.
# Frank B. Wilderson, Jr -> Frank Wilderson, Jr
# Kathleen J"Kathy" Higgins Victor -> Kathleen J. "Kathy" Higgins Victor
# E. Thomas "Tom" Sullivan -> E. Thomas Sullivan
# Jeffrey S. "Jeff" Marsh -> Jeffrey S. Marsh
# Jyotsna Jo Heckman -> Jyotsna Jo Heckman.
# Daniel M. "Dan" DiLella, Sr -> Daniel M. "Dan" DiLella, Sr.
# John A. Luke, Jr -> John A. Luke, Jr.an
# B. Keith "BK" Fulton -> B. Keith Fulton
# Shelmer D. Blackburn, Jr -> Shelmer D. Blackburn, Jr.
# Thomas Lauck "Tom" Sager -> Thomas Lauck Sager
# Anthony R. Britton, Jr -> Anthony R. Britton, Jr.
# Charles Waterhouse "Chip" Goodyear IV -> Charles W. "Chip" Goodyear IV
# Mendel Mark Silber -> Mark Silber
# Theodore V. "Ted" Wells, Jr -> Theodore V. Wells, Jr
# Dr. Gerdenio M. "Sonny" Manuel, S.J -> Dr. Gerdenio M. "Sonny" Manuel, S.J.
# William Howard "Bill" Ahmanson -> William Howard Ahmanson
# Gregory M. Goethals, S.J -> Gregory M. Goethals, S.JMary Elizabeth Ingham, CSJ
# Irma J. Brown -> Karen J. DialThe Honorable Irma J. Brown Dillon
# Catharine M. Ryan -> Catharine Murray Ryan
# Christopher Ludwig Eisgruber -> Christopher Ludwig Eisgruber*
# Dr. Robert L. "Bob" Barchi, MD, PhD -> Dr. Robert L"Bob" Barchi, MD, PhD
# Year 1999 updated with standardized names.
# Year 2000 updated with standardized names.
# Year 2005 updated with standardized names.
# Year 2007 updated with standardized names.
# Year 2008 updated with standardized names.
# Year 2009 updated with standardized names.
# Year 2010 updated with standardized names.
# Year 2011 updated with standardized names.
# Year 2013 updated with standardized names.
# Year 2018 updated with standardized names.
