# %%
import pandas as pd
from collections import defaultdict, Counter
import networkx as nx
import os
import re
import matplotlib.pyplot as plt
from rapidfuzz import fuzz
from itertools import combinations

# %%
absolute_path = "C:\\Users\\tykun\\OneDrive\\Documents\\SchoolDocs\\VSCodeProjects\\connectedData\\board_analysis\\"
altered_dataframes = "altered_dataframes\\"
board_dataframes = "board_dataframes\\"
final_scripts = "final_scripts\\"
regression = "regression\\"
normalized_dataframes = "normalized_dataframes\\"
normalized_regression_boards = "normalized_regression_boards\\"


years = ["1999", "2000", "2005", "2007", "2008", "2009", "2011", "2013", "2018"]

# %%
def remove_non_samples(df: pd.DataFrame) -> pd.DataFrame:
    """Filter the DataFrame to include only rows where 'PrimarySample' is True."""
    return df[df['PrimarySample'] == True]

def normalize(x):
    """Convert the input to a string and strip whitespace."""
    return str(x).strip()

# %%
affiliation_df = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_systems.csv")

# %%
# This dictionary will map AffiliationId -> Counter({InstitutionName: count}) from both DataFrames.
affiliation_name_counter = defaultdict(Counter)
years_board_data = {}
years_double_data = {} 

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}{regression}regression_boards", f"{year}_boards_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}{regression}regression_boards", f"{year}_double_boards_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    years_board_data[year] = board_df
    years_double_data[year] = double_board_df
    
    for aff_id, institution_name in zip(board_df["AffiliationId"], board_df["Institution"]):
        affiliation_name_counter[aff_id][institution_name] += 1
        
    for aff_id, institution_name in zip(double_board_df["AffiliationId"], double_board_df["Institution"]):
        affiliation_name_counter[aff_id][institution_name] += 1

# Create final mapping: for each AffiliationId, choose the most common institution name across both DataFrames.
affiliation_final_name = {}
for aff_id, name_counter in affiliation_name_counter.items():
    most_common_name = name_counter.most_common(1)[0][0]
    affiliation_final_name[aff_id] = most_common_name



affiliation_final_name = {k: v for k, v in affiliation_final_name.items() if pd.notna(k)}

#Now update both the board and double board DataFrames using the standardized names.
for year in years:
    board_df = years_board_data[year]
    double_board_df = years_double_data[year]
    
    original_board_names = board_df["Institution"].copy()
    original_double_names = double_board_df["Institution"].copy()
    
    #map the standardized institution names based on AffiliationId
    board_df["Institution"] = board_df["AffiliationId"].map(affiliation_final_name)
    double_board_df["Institution"] = double_board_df["AffiliationId"].map(affiliation_final_name)
    
    #log changes: For each unique affiliation id, if the original names differ from the new standardized name, print the change.
    for aff in board_df["AffiliationId"].unique():
        group_old_names = original_board_names[board_df["AffiliationId"] == aff].unique()
        new_name = affiliation_final_name.get(aff, None)
        if set(group_old_names) != {new_name}:
            print(f"Year {year}: Board AffiliationId '{aff}' had original names {group_old_names} -> changed to '{new_name}'")
    
    for aff in double_board_df["AffiliationId"].unique():
        group_old_names = original_double_names[double_board_df["AffiliationId"] == aff].unique()
        new_name = affiliation_final_name.get(aff, None)
        if set(group_old_names) != {new_name}:
            print(f"Year {year}: Double Board AffiliationId '{aff}' had original names {group_old_names} -> changed to '{new_name}'")
    
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df.to_csv(board_path, index=False)
    double_board_df.to_csv(double_board_path, index=False)
# Out:
# Year 1999: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 1999: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 1999: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 1999: Board AffiliationId '35777872.0' had original names ['North Carolina Agricultural And Technical State University'] -> changed to 'North Carolina Agricultural and Technical State University'
# Year 1999: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 1999: Board AffiliationId '392282.0' had original names ['State University Of New York At Albany'] -> changed to 'State University of New York at Albany'
# Year 1999: Board AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'State University of New York at Buffalo'
# Year 1999: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 1999: Board AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 1999: Board AffiliationId '17301866.0' had original names ['University Of Alabama'] -> changed to 'Universitv of Alabama Tuscaloosa'
# Year 1999: Board AffiliationId '157725225.0' had original names ['University Of Illinois At Urbana Champaign'] -> changed to 'University of Illinois at Urbana-Champaign'
# Year 1999: Board AffiliationId '166722992.0' had original names ['University Of Massachusetts Worcester'] -> changed to 'University of Massachusetts at Worcester'
# Year 1999: Board AffiliationId '368840534.0' had original names ['University Of Mississippi'] -> changed to 'University of Mississippi Ole Miss'
# Year 1999: Board AffiliationId '208333798.0' had original names ['University Of Missouri St Louis'] -> changed to 'University of Missouri St Louis'
# Year 1999: Board AffiliationId '134113660.0' had original names ['University Of Nevada Reno'] -> changed to 'University of Nevada, Reno'
# Year 1999: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 1999: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 1999: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 1999: Board AffiliationId '123534392.0' had original names ['University Of North Texas'] -> changed to 'University of North Texas'
# Year 1999: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 1999: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 1999: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2000: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2000: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2000: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2000: Board AffiliationId '35777872.0' had original names ['North Carolina Agricultural And Technical State University'] -> changed to 'North Carolina Agricultural and Technical State University'
# Year 2000: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2000: Board AffiliationId '63190737.0' had original names ['State University Of New York At Buffalo'] -> changed to 'State University of New York at Buffalo'
# Year 2000: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2000: Board AffiliationId '204669301.0' had original names ['Union Institute'] -> changed to 'Union Institute & University'
# Year 2000: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2000: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2000: Board AffiliationId '368840534.0' had original names ['University Of Mississippi'] -> changed to 'University of Mississippi Ole Miss'
# Year 2000: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2000: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2000: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2000: Board AffiliationId '123534392.0' had original names ['University Of North Texas'] -> changed to 'University of North Texas'
# Year 2000: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 2000: Board AffiliationId '86519309.0' had original names ['University Of Texas At Austin'] -> changed to 'University of Texas at Austin'
# Year 2000: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2000: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2000: Double Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2005: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2005: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2005: Board AffiliationId '102179633.0' had original names ['New School University'] -> changed to 'New School'
# Year 2005: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2005: Board AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2005: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2005: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2005: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2005: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2005: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2005: Board AffiliationId '134113660.0' had original names ['University Of Nevada Reno'] -> changed to 'University of Nevada, Reno'
# Year 2005: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2005: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2005: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2005: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2005: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2005: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2005: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2005: Double Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2007: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2007: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2007: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2007: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2007: Board AffiliationId '59553526.0' had original names ['State University Of New York At Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2007: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2007: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2007: Board AffiliationId '161318765.0' had original names ['University Of California Los Angeles'] -> changed to 'University of California Los Angeles'
# Year 2007: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2007: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2007: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2007: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2007: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2007: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2007: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2007: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2007: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2007: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2008: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2008: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2008: Board AffiliationId '23732399.0' had original names ['Montana State University'] -> changed to 'Montana State University Bozeman'
# Year 2008: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic University'] -> changed to 'New York University'
# Year 2008: Board AffiliationId '123946342.0' had original names ['State University Of New York At Binghamton'] -> changed to 'State University of New York at Binghamton'
# Year 2008: Board AffiliationId '59553526.0' had original names ['State University Of New York Stony Brook'] -> changed to 'State University of New York, Stony Brook'
# Year 2008: Board AffiliationId '392282.0' had original names ['University At Albany Suny'] -> changed to 'State University of New York at Albany'
# Year 2008: Board AffiliationId '63190737.0' had original names ['University At Buffalo State University Of New York'] -> changed to 'State University of New York at Buffalo'
# Year 2008: Board AffiliationId '95457486.0' had original names ['University Of California Berkeley'] -> changed to 'University of California Berkeley'
# Year 2008: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2008: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2008: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2008: Board AffiliationId '102149020.0' had original names ['University Of North Carolina At Charlotte'] -> changed to 'University of North Carolina at Charlotte'
# Year 2008: Board AffiliationId '169335092.0' had original names ['University Of North Carolina At Greensboro'] -> changed to 'University of North Carolina at Greensboro'
# Year 2008: Board AffiliationId '153901656.0' had original names ['University Of North Carolina At Wilmington'] -> changed to 'University of North Carolina at Wilmington'
# Year 2008: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2008: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2008: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2009: Board AffiliationId '8248082.0' had original names ['Florida Agricultural And Mechanical University'] -> changed to 'Florida Agricultural and Mechanical University'
# Year 2009: Board AffiliationId '200885203.0' had original names ['Indiana University Of Pennsylvania'] -> changed to 'Indiana University of Pennsylvania'
# Year 2009: Board AffiliationId '23732399.0' had original names ['Montana State University'] -> changed to 'Montana State University Bozeman'
# Year 2009: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2009: Board AffiliationId '13511017.0' had original names ['Texas State University San Marcos'] -> changed to 'Southwest Texas State University'
# Year 2009: Board AffiliationId '106165777.0' had original names ['University Of Central Florida'] -> changed to 'University of Central Florida'
# Year 2009: Board AffiliationId '33213144.0' had original names ['University Of Florida'] -> changed to 'University of Florida'
# Year 2009: Board AffiliationId '94658018.0' had original names ['University Of Memphis'] -> changed to 'University of Memphis'
# Year 2009: Board AffiliationId '11874761.0' had original names ['University Of North Florida'] -> changed to 'University of North Florida'
# Year 2009: Board AffiliationId '2613432.0' had original names ['University Of South Florida'] -> changed to 'University of South Florida'
# Year 2009: Board AffiliationId '44854399.0' had original names ['University Of Southern Mississippi'] -> changed to 'University of Southern Mississippi'
# Year 2009: Board AffiliationId '2802326326.0' had original names ['University Of Texas At Brownsville/Texas Southmost College'] -> changed to 'University of Texas at Brownsville/Texas Southmost College'
# Year 2009: Board AffiliationId '859038795.0' had original names ['Virginia Tech'] -> changed to 'Virginia Polytechnic Institute And State University'
# Year 2009: Board AffiliationId '161171246.0' had original names ['West Chester University Of Pennsylvania'] -> changed to 'West Chester University of Pennsylvania'
# Year 2009: Double Board AffiliationId '859038795.0' had original names ['Virginia Tech'] -> changed to 'Virginia Polytechnic Institute And State University'
# Year 2011: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2011: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2011: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2011: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2011: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2011: Board AffiliationId '155093810.0' had original names ['University of Idaho'] -> changed to 'University Of Idaho'
# Year 2011: Board AffiliationId '146416000.0' had original names ['University of Kansas'] -> changed to 'University Of Kansas'
# Year 2011: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2011: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'
# Year 2013: Board AffiliationId '57206974.0' had original names ['New York University' 'Polytechnic Institute Of New York University'] -> changed to 'New York University'
# Year 2013: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2013: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2013: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2013: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2013: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2013: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'
# Year 2018: Board AffiliationId '2801502357.0' had original names ['Southern Illinois University'] -> changed to 'Southern Illinois University System'
# Year 2018: Board AffiliationId '44461941.0' had original names ['University Of Houston'] -> changed to 'University of Houston'
# Year 2018: Board AffiliationId '76835614.0' had original names ['University Of Missouri Columbia' 'University of Missouri, Columbia'] -> changed to 'University of Missouri, Columbia'
# Year 2018: Board AffiliationId '110152177.0' had original names ['University of Akron'] -> changed to 'University Of Akron'
# Year 2018: Board AffiliationId '138006243.0' had original names ['University of Arizona'] -> changed to 'University Of Arizona'
# Year 2018: Board AffiliationId '63135867.0' had original names ['University of Cincinnati'] -> changed to 'University Of Cincinnati'
# Year 2018: Board AffiliationId '155093810.0' had original names ['University of Idaho'] -> changed to 'University Of Idaho'
# Year 2018: Board AffiliationId '146416000.0' had original names ['University of Kansas'] -> changed to 'University Of Kansas'
# Year 2018: Board AffiliationId '8692664.0' had original names ['University of Oklahoma'] -> changed to 'University Of Oklahoma'
# Year 2018: Board AffiliationId '90871651.0' had original names ['University of Toledo'] -> changed to 'University Of Toledo'

# %%
'''
Determine what institutions report their board every year:
'''
affiliation_info = {}

for year in years:
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    for _, row in board_df.iterrows():
        affiliation_id = row.get("AffiliationId")
        if pd.isna(affiliation_id) or normalize(str(affiliation_id)) == "":
            continue
        affiliation_id = str(affiliation_id).strip()
        if affiliation_id not in affiliation_info:
            affiliation_info[affiliation_id] = {"years": set()}
        affiliation_info[affiliation_id]["years"].add(year)
    
    for _, row in double_board_df.iterrows():
        affiliation_id = row.get("AffiliationId")
        if pd.isna(affiliation_id) or normalize(str(affiliation_id)) == "":
            continue
        affiliation_id = str(affiliation_id).strip()
        if affiliation_id not in affiliation_info:
            affiliation_info[affiliation_id] = {"years": set()}
        affiliation_info[affiliation_id]["years"].add(year)

all_years = set(years)
affiliations_every_year = {aff: info for aff, info in affiliation_info.items() if info["years"] == all_years}
affiliations_certain_years = {aff: info for aff, info in affiliation_info.items() if info["years"] != all_years}

# print("Affiliation IDs that appear in every year:")
# for aff in sorted(affiliations_every_year):
#     info = affiliations_every_year[aff]
#     print(f"{aff}: Years: {sorted(info['years'])}")

# print("\nAffiliation IDs that appear in only certain years:")
# for aff, info in affiliations_certain_years.items():
#     print(f"{aff}: Years: {sorted(info['years'])}")

print(len(affiliations_every_year), len(affiliations_certain_years))
# Out:
# 227 66

# %%
for year in years:
    board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv"
    double_board_path = f"{absolute_path}{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv"
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    board_df["AffiliationId"] = board_df["AffiliationId"].astype(str).str.strip()
    double_board_df["AffiliationId"] = double_board_df["AffiliationId"].astype(str).str.strip()
    
    # Ensure the keys in affiliations_every_year are strings
    aff_keys = set(str(key).strip() for key in affiliations_every_year.keys())
    
    board_df = board_df[ board_df["AffiliationId"].isin(aff_keys) ]
    double_board_df = double_board_df[ double_board_df["AffiliationId"].isin(aff_keys) ]
    
    board_df.to_csv(board_path, index=False)
    double_board_df.to_csv(double_board_path, index=False)
    
    print(f"Year {year}: kept only affiliation IDs that report every year.")
    print(f"  Boards saved to: {board_path}")
    print(f"  Double Boards saved to: {double_board_path}")
# Out:
# Year 1999: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\1999_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\1999_double_boards_normalized_regression.csv
# Year 2000: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2000_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2000_double_boards_normalized_regression.csv
# Year 2005: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2005_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2005_double_boards_normalized_regression.csv
# Year 2007: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2007_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2007_double_boards_normalized_regression.csv
# Year 2008: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2008_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2008_double_boards_normalized_regression.csv
# Year 2009: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2009_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2009_double_boards_normalized_regression.csv
# Year 2011: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2011_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2011_double_boards_normalized_regression.csv
# Year 2013: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2013_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2013_double_boards_normalized_regression.csv
# Year 2018: kept only affiliation IDs that report every year.
#   Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2018_boards_normalized_regression.csv
#   Double Boards saved to: C:\Users\tykun\OneDrive\Documents\SchoolDocs\VSCodeProjects\connectedData\board_analysis\final_scripts\regression\normalized_regression_boards\2018_double_boards_normalized_regression.csv

# %%
#time invariant dfs
affiliation_df = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_systems.csv")
original_affiliation_df  = pd.read_csv(f"{absolute_path}{final_scripts}{regression}regression_stats\\affiliation_original.csv")

#create a dictionary mapping state system -> institutions within the system
affiliation_dict = affiliation_df.groupby("StateSystem")["AffiliationId"].apply(list).to_dict()

affiliation_inverted = {
    aff_id: state_system
    for state_system, aff_ids in affiliation_dict.items()
    for aff_id in aff_ids
}

matched_df = original_affiliation_df[original_affiliation_df["FullName"].isin(affiliation_dict.keys())].copy()

matched_df["StateSystem"] = matched_df["FullName"]

mapping_df = matched_df[["StateSystem", "AffiliationId"]]

mapping_df = mapping_df.drop_duplicates()

system_id_map = {}
nan_id_map = {}

for _, row in mapping_df.iterrows():
    state_system = row["StateSystem"]
    board_aff_id = row["AffiliationId"]
    if pd.isna(board_aff_id):
        nan_id_map[state_system] = affiliation_dict.get(state_system, [])
    else:
        system_id_map[board_aff_id] = affiliation_dict.get(state_system, [])

# Display the resulting dictionary
print(system_id_map)
print(nan_id_map)
# Out:
# {127339247.0: [184813773, 67328108, 67328108, 142934699, 142934699, 142934699, 59897056, 59897056, 43369023, 43369023, 26538001, 71838634], 174216632.0: [125687163, 125687163, 125687163], 4210131357.0: [92446798, 92446798, 92446798, 92446798], 4210165361.0: [120156002, 106969075, 155093810], 2801365651.0: [189590672, 146416000, 39587148], 4210141039.0: [61937129, 99041443, 368840534, 44854399], 4210127926.0: [57328836, 24571045, 24571045], 29957033.0: [200885203, 161171246, 161171246], 1327163397.0: [392282, 392282, 392282, 392282, 123946342, 123946342, 123946342, 123946342, 63190737, 63190737, 63190737, 63190737, 59553526, 59553526, 59553526, 59553526, 59553526], 2801649442.0: [8248082, 63772739, 19700959, 106165777, 33213144, 11874761, 2613432], 173268674.0: [75063564, 91045830, 91045830, 91045830, 206651237, 206651237, 96749437, 96749437, 164185940, 164185940, 181414168, 181414168], 2801273398.0: [191429286, 13511017, 13511017, 13511017, 13511017], 4210088475.0: [12315562, 926076166], 68260882.0: [133999245, 133999245, 134113660, 134113660], 2800507078.0: [32389192, 32389192, 82495205, 82495205, 17301866, 17301866, 17301866, 17301866], 2802090665.0: [141472210], 2799691083.0: [78715868, 78715868, 78715868, 102401767, 79620101], 2803209242.0: [95457486, 95457486, 84218800, 84218800, 204250578, 204250578, 161318765, 161318765, 156087764, 156087764, 103635307, 103635307, 36258959, 36258959, 180670191, 154570441, 185103710], 2802236040.0: [188538660, 188538660, 888729015, 888729015, 921990950, 921990950, 921990950, 921990950], 1331384533.0: [117965899, 117965899], 2801525821.0: [44461941], 2801919071.0: [39422238, 39422238, 157725225, 157725225], 2799628689.0: [919208787, 79516672, 79516672, 79516672, 79516672], 2802397601.0: [7947594, 7947594, 7947594], 2802841742.0: [24603500, 24603500, 33434090, 33434090, 100633361, 100633361, 133738476, 133738476, 166722992, 166722992, 166722992], 4777552.0: [76835614, 76835614, 75421653, 75421653, 20382870, 20382870, 208333798, 208333798], 2802450327.0: [114395901, 114395901, 114395901, 122266389, 122266389, 59130452], 4210158053.0: [186335123, 35777872, 137902535, 114027177, 102149020, 169335092, 153901656, 153901656], 2802090120.0: [123534392], 2799495847.0: [75027704, 160606119, 160606119], 16452829.0: [189196454, 86519309, 2802326326, 2802326326, 162577319, 164936912, 164936912, 45438204, 221716585, 4210094379, 4210094379, 919571938, 165951966, 165951966, 55302922], 1304256225.0: [135310074, 135310074, 43579087, 43579087], 1289702989.0: [130701444, 39815113, 181565077, 172980758, 165733156], 1317227900.0: [126744593, 79272384, 66946132, 22407884, 22407884], 2800453862.0: [161057412, 161057412], 2802096936.0: [157417397, 102607778, 149910238, 83328450, 52357470, 52357470, 4210106879, 110152177, 63135867, 90871651, 19648265]}
# {'Arizona Board of Regents': [55732556, 203172682, 138006243], 'Indiana University System': [4210119109, 55769427], 'Oklahoma State System of Higher Education': [115475287, 8692664], 'Tennessee Board of Regents': [119443389, 169615421, 75256744, 63920570, 94658018]}

# %%
'''
The interlocks that we count here are not going to be the interlocks used for the network. this is to identify interlocking institutions so we can clean the members names
'''

substrings_to_remove = [
    "Rev.", "SJ", "Sister", "Brother", "Father", "OP", "The Very",
    "Sr.", "O.P.", "Very Rev.", "Br.", "Dr.", "Md.", "S.J.", "Very Rev",
    "M.D.", "O.P", "S.J", "J.R", "Jr.", "Jr ", "III"
]

def clean_name(raw_name: str) -> str:
    for title in substrings_to_remove:
        raw_name = re.sub(r'\b' + re.escape(title.strip()) + r'\b', '', raw_name, flags=re.IGNORECASE)
    raw_name = re.sub(r'[^\w\s]', '', raw_name)
    return " ".join(raw_name.split()).title()

# Convert system_id_map values to a list of sets.
# For each value, first cast to int then to str.
system_lists = []
for vals in system_id_map.values():
    sys_set = set(str(int(x)).strip() for x in vals if pd.notna(x))
    if sys_set and sys_set not in system_lists:
        system_lists.append(sys_set)

for year in years:
    board_path = os.path.join(absolute_path, f"{final_scripts}{regression}{normalized_regression_boards}{year}_boards_normalized_regression.csv")
    double_board_path = os.path.join(absolute_path, f"{final_scripts}{regression}{normalized_regression_boards}{year}_double_boards_normalized_regression.csv")
    board_df = pd.read_csv(board_path)
    double_board_df = pd.read_csv(double_board_path)
    
    board_df = remove_non_samples(board_df)
    double_board_df = remove_non_samples(double_board_df)
    
    combined_df = pd.concat([board_df, double_board_df], ignore_index=True)
    board_sizes = combined_df.groupby("Institution").size().to_dict()
    
    board_member_dict = defaultdict(set)
    edge_accum = {}
    # Each institution's affiliation id will be stored as a string of the int value.
    year_nodes_dict = defaultdict(lambda: {'Interlock_Count': 0, 'AffiliationId': None})
    
    for _, row in combined_df.iterrows():
        name_raw = row["Name"]
        if "vacant" in str(name_raw).lower():
            continue
        name = clean_name(name_raw)
        institution = row["Institution"]
        if pd.notnull(row["AffiliationId"]):
            try:
                affiliation_id = str(int(float(row["AffiliationId"]))).strip()
            except Exception:
                affiliation_id = str(row["AffiliationId"]).strip()
        else:
            affiliation_id = None

        for prev_institution in board_member_dict[name]:
            if prev_institution == institution:
                continue
            # Get affiliation IDs for both institutions, casting to int then to str.
            id1 = None
            if year_nodes_dict.get(prev_institution, {}).get('AffiliationId') is not None:
                try:
                    id1 = str(int(float(year_nodes_dict.get(prev_institution)['AffiliationId']))).strip()
                except Exception:
                    id1 = str(year_nodes_dict.get(prev_institution)['AffiliationId']).strip()
            id2 = affiliation_id
            same_system = False
            if id1 and id2:
                for sys_set in system_lists:
                    if id1 in sys_set and id2 in sys_set:
                        same_system = True
                        break
            if same_system:
                continue
            pair = tuple(sorted([prev_institution, institution]))
            if pair not in edge_accum:
                edge_id = f"e_{year}_{len(edge_accum)+1}"
                edge_accum[pair] = {
                    'Id': edge_id,
                    'Source': pair[0],
                    'Target': pair[1],
                    'Type': 'Undirected',
                    'Shared': 0,
                    'Year': year
                }
            edge_accum[pair]['Shared'] += 1
            year_nodes_dict[prev_institution]['Interlock_Count'] += 1
            year_nodes_dict[institution]['Interlock_Count'] += 1
        board_member_dict[name].add(institution)
        if year_nodes_dict[institution]['AffiliationId'] is None and affiliation_id:
            year_nodes_dict[institution]['AffiliationId'] = affiliation_id

    for pair, data in edge_accum.items():
        inst1, inst2 = pair
        size1 = board_sizes.get(inst1, 0)
        size2 = board_sizes.get(inst2, 0)
        denom = size1 + size2 if (size1 + size2) > 0 else 1
        data['Weight'] = data['Shared'] / denom

    nodes_data = []
    for inst, data in year_nodes_dict.items():
        nodes_data.append({
            'Id': inst,
            'Label': inst,
            'Interlock_Count': data['Interlock_Count'],
            'AffiliationId': data['AffiliationId'],
            'Board_Size': board_sizes.get(inst, 0)
        })
    nodes_df = pd.DataFrame(nodes_data)
    
    if edge_accum:
        edges_df = pd.DataFrame(list(edge_accum.values()))
        edges_df = edges_df[['Id', 'Source', 'Target', 'Type', 'Weight', 'Year']]
    else:
        edges_df = pd.DataFrame(columns=['Id', 'Source', 'Target', 'Type', 'Weight', 'Year'])
    
    # out_nodes_path = os.path.join(absolute_path, f"{final_scripts}regression\\interlocks\\{year}_interlocks_nodes.csv")
    # out_edges_path = os.path.join(absolute_path, f"{final_scripts}regression\\interlocks\\{year}_interlocks_edges.csv")
    # nodes_df.to_csv(out_nodes_path, index=False)
    # edges_df.to_csv(out_edges_path, index=False)
    
    # print(f"Year {year} interlock nodes saved to: {out_nodes_path}")
    # print(f"Year {year} interlock edges saved to: {out_edges_path}")

# %%
# name_counts = defaultdict(int)

# for year in years:
#     board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_boards_normalized_regression.csv")
#     double_board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_double_boards_normalized_regression.csv")
#     board_df = pd.read_csv(board_path)
#     double_board_df = pd.read_csv(double_board_path)
#     board_df = remove_non_samples(board_df)
#     double_board_df = remove_non_samples(double_board_df)

#     for name in board_df["Name"].dropna():
#         name_counts[str(name).strip()] += 1
#     for name in double_board_df["Name"].dropna():
#         name_counts[str(name).strip()] += 1

# all_names = list(name_counts.keys())
# sorted_names = sorted(all_names, key=lambda n: name_counts[n], reverse=True)

# name_mapping = {}
# used = set()
# fuzzy_threshold = 90

# for name in sorted_names:
#     if name in used:
#         continue
#     similar_names = []
#     for candidate in all_names:
#         if candidate in used:
#             continue
#         if fuzz.token_set_ratio(name, candidate) >= fuzzy_threshold:
#             similar_names.append(candidate)
#     canonical = max(similar_names, key=lambda n: name_counts[n])
#     for candidate in similar_names:
#         name_mapping[candidate] = canonical
#         used.add(candidate)

# print("Name mapping (only changes):")
# for orig, canon in name_mapping.items():
#     if orig != canon:
#         print(f"{orig} -> {canon}")

# for year in years:
#     board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_boards_normalized_regression.csv")
#     double_board_path = os.path.join(absolute_path, f"{final_scripts}regression\\normalized_regression_boards\\{year}_double_boards_normalized_regression.csv")
#     board_df = pd.read_csv(board_path)
#     double_board_df = pd.read_csv(double_board_path)
#     board_df = remove_non_samples(board_df)
#     double_board_df = remove_non_samples(double_board_df)
    
#     board_df["Name"] = board_df["Name"].apply(lambda x: name_mapping.get(str(x).strip(), x) if pd.notnull(x) else x)
#     double_board_df["Name"] = double_board_df["Name"].apply(lambda x: name_mapping.get(str(x).strip(), x) if pd.notnull(x) else x)
    
#     board_df.to_csv(board_path, index=False)
#     double_board_df.to_csv(double_board_path, index=False)
#     print(f"Year {year} updated with standardized names.")
